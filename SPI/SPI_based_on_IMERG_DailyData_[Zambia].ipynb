# %% [markdown]
# # Satellite-based monitoring of dry and wet conditions using Standardized Precipitation Index (SPI)  colab version

# %% [markdown]
# Surajit Ghosh |Rim | IWMI

# %% [markdown]
# The SPI analysis is following the training conducted in 28 Jan 2020 by [NASA ARSET](https://arset.gsfc.nasa.gov) on **Application of GPM IMERG Reanalysis for Assessing Extreme Dry and Wet Periods**. Link: https://arset.gsfc.nasa.gov/water/webinars/IMERG-2020
#
# Some of the step have been modified and adjusted based on experiencing of several problems during the training, and latest version of [Climate Indices in Python](https://github.com/monocongo/climate_indices) software is used in this tutorial. While NASA ARSET training still used the official release version from [U.S. Drought Portal](https://www.drought.gov/drought/python-climate-indices)

# %% [markdown]
# ## 1. Objectives
# - Learn how to bulk download IMERG data from NASA GES DISC
# - Determine how to calculate the Standardized Precipitation Index (SPI) for assessing extreme dry and wet periods

# %% [markdown]
# ### 1.1. Outline
# - Background on the Standardized Precipitation Index (SPI)
#     - SPI Interpretation
# - Software and Data Preparation
#     - Case Study: Zambia
#     - Install Supporting Software
#     - Data Acquisition
#     - Configure the Conda and python environment
#     - Pre-process data using NetCDF Operator ([NCO](http://nco.sourceforge.net/nco.html))
# - Running SPI code
#     - Pre-compute SPI distribution fitting variables (Optional analysis)
# - Interpret the result using Panoply

# %% [markdown]
# ## 2. Background on the Standardized Precipitation Index
# First developed by T.B. McKee et al. (1993) and used by Guttman (1999)
# - Used for estimating meteorological conditions based on precipitation alone
# - Wet or dry conditions can be monitored on a variety of time scales from sub seasonal to interannual
# - Can be compared across regions with markedly difference climates
# - Does not consider the intensity of precipitation and its potential impacts on runoff, streamflow, and water availability
# - Expressed as the number of standard deviations from the long term mean, for a normally distributed random variable, and fitted probability distribution for the actual precipitation record
# - SPI values < 1 indicate a condition of drought, the more negative the value the more severe the drought condition. SPI values > +1 indicate wetter conditions compared to a climatology

# %% [markdown]
# ### 2.1. SPI Interpretation
# https://drought.unl.edu/droughtmonitoring/SPI.aspx
#
# - 1 month: Similar to a map displaying the percent of normal precipitation for a month. Reflects relatively short term conditions. Its application can be related closely with short term soil moisture and crop stress.
# - 3 month: Provides a comparison of the precipitation over a specific 3 month period with the precipitation totals from the same 3 month period for all the years included in the historical record. Reflects short and medium term moisture conditions and provides a seasonal estimation of precipitation.
# - 6 month: Compares the precipitation for that period with the same 6 month period over the historical record. A 6 month SPI can be very effective in showing the precipitation over distinct seasons and may be associated with anomalous streamflow and reservoir levels.
# - 9 month: Provides an indication of precipitation patterns over a medium time scale. SPI values below 1.5 for these time scales are usually a good indication that significant impacts are occurring in agriculture and may be showing up in other sectors as well.
# - 12 month: Reflects long term precipitation patterns. Longer SPIs tend toward zero unless a specific trend is taking place. SPIs of these time scales are probably tied to streamflow, reservoir levels, and even groundwater levels at the longer time scales. In some locations of the country, the 12 month SPI is most closely related with the Palmer Index, and the two indices should reflect similar conditions.
#
#  (Source: J. Keyantash)

# %% [markdown]
# ### 2.2. Reference
# - Guttman, N. B., 1999: Accepting the Standardized Precipitation Index: A calculation algorithm. J. Amer. Water Resour. Assoc., 35(2), 311-322. [Link](https://climatedataguide.ucar.edu/climate-data/standardized-precipitation-index-spi)
# - Keyantash, John & National Center for Atmospheric Research Staff (Eds). "The Climate Data Guide: Standardized Precipitation Index (SPI)." Retrieved from https://climatedataguide.ucar.edu/climate-data/standardized-precipitation-index-spi
# - Lloyd Hughes, B., and M. A. Saunders, 2002: A drought climatology for Europe. Int. J. Climatol., DOI:10.1002/joc.846 [Link](https://rmets.onlinelibrary.wiley.com/doi/epdf/10.1002/joc.846)
# - McKee, T.B., N. J. Doesken, and J. Kliest, 1993: The relationship of drought frequency and duration to time scales. In Proceedings of the 8th Conference of Applied Climatology, 17 22 January, Anaheim, CA. American Meterological Society, Boston, MA. 179-18. [Link](https://www.droughtmanagement.info/literature/AMS_Relationship_Drought_Frequency_Duration_Time_Scales_1993.pdf)
# - National Drought Mitigation Center (NDMC) at the University of Nebraska Lincoln. [Link](https://drought.unl.edu/droughtmonitoring/SPI.aspx)
# - World Meteorological Organization (WMO), 2012: Standardized Precipitation Index User Guide. [Link](https://library.wmo.int/doc_num.php?explnum_id=7768)
# - Climate Indices in Python https://climate-indices.readthedocs.io/en/latest/

# %% [markdown]
# ## 3. Software and Data Preparation
# Case study: Zambia

# %% [markdown]
# ### 3.1. Install Supporting Software
# **If you encounter a problem, please look for a online solution.** The installation and configuration described below is performed in the colab terminal.
#
# 1. However, to visualize the results, you need to download and install [Panoply Data Viewer](https://www.giss.nasa.gov/tools/panoply/) from [NASA GISS](https://www.giss.nasa.gov/tools/panoply/download/) on your machine:
#     - macOS: https://www.giss.nasa.gov/tools/panoply/download/PanoplyMacOS-4.11.4.dmg
#     - Windows: https://www.giss.nasa.gov/tools/panoply/download/PanoplyWin-4.11.4.zip
#     - Linux: https://www.giss.nasa.gov/tools/panoply/download/PanoplyJ-4.11.4.zip

# %%
# new code
# !pip install condacolab
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting condacolab
#   Using cached condacolab-0.1.3-py3-none-any.whl (6.8 kB)
# Installing collected packages: condacolab
# Successfully installed condacolab-0.1.3

# %%
import condacolab
condacolab.install()
# Out:
# ✨🍰✨ Everything looks OK!

# %% [markdown]
# 2. Install ```wget``` package. ues ```wget``` to download IMERG data and use wget to prepare conda distribution in colab

# %%
# !pip install wget
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: wget in /usr/local/lib/python3.7/site-packages (3.2)

# %% [markdown]
# ### 3.2. Data Acquisition
# 1. Download monthly IMERG data from GES DISC: More detailed instructions can be found from EARTHDATA website https://disc.gsfc.nasa.gov/data-access
#     - Using a web browser, go to NASA Goddard Earth Sciences (GES) Data and Information Services Center (DISC): https://disc.gsfc.nasa.gov/
#     - Type “IMERG” in the search bar and click on the search icon
#     - Select IMERG Version 6 Level 3 data at “monthly” temporal resolution and click on the “Subset/Get Data” icon
#     - Leave the default date range since we want the entire time series
#     - Under Spatial Subset enter ```114.3, -9, 115.8, -8``` This spatial subset is for **Zambia**
#     - Under Variables select only ```precipitation```
#     - Leave the default parameters under Grid
#     - Under File Format select "netCDF"
#     - Click Get Data
#     - Data links windows will popup and you may click **"Download links list"**
#     - You will get a txt file with similar filename like this one **subset_GPM_3IMERGM_06_20210117_064353.txt**
#     - Upload this txt file into your specified download folder in this case folder **IMERG_mm_hr**
#     - Run the code to download the data to folder **IMERG_mm_hr**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# remember to change the download txt file name, output dir, your username and password
# !wget --user=rimu --password=theworldisfullofcrap1A. -P /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day --content-disposition -i  /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/subset_GPM_3IMERGDL_06_20220721_202813.txt
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211113-S000000-E235959.V06.nc4.SUB.nc4’
#
# 3B-DAY-L.MS.MRG.3IM 100%[===================>]  66.59K  --.-KB/s    in 0.1s
#
# 2022-07-22 00:13:27 (585 KB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211113-S000000-E235959.V06.nc4.SUB.nc4’ saved [68186/68186]
#
# --2022-07-22 00:13:27--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDL.06%2F2021%2F11%2F3B-DAY-L.MS.MRG.3IMERG.20211114-S000000-E235959.V06.nc4&FORMAT=bmM0Lw&BBOX=-18.3%2C21.885%2C-8.104%2C33.75&LABEL=3B-DAY-L.MS.MRG.3IMERG.20211114-S000000-E235959.V06.nc4.SUB.nc4&SHORTNAME=GPM_3IMERGDL&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitationCal
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# 200 OK
# Length: 68186 (67K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211113-S000000-E235959.V06.nc4.SUB.nc4’
#
# 3B-DAY-L.MS.MRG.3IM 100%[===================>]  66.59K  --.-KB/s    in 0.1s
#
# 2022-07-22 00:13:27 (585 KB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211113-S000000-E235959.V06.nc4.SUB.nc4’ saved [68186/68186]
#
# --2022-07-22 00:13:27--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDL.06%2F2021%2F11%2F3B-DAY-L.MS.MRG.3IMERG.20211114-S000000-E235959.V06.nc4&FORMAT=bmM0Lw&BBOX=-18.3%2C21.885%2C-8.104%2C33.75&LABEL=3B-DAY-L.MS.MRG.3IMERG.20211114-S000000-E235959.V06.nc4.SUB.nc4&SHORTNAME=GPM_3IMERGDL&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitationCal
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... HTTP request sent, awaiting response... 200 OK
# Length: 70391 (69K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211114-S000000-E235959.V06.nc4.SUB.nc4’
#
# 3B-DAY-L.MS.MRG.3IM 100%[===================>]  68.74K  --.-KB/s    in 0.1s
#
# 2022-07-22 00:13:29 (599 KB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211114-S000000-E235959.V06.nc4.SUB.nc4’ saved [70391/70391]
#
# --2022-07-22 00:13:29--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDL.06%2F2021%2F11%2F3B-DAY-L.MS.MRG.3IMERG.20211115-S000000-E235959.V06.nc4&FORMAT=bmM0Lw&BBOX=-18.3%2C21.885%2C-8.104%2C33.75&LABEL=3B-DAY-L.MS.MRG.3IMERG.20211115-S000000-E235959.V06.nc4.SUB.nc4&SHORTNAME=GPM_3IMERGDL&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitationCal
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... 200 OK
# Length: 70391 (69K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211114-S000000-E235959.V06.nc4.SUB.nc4’
#
# 3B-DAY-L.MS.MRG.3IM 100%[===================>]  68.74K  --.-KB/s    in 0.1s
#
# 2022-07-22 00:13:29 (599 KB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211114-S000000-E235959.V06.nc4.SUB.nc4’ saved [70391/70391]
#
# --2022-07-22 00:13:29--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDL.06%2F2021%2F11%2F3B-DAY-L.MS.MRG.3IMERG.20211115-S000000-E235959.V06.nc4&FORMAT=bmM0Lw&BBOX=-18.3%2C21.885%2C-8.104%2C33.75&LABEL=3B-DAY-L.MS.MRG.3IMERG.20211115-S000000-E235959.V06.nc4.SUB.nc4&SHORTNAME=GPM_3IMERGDL&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitationCal
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 69113 (67K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211115-S000000-E235959.V06.nc4.SUB.nc4’
#
# 3B-DAY-L.MS.MRG.3IM 100%[===================>]  67.49K  --.-KB/s    in 0.1s
#
# 2022-07-22 00:13:30 (588 KB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211115-S000000-E235959.V06.nc4.SUB.nc4’ saved [69113/69113]
#
# --2022-07-22 00:13:30--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDL.06%2F2021%2F11%2F3B-DAY-L.MS.MRG.3IMERG.20211116-S000000-E235959.V06.nc4&FORMAT=bmM0Lw&BBOX=-18.3%2C21.885%2C-8.104%2C33.75&LABEL=3B-DAY-L.MS.MRG.3IMERG.20211116-S000000-E235959.V06.nc4.SUB.nc4&SHORTNAME=GPM_3IMERGDL&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitationCal
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# 200 OK
# Length: 69113 (67K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211115-S000000-E235959.V06.nc4.SUB.nc4’
#
# 3B-DAY-L.MS.MRG.3IM 100%[===================>]  67.49K  --.-KB/s    in 0.1s
#
# 2022-07-22 00:13:30 (588 KB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211115-S000000-E235959.V06.nc4.SUB.nc4’ saved [69113/69113]
#
# --2022-07-22 00:13:30--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDL.06%2F2021%2F11%2F3B-DAY-L.MS.MRG.3IMERG.20211116-S000000-E235959.V06.nc4&FORMAT=bmM0Lw&BBOX=-18.3%2C21.885%2C-8.104%2C33.75&LABEL=3B-DAY-L.MS.MRG.3IMERG.20211116-S000000-E235959.V06.nc4.SUB.nc4&SHORTNAME=GPM_3IMERGDL&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitationCal
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... HTTP request sent, awaiting response... 200 OK
# Length: 60112 (59K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211116-S000000-E235959.V06.nc4.SUB.nc4’
#
# 3B-DAY-L.MS.MRG.3IM 100%[===================>]  58.70K  --.-KB/s    in 0.1s
#
# 2022-07-22 00:13:32 (512 KB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211116-S000000-E235959.V06.nc4.SUB.nc4’ saved [60112/60112]
#
# --2022-07-22 00:13:32--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDL.06%2F2021%2F11%2F3B-DAY-L.MS.MRG.3IMERG.20211117-S000000-E235959.V06.nc4&FORMAT=bmM0Lw&BBOX=-18.3%2C21.885%2C-8.104%2C33.75&LABEL=3B-DAY-L.MS.MRG.3IMERG.20211117-S000000-E235959.V06.nc4.SUB.nc4&SHORTNAME=GPM_3IMERGDL&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitationCal
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... 200 OK
# Length: 60112 (59K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211116-S000000-E235959.V06.nc4.SUB.nc4’
#
# 3B-DAY-L.MS.MRG.3IM 100%[===================>]  58.70K  --.-KB/s    in 0.1s
#
# 2022-07-22 00:13:32 (512 KB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211116-S000000-E235959.V06.nc4.SUB.nc4’ saved [60112/60112]
#
# --2022-07-22 00:13:32--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDL.06%2F2021%2F11%2F3B-DAY-L.MS.MRG.3IMERG.20211117-S000000-E235959.V06.nc4&FORMAT=bmM0Lw&BBOX=-18.3%2C21.885%2C-8.104%2C33.75&LABEL=3B-DAY-L.MS.MRG.3IMERG.20211117-S000000-E235959.V06.nc4.SUB.nc4&SHORTNAME=GPM_3IMERGDL&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitationCal
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 60010 (59K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211117-S000000-E235959.V06.nc4.SUB.nc4’
#
# 3B-DAY-L.MS.MRG.3IM 100%[===================>]  58.60K  --.-KB/s    in 0.1s
#
# 2022-07-22 00:13:34 (510 KB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211117-S000000-E235959.V06.nc4.SUB.nc4’ saved [60010/60010]
#
# --2022-07-22 00:13:34--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDL.06%2F2021%2F11%2F3B-DAY-L.MS.MRG.3IMERG.20211118-S000000-E235959.V06.nc4&FORMAT=bmM0Lw&BBOX=-18.3%2C21.885%2C-8.104%2C33.75&LABEL=3B-DAY-L.MS.MRG.3IMERG.20211118-S000000-E235959.V06.nc4.SUB.nc4&SHORTNAME=GPM_3IMERGDL&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitationCal
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... 200 OK
# Length: 60010 (59K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211117-S000000-E235959.V06.nc4.SUB.nc4’
#
# 3B-DAY-L.MS.MRG.3IM 100%[===================>]  58.60K  --.-KB/s    in 0.1s
#
# 2022-07-22 00:13:34 (510 KB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211117-S000000-E235959.V06.nc4.SUB.nc4’ saved [60010/60010]
#
# --2022-07-22 00:13:34--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDL.06%2F2021%2F11%2F3B-DAY-L.MS.MRG.3IMERG.20211118-S000000-E235959.V06.nc4&FORMAT=bmM0Lw&BBOX=-18.3%2C21.885%2C-8.104%2C33.75&LABEL=3B-DAY-L.MS.MRG.3IMERG.20211118-S000000-E235959.V06.nc4.SUB.nc4&SHORTNAME=GPM_3IMERGDL&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitationCal
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 66914 (65K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211118-S000000-E235959.V06.nc4.SUB.nc4’
#
# 3B-DAY-L.MS.MRG.3IM 100%[===================>]  65.35K  --.-KB/s    in 0.1s
#
# 2022-07-22 00:13:35 (571 KB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211118-S000000-E235959.V06.nc4.SUB.nc4’ saved [66914/66914]
#
# --2022-07-22 00:13:35--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDL.06%2F2021%2F11%2F3B-DAY-L.MS.MRG.3IMERG.20211119-S000000-E235959.V06.nc4&FORMAT=bmM0Lw&BBOX=-18.3%2C21.885%2C-8.104%2C33.75&LABEL=3B-DAY-L.MS.MRG.3IMERG.20211119-S000000-E235959.V06.nc4.SUB.nc4&SHORTNAME=GPM_3IMERGDL&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitationCal
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# 200 OK
# Length: 66914 (65K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211118-S000000-E235959.V06.nc4.SUB.nc4’
#
# 3B-DAY-L.MS.MRG.3IM 100%[===================>]  65.35K  --.-KB/s    in 0.1s
#
# 2022-07-22 00:13:35 (571 KB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211118-S000000-E235959.V06.nc4.SUB.nc4’ saved [66914/66914]
#
# --2022-07-22 00:13:35--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDL.06%2F2021%2F11%2F3B-DAY-L.MS.MRG.3IMERG.20211119-S000000-E235959.V06.nc4&FORMAT=bmM0Lw&BBOX=-18.3%2C21.885%2C-8.104%2C33.75&LABEL=3B-DAY-L.MS.MRG.3IMERG.20211119-S000000-E235959.V06.nc4.SUB.nc4&SHORTNAME=GPM_3IMERGDL&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitationCal
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... HTTP request sent, awaiting response... 200 OK
# Length: 72479 (71K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211119-S000000-E235959.V06.nc4.SUB.nc4’
#
# 3B-DAY-L.MS.MRG.3IM 100%[===================>]  70.78K  --.-KB/s    in 0.1s
#
# 2022-07-22 00:13:37 (622 KB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211119-S000000-E235959.V06.nc4.SUB.nc4’ saved [72479/72479]
#
# --2022-07-22 00:13:37--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDL.06%2F2021%2F11%2F3B-DAY-L.MS.MRG.3IMERG.20211120-S000000-E235959.V06.nc4&FORMAT=bmM0Lw&BBOX=-18.3%2C21.885%2C-8.104%2C33.75&LABEL=3B-DAY-L.MS.MRG.3IMERG.20211120-S000000-E235959.V06.nc4.SUB.nc4&SHORTNAME=GPM_3IMERGDL&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitationCal
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... 200 OK
# Length: 72479 (71K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211119-S000000-E235959.V06.nc4.SUB.nc4’
#
# 3B-DAY-L.MS.MRG.3IM 100%[===================>]  70.78K  --.-KB/s    in 0.1s
#
# 2022-07-22 00:13:37 (622 KB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211119-S000000-E235959.V06.nc4.SUB.nc4’ saved [72479/72479]
#
# --2022-07-22 00:13:37--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDL.06%2F2021%2F11%2F3B-DAY-L.MS.MRG.3IMERG.20211120-S000000-E235959.V06.nc4&FORMAT=bmM0Lw&BBOX=-18.3%2C21.885%2C-8.104%2C33.75&LABEL=3B-DAY-L.MS.MRG.3IMERG.20211120-S000000-E235959.V06.nc4.SUB.nc4&SHORTNAME=GPM_3IMERGDL&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitationCal
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72463 (71K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211120-S000000-E235959.V06.nc4.SUB.nc4’
#
# 3B-DAY-L.MS.MRG.3IM 100%[===================>]  70.76K  --.-KB/s    in 0.1s
#
# 2022-07-22 00:13:39 (614 KB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211120-S000000-E235959.V06.nc4.SUB.nc4’ saved [72463/72463]
#
# --2022-07-22 00:13:39--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDL.06%2F2021%2F11%2F3B-DAY-L.MS.MRG.3IMERG.20211121-S000000-E235959.V06.nc4&FORMAT=bmM0Lw&BBOX=-18.3%2C21.885%2C-8.104%2C33.75&LABEL=3B-DAY-L.MS.MRG.3IMERG.20211121-S000000-E235959.V06.nc4.SUB.nc4&SHORTNAME=GPM_3IMERGDL&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitationCal
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... 200 OK
# Length: 72463 (71K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211120-S000000-E235959.V06.nc4.SUB.nc4’
#
# 3B-DAY-L.MS.MRG.3IM 100%[===================>]  70.76K  --.-KB/s    in 0.1s
#
# 2022-07-22 00:13:39 (614 KB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211120-S000000-E235959.V06.nc4.SUB.nc4’ saved [72463/72463]
#
# --2022-07-22 00:13:39--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDL.06%2F2021%2F11%2F3B-DAY-L.MS.MRG.3IMERG.20211121-S000000-E235959.V06.nc4&FORMAT=bmM0Lw&BBOX=-18.3%2C21.885%2C-8.104%2C33.75&LABEL=3B-DAY-L.MS.MRG.3IMERG.20211121-S000000-E235959.V06.nc4.SUB.nc4&SHORTNAME=GPM_3IMERGDL&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitationCal
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 69749 (68K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211121-S000000-E235959.V06.nc4.SUB.nc4’
#
# 3B-DAY-L.MS.MRG.3IM 100%[===================>]  68.11K  --.-KB/s    in 0.1s
#
# 2022-07-22 00:13:40 (597 KB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211121-S000000-E235959.V06.nc4.SUB.nc4’ saved [69749/69749]
#
# --2022-07-22 00:13:40--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDL.06%2F2021%2F11%2F3B-DAY-L.MS.MRG.3IMERG.20211122-S000000-E235959.V06.nc4&FORMAT=bmM0Lw&BBOX=-18.3%2C21.885%2C-8.104%2C33.75&LABEL=3B-DAY-L.MS.MRG.3IMERG.20211122-S000000-E235959.V06.nc4.SUB.nc4&SHORTNAME=GPM_3IMERGDL&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitationCal
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# 200 OK
# Length: 69749 (68K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211121-S000000-E235959.V06.nc4.SUB.nc4’
#
# 3B-DAY-L.MS.MRG.3IM 100%[===================>]  68.11K  --.-KB/s    in 0.1s
#
# 2022-07-22 00:13:40 (597 KB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211121-S000000-E235959.V06.nc4.SUB.nc4’ saved [69749/69749]
#
# --2022-07-22 00:13:40--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDL.06%2F2021%2F11%2F3B-DAY-L.MS.MRG.3IMERG.20211122-S000000-E235959.V06.nc4&FORMAT=bmM0Lw&BBOX=-18.3%2C21.885%2C-8.104%2C33.75&LABEL=3B-DAY-L.MS.MRG.3IMERG.20211122-S000000-E235959.V06.nc4.SUB.nc4&SHORTNAME=GPM_3IMERGDL&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitationCal
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... HTTP request sent, awaiting response... 200 OK
# Length: 69449 (68K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211122-S000000-E235959.V06.nc4.SUB.nc4’
#
# 3B-DAY-L.MS.MRG.3IM 100%[===================>]  67.82K  --.-KB/s    in 0.1s
#
# 2022-07-22 00:13:42 (584 KB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211122-S000000-E235959.V06.nc4.SUB.nc4’ saved [69449/69449]
#
# --2022-07-22 00:13:42--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDL.06%2F2021%2F11%2F3B-DAY-L.MS.MRG.3IMERG.20211123-S000000-E235959.V06.nc4&FORMAT=bmM0Lw&BBOX=-18.3%2C21.885%2C-8.104%2C33.75&LABEL=3B-DAY-L.MS.MRG.3IMERG.20211123-S000000-E235959.V06.nc4.SUB.nc4&SHORTNAME=GPM_3IMERGDL&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitationCal
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# 200 OK
# Length: 69449 (68K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211122-S000000-E235959.V06.nc4.SUB.nc4’
#
# 3B-DAY-L.MS.MRG.3IM 100%[===================>]  67.82K  --.-KB/s    in 0.1s
#
# 2022-07-22 00:13:42 (584 KB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211122-S000000-E235959.V06.nc4.SUB.nc4’ saved [69449/69449]
#
# --2022-07-22 00:13:42--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDL.06%2F2021%2F11%2F3B-DAY-L.MS.MRG.3IMERG.20211123-S000000-E235959.V06.nc4&FORMAT=bmM0Lw&BBOX=-18.3%2C21.885%2C-8.104%2C33.75&LABEL=3B-DAY-L.MS.MRG.3IMERG.20211123-S000000-E235959.V06.nc4.SUB.nc4&SHORTNAME=GPM_3IMERGDL&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitationCal
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... HTTP request sent, awaiting response... 200 OK
# Length: 71392 (70K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211123-S000000-E235959.V06.nc4.SUB.nc4’
#
# 3B-DAY-L.MS.MRG.3IM 100%[===================>]  69.72K  --.-KB/s    in 0.1s
#
# 2022-07-22 00:13:44 (591 KB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211123-S000000-E235959.V06.nc4.SUB.nc4’ saved [71392/71392]
#
# --2022-07-22 00:13:44--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDL.06%2F2021%2F11%2F3B-DAY-L.MS.MRG.3IMERG.20211124-S000000-E235959.V06.nc4&FORMAT=bmM0Lw&BBOX=-18.3%2C21.885%2C-8.104%2C33.75&LABEL=3B-DAY-L.MS.MRG.3IMERG.20211124-S000000-E235959.V06.nc4.SUB.nc4&SHORTNAME=GPM_3IMERGDL&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitationCal
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... 200 OK
# Length: 71392 (70K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211123-S000000-E235959.V06.nc4.SUB.nc4’
#
# 3B-DAY-L.MS.MRG.3IM 100%[===================>]  69.72K  --.-KB/s    in 0.1s
#
# 2022-07-22 00:13:44 (591 KB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211123-S000000-E235959.V06.nc4.SUB.nc4’ saved [71392/71392]
#
# --2022-07-22 00:13:44--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDL.06%2F2021%2F11%2F3B-DAY-L.MS.MRG.3IMERG.20211124-S000000-E235959.V06.nc4&FORMAT=bmM0Lw&BBOX=-18.3%2C21.885%2C-8.104%2C33.75&LABEL=3B-DAY-L.MS.MRG.3IMERG.20211124-S000000-E235959.V06.nc4.SUB.nc4&SHORTNAME=GPM_3IMERGDL&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitationCal
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 69333 (68K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211124-S000000-E235959.V06.nc4.SUB.nc4’
#
# 3B-DAY-L.MS.MRG.3IM 100%[===================>]  67.71K  --.-KB/s    in 0.1s
#
# 2022-07-22 00:13:45 (590 KB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211124-S000000-E235959.V06.nc4.SUB.nc4’ saved [69333/69333]
#
# --2022-07-22 00:13:45--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDL.06%2F2021%2F11%2F3B-DAY-L.MS.MRG.3IMERG.20211125-S000000-E235959.V06.nc4&FORMAT=bmM0Lw&BBOX=-18.3%2C21.885%2C-8.104%2C33.75&LABEL=3B-DAY-L.MS.MRG.3IMERG.20211125-S000000-E235959.V06.nc4.SUB.nc4&SHORTNAME=GPM_3IMERGDL&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitationCal
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# 200 OK
# Length: 69333 (68K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211124-S000000-E235959.V06.nc4.SUB.nc4’
#
# 3B-DAY-L.MS.MRG.3IM 100%[===================>]  67.71K  --.-KB/s    in 0.1s
#
# 2022-07-22 00:13:45 (590 KB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211124-S000000-E235959.V06.nc4.SUB.nc4’ saved [69333/69333]
#
# --2022-07-22 00:13:45--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDL.06%2F2021%2F11%2F3B-DAY-L.MS.MRG.3IMERG.20211125-S000000-E235959.V06.nc4&FORMAT=bmM0Lw&BBOX=-18.3%2C21.885%2C-8.104%2C33.75&LABEL=3B-DAY-L.MS.MRG.3IMERG.20211125-S000000-E235959.V06.nc4.SUB.nc4&SHORTNAME=GPM_3IMERGDL&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitationCal
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... HTTP request sent, awaiting response... 200 OK
# Length: 73465 (72K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211125-S000000-E235959.V06.nc4.SUB.nc4’
#
# 3B-DAY-L.MS.MRG.3IM 100%[===================>]  71.74K  --.-KB/s    in 0.1s
#
# 2022-07-22 00:13:47 (615 KB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211125-S000000-E235959.V06.nc4.SUB.nc4’ saved [73465/73465]
#
# --2022-07-22 00:13:47--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDL.06%2F2021%2F11%2F3B-DAY-L.MS.MRG.3IMERG.20211126-S000000-E235959.V06.nc4&FORMAT=bmM0Lw&BBOX=-18.3%2C21.885%2C-8.104%2C33.75&LABEL=3B-DAY-L.MS.MRG.3IMERG.20211126-S000000-E235959.V06.nc4.SUB.nc4&SHORTNAME=GPM_3IMERGDL&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitationCal
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# 200 OK
# Length: 73465 (72K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211125-S000000-E235959.V06.nc4.SUB.nc4’
#
# 3B-DAY-L.MS.MRG.3IM 100%[===================>]  71.74K  --.-KB/s    in 0.1s
#
# 2022-07-22 00:13:47 (615 KB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211125-S000000-E235959.V06.nc4.SUB.nc4’ saved [73465/73465]
#
# --2022-07-22 00:13:47--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDL.06%2F2021%2F11%2F3B-DAY-L.MS.MRG.3IMERG.20211126-S000000-E235959.V06.nc4&FORMAT=bmM0Lw&BBOX=-18.3%2C21.885%2C-8.104%2C33.75&LABEL=3B-DAY-L.MS.MRG.3IMERG.20211126-S000000-E235959.V06.nc4.SUB.nc4&SHORTNAME=GPM_3IMERGDL&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitationCal
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... HTTP request sent, awaiting response... 200 OK
# Length: 70494 (69K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211126-S000000-E235959.V06.nc4.SUB.nc4’
#
# 3B-DAY-L.MS.MRG.3IM 100%[===================>]  68.84K  --.-KB/s    in 0.1s
#
# 2022-07-22 00:13:49 (572 KB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211126-S000000-E235959.V06.nc4.SUB.nc4’ saved [70494/70494]
#
# --2022-07-22 00:13:49--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDL.06%2F2021%2F11%2F3B-DAY-L.MS.MRG.3IMERG.20211127-S000000-E235959.V06.nc4&FORMAT=bmM0Lw&BBOX=-18.3%2C21.885%2C-8.104%2C33.75&LABEL=3B-DAY-L.MS.MRG.3IMERG.20211127-S000000-E235959.V06.nc4.SUB.nc4&SHORTNAME=GPM_3IMERGDL&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitationCal
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... 200 OK
# Length: 70494 (69K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211126-S000000-E235959.V06.nc4.SUB.nc4’
#
# 3B-DAY-L.MS.MRG.3IM 100%[===================>]  68.84K  --.-KB/s    in 0.1s
#
# 2022-07-22 00:13:49 (572 KB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211126-S000000-E235959.V06.nc4.SUB.nc4’ saved [70494/70494]
#
# --2022-07-22 00:13:49--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDL.06%2F2021%2F11%2F3B-DAY-L.MS.MRG.3IMERG.20211127-S000000-E235959.V06.nc4&FORMAT=bmM0Lw&BBOX=-18.3%2C21.885%2C-8.104%2C33.75&LABEL=3B-DAY-L.MS.MRG.3IMERG.20211127-S000000-E235959.V06.nc4.SUB.nc4&SHORTNAME=GPM_3IMERGDL&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitationCal
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 56732 (55K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211127-S000000-E235959.V06.nc4.SUB.nc4’
#
# 3B-DAY-L.MS.MRG.3IM 100%[===================>]  55.40K  --.-KB/s    in 0.1s
#
# 2022-07-22 00:13:50 (486 KB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211127-S000000-E235959.V06.nc4.SUB.nc4’ saved [56732/56732]
#
# --2022-07-22 00:13:50--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDL.06%2F2021%2F11%2F3B-DAY-L.MS.MRG.3IMERG.20211128-S000000-E235959.V06.nc4&FORMAT=bmM0Lw&BBOX=-18.3%2C21.885%2C-8.104%2C33.75&LABEL=3B-DAY-L.MS.MRG.3IMERG.20211128-S000000-E235959.V06.nc4.SUB.nc4&SHORTNAME=GPM_3IMERGDL&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitationCal
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... 200 OK
# Length: 56732 (55K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211127-S000000-E235959.V06.nc4.SUB.nc4’
#
# 3B-DAY-L.MS.MRG.3IM 100%[===================>]  55.40K  --.-KB/s    in 0.1s
#
# 2022-07-22 00:13:50 (486 KB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211127-S000000-E235959.V06.nc4.SUB.nc4’ saved [56732/56732]
#
# --2022-07-22 00:13:50--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDL.06%2F2021%2F11%2F3B-DAY-L.MS.MRG.3IMERG.20211128-S000000-E235959.V06.nc4&FORMAT=bmM0Lw&BBOX=-18.3%2C21.885%2C-8.104%2C33.75&LABEL=3B-DAY-L.MS.MRG.3IMERG.20211128-S000000-E235959.V06.nc4.SUB.nc4&SHORTNAME=GPM_3IMERGDL&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitationCal
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 53411 (52K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211128-S000000-E235959.V06.nc4.SUB.nc4’
#
# 3B-DAY-L.MS.MRG.3IM 100%[===================>]  52.16K  --.-KB/s    in 0.1s
#
# 2022-07-22 00:13:52 (452 KB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211128-S000000-E235959.V06.nc4.SUB.nc4’ saved [53411/53411]
#
# --2022-07-22 00:13:52--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDL.06%2F2021%2F11%2F3B-DAY-L.MS.MRG.3IMERG.20211129-S000000-E235959.V06.nc4&FORMAT=bmM0Lw&BBOX=-18.3%2C21.885%2C-8.104%2C33.75&LABEL=3B-DAY-L.MS.MRG.3IMERG.20211129-S000000-E235959.V06.nc4.SUB.nc4&SHORTNAME=GPM_3IMERGDL&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitationCal
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# 200 OK
# Length: 53411 (52K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211128-S000000-E235959.V06.nc4.SUB.nc4’
#
# 3B-DAY-L.MS.MRG.3IM 100%[===================>]  52.16K  --.-KB/s    in 0.1s
#
# 2022-07-22 00:13:52 (452 KB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211128-S000000-E235959.V06.nc4.SUB.nc4’ saved [53411/53411]
#
# --2022-07-22 00:13:52--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDL.06%2F2021%2F11%2F3B-DAY-L.MS.MRG.3IMERG.20211129-S000000-E235959.V06.nc4&FORMAT=bmM0Lw&BBOX=-18.3%2C21.885%2C-8.104%2C33.75&LABEL=3B-DAY-L.MS.MRG.3IMERG.20211129-S000000-E235959.V06.nc4.SUB.nc4&SHORTNAME=GPM_3IMERGDL&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitationCal
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... HTTP request sent, awaiting response... 200 OK
# Length: 57495 (56K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211129-S000000-E235959.V06.nc4.SUB.nc4’
#
# 3B-DAY-L.MS.MRG.3IM 100%[===================>]  56.15K  --.-KB/s    in 0.1s
#
# 2022-07-22 00:13:54 (491 KB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211129-S000000-E235959.V06.nc4.SUB.nc4’ saved [57495/57495]
#
# --2022-07-22 00:13:54--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDL.06%2F2021%2F11%2F3B-DAY-L.MS.MRG.3IMERG.20211130-S000000-E235959.V06.nc4&FORMAT=bmM0Lw&BBOX=-18.3%2C21.885%2C-8.104%2C33.75&LABEL=3B-DAY-L.MS.MRG.3IMERG.20211130-S000000-E235959.V06.nc4.SUB.nc4&SHORTNAME=GPM_3IMERGDL&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitationCal
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... 200 OK
# Length: 57495 (56K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211129-S000000-E235959.V06.nc4.SUB.nc4’
#
# 3B-DAY-L.MS.MRG.3IM 100%[===================>]  56.15K  --.-KB/s    in 0.1s
#
# 2022-07-22 00:13:54 (491 KB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211129-S000000-E235959.V06.nc4.SUB.nc4’ saved [57495/57495]
#
# --2022-07-22 00:13:54--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDL.06%2F2021%2F11%2F3B-DAY-L.MS.MRG.3IMERG.20211130-S000000-E235959.V06.nc4&FORMAT=bmM0Lw&BBOX=-18.3%2C21.885%2C-8.104%2C33.75&LABEL=3B-DAY-L.MS.MRG.3IMERG.20211130-S000000-E235959.V06.nc4.SUB.nc4&SHORTNAME=GPM_3IMERGDL&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitationCal
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 53620 (52K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211130-S000000-E235959.V06.nc4.SUB.nc4’
#
#           3B-DAY-L.   0%[                    ]       0  --.-KB/s               200 OK
# Length: 53620 (52K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211130-S000000-E235959.V06.nc4.SUB.nc4’
#
# 3B-DAY-L.MS.MRG.3IM 100%[===================>]  52.36K  --.-KB/s    in 0.1s
#
# 2022-07-22 00:13:55 (451 KB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211130-S000000-E235959.V06.nc4.SUB.nc4’ saved [53620/53620]
#
# --2022-07-22 00:13:55--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDL.06%2F2021%2F12%2F3B-DAY-L.MS.MRG.3IMERG.20211201-S000000-E235959.V06.nc4&FORMAT=bmM0Lw&BBOX=-18.3%2C21.885%2C-8.104%2C33.75&LABEL=3B-DAY-L.MS.MRG.3IMERG.20211201-S000000-E235959.V06.nc4.SUB.nc4&SHORTNAME=GPM_3IMERGDL&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitationCal
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# 3B-DAY-L.MS.MRG.3IM 100%[===================>]  52.36K  --.-KB/s    in 0.1s
#
# 2022-07-22 00:13:55 (451 KB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211130-S000000-E235959.V06.nc4.SUB.nc4’ saved [53620/53620]
#
# --2022-07-22 00:13:55--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDL.06%2F2021%2F12%2F3B-DAY-L.MS.MRG.3IMERG.20211201-S000000-E235959.V06.nc4&FORMAT=bmM0Lw&BBOX=-18.3%2C21.885%2C-8.104%2C33.75&LABEL=3B-DAY-L.MS.MRG.3IMERG.20211201-S000000-E235959.V06.nc4.SUB.nc4&SHORTNAME=GPM_3IMERGDL&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitationCal
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 60386 (59K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211201-S000000-E235959.V06.nc4.SUB.nc4’
#
# 3B-DAY-L.MS.MRG.3IM 100%[===================>]  58.97K  --.-KB/s    in 0.1s
#
# 2022-07-22 00:13:57 (507 KB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211201-S000000-E235959.V06.nc4.SUB.nc4’ saved [60386/60386]
#
# --2022-07-22 00:13:57--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDL.06%2F2021%2F12%2F3B-DAY-L.MS.MRG.3IMERG.20211202-S000000-E235959.V06.nc4&FORMAT=bmM0Lw&BBOX=-18.3%2C21.885%2C-8.104%2C33.75&LABEL=3B-DAY-L.MS.MRG.3IMERG.20211202-S000000-E235959.V06.nc4.SUB.nc4&SHORTNAME=GPM_3IMERGDL&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitationCal
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# 200 OK
# Length: 60386 (59K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211201-S000000-E235959.V06.nc4.SUB.nc4’
#
# 3B-DAY-L.MS.MRG.3IM 100%[===================>]  58.97K  --.-KB/s    in 0.1s
#
# 2022-07-22 00:13:57 (507 KB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211201-S000000-E235959.V06.nc4.SUB.nc4’ saved [60386/60386]
#
# --2022-07-22 00:13:57--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDL.06%2F2021%2F12%2F3B-DAY-L.MS.MRG.3IMERG.20211202-S000000-E235959.V06.nc4&FORMAT=bmM0Lw&BBOX=-18.3%2C21.885%2C-8.104%2C33.75&LABEL=3B-DAY-L.MS.MRG.3IMERG.20211202-S000000-E235959.V06.nc4.SUB.nc4&SHORTNAME=GPM_3IMERGDL&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitationCal
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... HTTP request sent, awaiting response... 200 OK
# Length: 62569 (61K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211202-S000000-E235959.V06.nc4.SUB.nc4’
#
# 3B-DAY-L.MS.MRG.3IM 100%[===================>]  61.10K  --.-KB/s    in 0.1s
#
# 2022-07-22 00:13:59 (531 KB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211202-S000000-E235959.V06.nc4.SUB.nc4’ saved [62569/62569]
#
# --2022-07-22 00:13:59--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDL.06%2F2021%2F12%2F3B-DAY-L.MS.MRG.3IMERG.20211203-S000000-E235959.V06.nc4&FORMAT=bmM0Lw&BBOX=-18.3%2C21.885%2C-8.104%2C33.75&LABEL=3B-DAY-L.MS.MRG.3IMERG.20211203-S000000-E235959.V06.nc4.SUB.nc4&SHORTNAME=GPM_3IMERGDL&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitationCal
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... 200 OK
# Length: 62569 (61K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211202-S000000-E235959.V06.nc4.SUB.nc4’
#
# 3B-DAY-L.MS.MRG.3IM 100%[===================>]  61.10K  --.-KB/s    in 0.1s
#
# 2022-07-22 00:13:59 (531 KB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211202-S000000-E235959.V06.nc4.SUB.nc4’ saved [62569/62569]
#
# --2022-07-22 00:13:59--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDL.06%2F2021%2F12%2F3B-DAY-L.MS.MRG.3IMERG.20211203-S000000-E235959.V06.nc4&FORMAT=bmM0Lw&BBOX=-18.3%2C21.885%2C-8.104%2C33.75&LABEL=3B-DAY-L.MS.MRG.3IMERG.20211203-S000000-E235959.V06.nc4.SUB.nc4&SHORTNAME=GPM_3IMERGDL&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitationCal
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 53205 (52K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211203-S000000-E235959.V06.nc4.SUB.nc4’
#
#           3B-DAY-L.   0%[                    ]       0  --.-KB/s               200 OK
# Length: 53205 (52K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211203-S000000-E235959.V06.nc4.SUB.nc4’
#
# 3B-DAY-L.MS.MRG.3IM 100%[===================>]  51.96K  --.-KB/s    in 0.09s
#
# 2022-07-22 00:14:00 (555 KB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211203-S000000-E235959.V06.nc4.SUB.nc4’ saved [53205/53205]
#
# --2022-07-22 00:14:00--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDL.06%2F2021%2F12%2F3B-DAY-L.MS.MRG.3IMERG.20211204-S000000-E235959.V06.nc4&FORMAT=bmM0Lw&BBOX=-18.3%2C21.885%2C-8.104%2C33.75&LABEL=3B-DAY-L.MS.MRG.3IMERG.20211204-S000000-E235959.V06.nc4.SUB.nc4&SHORTNAME=GPM_3IMERGDL&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitationCal
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# 3B-DAY-L.MS.MRG.3IM 100%[===================>]  51.96K  --.-KB/s    in 0.09s
#
# 2022-07-22 00:14:00 (555 KB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211203-S000000-E235959.V06.nc4.SUB.nc4’ saved [53205/53205]
#
# --2022-07-22 00:14:00--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDL.06%2F2021%2F12%2F3B-DAY-L.MS.MRG.3IMERG.20211204-S000000-E235959.V06.nc4&FORMAT=bmM0Lw&BBOX=-18.3%2C21.885%2C-8.104%2C33.75&LABEL=3B-DAY-L.MS.MRG.3IMERG.20211204-S000000-E235959.V06.nc4.SUB.nc4&SHORTNAME=GPM_3IMERGDL&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitationCal
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 49219 (48K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211204-S000000-E235959.V06.nc4.SUB.nc4’
#
# 3B-DAY-L.MS.MRG.3IM 100%[===================>]  48.07K  --.-KB/s    in 0.1s
#
# 2022-07-22 00:14:02 (422 KB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211204-S000000-E235959.V06.nc4.SUB.nc4’ saved [49219/49219]
#
# --2022-07-22 00:14:02--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDL.06%2F2021%2F12%2F3B-DAY-L.MS.MRG.3IMERG.20211205-S000000-E235959.V06.nc4&FORMAT=bmM0Lw&BBOX=-18.3%2C21.885%2C-8.104%2C33.75&LABEL=3B-DAY-L.MS.MRG.3IMERG.20211205-S000000-E235959.V06.nc4.SUB.nc4&SHORTNAME=GPM_3IMERGDL&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitationCal
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# 200 OK
# Length: 49219 (48K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211204-S000000-E235959.V06.nc4.SUB.nc4’
#
# 3B-DAY-L.MS.MRG.3IM 100%[===================>]  48.07K  --.-KB/s    in 0.1s
#
# 2022-07-22 00:14:02 (422 KB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211204-S000000-E235959.V06.nc4.SUB.nc4’ saved [49219/49219]
#
# --2022-07-22 00:14:02--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDL.06%2F2021%2F12%2F3B-DAY-L.MS.MRG.3IMERG.20211205-S000000-E235959.V06.nc4&FORMAT=bmM0Lw&BBOX=-18.3%2C21.885%2C-8.104%2C33.75&LABEL=3B-DAY-L.MS.MRG.3IMERG.20211205-S000000-E235959.V06.nc4.SUB.nc4&SHORTNAME=GPM_3IMERGDL&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitationCal
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... HTTP request sent, awaiting response... 200 OK
# Length: 62467 (61K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211205-S000000-E235959.V06.nc4.SUB.nc4’
#
# 3B-DAY-L.MS.MRG.3IM 100%[===================>]  61.00K  --.-KB/s    in 0.1s
#
# 2022-07-22 00:14:04 (512 KB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211205-S000000-E235959.V06.nc4.SUB.nc4’ saved [62467/62467]
#
# --2022-07-22 00:14:04--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDL.06%2F2021%2F12%2F3B-DAY-L.MS.MRG.3IMERG.20211206-S000000-E235959.V06.nc4&FORMAT=bmM0Lw&BBOX=-18.3%2C21.885%2C-8.104%2C33.75&LABEL=3B-DAY-L.MS.MRG.3IMERG.20211206-S000000-E235959.V06.nc4.SUB.nc4&SHORTNAME=GPM_3IMERGDL&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitationCal
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... 200 OK
# Length: 62467 (61K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211205-S000000-E235959.V06.nc4.SUB.nc4’
#
# 3B-DAY-L.MS.MRG.3IM 100%[===================>]  61.00K  --.-KB/s    in 0.1s
#
# 2022-07-22 00:14:04 (512 KB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211205-S000000-E235959.V06.nc4.SUB.nc4’ saved [62467/62467]
#
# --2022-07-22 00:14:04--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDL.06%2F2021%2F12%2F3B-DAY-L.MS.MRG.3IMERG.20211206-S000000-E235959.V06.nc4&FORMAT=bmM0Lw&BBOX=-18.3%2C21.885%2C-8.104%2C33.75&LABEL=3B-DAY-L.MS.MRG.3IMERG.20211206-S000000-E235959.V06.nc4.SUB.nc4&SHORTNAME=GPM_3IMERGDL&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitationCal
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 67465 (66K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211206-S000000-E235959.V06.nc4.SUB.nc4’
#
# 3B-DAY-L.MS.MRG.3IM 100%[===================>]  65.88K  --.-KB/s    in 0.1s
#
# 2022-07-22 00:14:05 (566 KB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20211206-S000000-E235959.V06.nc4.SUB.nc4’ saved [67465/67465]
#
# ...
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 33158 (32K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20220713-S000000-E235959.V06.nc4.SUB.nc4’
#
# 3B-DAY-L.MS.MRG.3IM 100%[===================>]  32.38K  --.-KB/s    in 0.06s
#
# 2022-07-22 00:20:05 (539 KB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20220713-S000000-E235959.V06.nc4.SUB.nc4’ saved [33158/33158]
#
# --2022-07-22 00:20:05--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDL.06%2F2022%2F07%2F3B-DAY-L.MS.MRG.3IMERG.20220714-S000000-E235959.V06.nc4&FORMAT=bmM0Lw&BBOX=-18.3%2C21.885%2C-8.104%2C33.75&LABEL=3B-DAY-L.MS.MRG.3IMERG.20220714-S000000-E235959.V06.nc4.SUB.nc4&SHORTNAME=GPM_3IMERGDL&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitationCal
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 33158 (32K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20220713-S000000-E235959.V06.nc4.SUB.nc4’
#
# 3B-DAY-L.MS.MRG.3IM 100%[===================>]  32.38K  --.-KB/s    in 0.06s
#
# 2022-07-22 00:20:05 (539 KB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20220713-S000000-E235959.V06.nc4.SUB.nc4’ saved [33158/33158]
#
# --2022-07-22 00:20:05--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDL.06%2F2022%2F07%2F3B-DAY-L.MS.MRG.3IMERG.20220714-S000000-E235959.V06.nc4&FORMAT=bmM0Lw&BBOX=-18.3%2C21.885%2C-8.104%2C33.75&LABEL=3B-DAY-L.MS.MRG.3IMERG.20220714-S000000-E235959.V06.nc4.SUB.nc4&SHORTNAME=GPM_3IMERGDL&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitationCal
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 33158 (32K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20220714-S000000-E235959.V06.nc4.SUB.nc4’
#
# 3B-DAY-L.MS.MRG.3IM 100%[===================>]  32.38K  --.-KB/s    in 0.06s
#
# 2022-07-22 00:20:07 (581 KB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20220714-S000000-E235959.V06.nc4.SUB.nc4’ saved [33158/33158]
#
# --2022-07-22 00:20:07--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDL.06%2F2022%2F07%2F3B-DAY-L.MS.MRG.3IMERG.20220715-S000000-E235959.V06.nc4&FORMAT=bmM0Lw&BBOX=-18.3%2C21.885%2C-8.104%2C33.75&LABEL=3B-DAY-L.MS.MRG.3IMERG.20220715-S000000-E235959.V06.nc4.SUB.nc4&SHORTNAME=GPM_3IMERGDL&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitationCal
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 33158 (32K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20220714-S000000-E235959.V06.nc4.SUB.nc4’
#
# 3B-DAY-L.MS.MRG.3IM 100%[===================>]  32.38K  --.-KB/s    in 0.06s
#
# 2022-07-22 00:20:07 (581 KB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20220714-S000000-E235959.V06.nc4.SUB.nc4’ saved [33158/33158]
#
# --2022-07-22 00:20:07--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDL.06%2F2022%2F07%2F3B-DAY-L.MS.MRG.3IMERG.20220715-S000000-E235959.V06.nc4&FORMAT=bmM0Lw&BBOX=-18.3%2C21.885%2C-8.104%2C33.75&LABEL=3B-DAY-L.MS.MRG.3IMERG.20220715-S000000-E235959.V06.nc4.SUB.nc4&SHORTNAME=GPM_3IMERGDL&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitationCal
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... HTTP request sent, awaiting response... 200 OK
# Length: 33158 (32K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20220715-S000000-E235959.V06.nc4.SUB.nc4’
#
# 3B-DAY-L.MS.MRG.3IM 100%[===================>]  32.38K  --.-KB/s    in 0.06s
#
# 2022-07-22 00:20:08 (586 KB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20220715-S000000-E235959.V06.nc4.SUB.nc4’ saved [33158/33158]
#
# --2022-07-22 00:20:08--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDL.06%2F2022%2F07%2F3B-DAY-L.MS.MRG.3IMERG.20220716-S000000-E235959.V06.nc4&FORMAT=bmM0Lw&BBOX=-18.3%2C21.885%2C-8.104%2C33.75&LABEL=3B-DAY-L.MS.MRG.3IMERG.20220716-S000000-E235959.V06.nc4.SUB.nc4&SHORTNAME=GPM_3IMERGDL&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitationCal
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# 200 OK
# Length: 33158 (32K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20220715-S000000-E235959.V06.nc4.SUB.nc4’
#
# 3B-DAY-L.MS.MRG.3IM 100%[===================>]  32.38K  --.-KB/s    in 0.06s
#
# 2022-07-22 00:20:08 (586 KB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20220715-S000000-E235959.V06.nc4.SUB.nc4’ saved [33158/33158]
#
# --2022-07-22 00:20:08--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDL.06%2F2022%2F07%2F3B-DAY-L.MS.MRG.3IMERG.20220716-S000000-E235959.V06.nc4&FORMAT=bmM0Lw&BBOX=-18.3%2C21.885%2C-8.104%2C33.75&LABEL=3B-DAY-L.MS.MRG.3IMERG.20220716-S000000-E235959.V06.nc4.SUB.nc4&SHORTNAME=GPM_3IMERGDL&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitationCal
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... HTTP request sent, awaiting response... 200 OK
# Length: 33158 (32K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20220716-S000000-E235959.V06.nc4.SUB.nc4’
#
# 3B-DAY-L.MS.MRG.3IM 100%[===================>]  32.38K  --.-KB/s    in 0.06s
#
# 2022-07-22 00:20:10 (583 KB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20220716-S000000-E235959.V06.nc4.SUB.nc4’ saved [33158/33158]
#
# --2022-07-22 00:20:10--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDL.06%2F2022%2F07%2F3B-DAY-L.MS.MRG.3IMERG.20220717-S000000-E235959.V06.nc4&FORMAT=bmM0Lw&BBOX=-18.3%2C21.885%2C-8.104%2C33.75&LABEL=3B-DAY-L.MS.MRG.3IMERG.20220717-S000000-E235959.V06.nc4.SUB.nc4&SHORTNAME=GPM_3IMERGDL&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitationCal
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# 200 OK
# Length: 33158 (32K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20220716-S000000-E235959.V06.nc4.SUB.nc4’
#
# 3B-DAY-L.MS.MRG.3IM 100%[===================>]  32.38K  --.-KB/s    in 0.06s
#
# 2022-07-22 00:20:10 (583 KB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20220716-S000000-E235959.V06.nc4.SUB.nc4’ saved [33158/33158]
#
# --2022-07-22 00:20:10--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDL.06%2F2022%2F07%2F3B-DAY-L.MS.MRG.3IMERG.20220717-S000000-E235959.V06.nc4&FORMAT=bmM0Lw&BBOX=-18.3%2C21.885%2C-8.104%2C33.75&LABEL=3B-DAY-L.MS.MRG.3IMERG.20220717-S000000-E235959.V06.nc4.SUB.nc4&SHORTNAME=GPM_3IMERGDL&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitationCal
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 33158 (32K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20220717-S000000-E235959.V06.nc4.SUB.nc4’
#
# 3B-DAY-L.MS.MRG.3IM 100%[===================>]  32.38K  --.-KB/s    in 0.06s
#
# 2022-07-22 00:20:11 (582 KB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20220717-S000000-E235959.V06.nc4.SUB.nc4’ saved [33158/33158]
#
# --2022-07-22 00:20:11--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDL.06%2F2022%2F07%2F3B-DAY-L.MS.MRG.3IMERG.20220718-S000000-E235959.V06.nc4&FORMAT=bmM0Lw&BBOX=-18.3%2C21.885%2C-8.104%2C33.75&LABEL=3B-DAY-L.MS.MRG.3IMERG.20220718-S000000-E235959.V06.nc4.SUB.nc4&SHORTNAME=GPM_3IMERGDL&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitationCal
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 33158 (32K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20220717-S000000-E235959.V06.nc4.SUB.nc4’
#
# 3B-DAY-L.MS.MRG.3IM 100%[===================>]  32.38K  --.-KB/s    in 0.06s
#
# 2022-07-22 00:20:11 (582 KB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20220717-S000000-E235959.V06.nc4.SUB.nc4’ saved [33158/33158]
#
# --2022-07-22 00:20:11--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDL.06%2F2022%2F07%2F3B-DAY-L.MS.MRG.3IMERG.20220718-S000000-E235959.V06.nc4&FORMAT=bmM0Lw&BBOX=-18.3%2C21.885%2C-8.104%2C33.75&LABEL=3B-DAY-L.MS.MRG.3IMERG.20220718-S000000-E235959.V06.nc4.SUB.nc4&SHORTNAME=GPM_3IMERGDL&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitationCal
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... HTTP request sent, awaiting response... 200 OK
# Length: 33158 (32K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20220718-S000000-E235959.V06.nc4.SUB.nc4’
#
# 3B-DAY-L.MS.MRG.3IM 100%[===================>]  32.38K  --.-KB/s    in 0.06s
#
# 2022-07-22 00:20:13 (587 KB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20220718-S000000-E235959.V06.nc4.SUB.nc4’ saved [33158/33158]
#
# --2022-07-22 00:20:13--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDL.06%2F2022%2F07%2F3B-DAY-L.MS.MRG.3IMERG.20220719-S000000-E235959.V06.nc4&FORMAT=bmM0Lw&BBOX=-18.3%2C21.885%2C-8.104%2C33.75&LABEL=3B-DAY-L.MS.MRG.3IMERG.20220719-S000000-E235959.V06.nc4.SUB.nc4&SHORTNAME=GPM_3IMERGDL&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitationCal
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# 200 OK
# Length: 33158 (32K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20220718-S000000-E235959.V06.nc4.SUB.nc4’
#
# 3B-DAY-L.MS.MRG.3IM 100%[===================>]  32.38K  --.-KB/s    in 0.06s
#
# 2022-07-22 00:20:13 (587 KB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20220718-S000000-E235959.V06.nc4.SUB.nc4’ saved [33158/33158]
#
# --2022-07-22 00:20:13--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDL.06%2F2022%2F07%2F3B-DAY-L.MS.MRG.3IMERG.20220719-S000000-E235959.V06.nc4&FORMAT=bmM0Lw&BBOX=-18.3%2C21.885%2C-8.104%2C33.75&LABEL=3B-DAY-L.MS.MRG.3IMERG.20220719-S000000-E235959.V06.nc4.SUB.nc4&SHORTNAME=GPM_3IMERGDL&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitationCal
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... HTTP request sent, awaiting response... 200 OK
# Length: 33158 (32K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20220719-S000000-E235959.V06.nc4.SUB.nc4’
#
# 3B-DAY-L.MS.MRG.3IM 100%[===================>]  32.38K  --.-KB/s    in 0.06s
#
# 2022-07-22 00:20:14 (529 KB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20220719-S000000-E235959.V06.nc4.SUB.nc4’ saved [33158/33158]
#
# --2022-07-22 00:20:14--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDL.06%2F2022%2F07%2F3B-DAY-L.MS.MRG.3IMERG.20220720-S000000-E235959.V06.nc4&FORMAT=bmM0Lw&BBOX=-18.3%2C21.885%2C-8.104%2C33.75&LABEL=3B-DAY-L.MS.MRG.3IMERG.20220720-S000000-E235959.V06.nc4.SUB.nc4&SHORTNAME=GPM_3IMERGDL&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitationCal
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# 200 OK
# Length: 33158 (32K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20220719-S000000-E235959.V06.nc4.SUB.nc4’
#
# 3B-DAY-L.MS.MRG.3IM 100%[===================>]  32.38K  --.-KB/s    in 0.06s
#
# 2022-07-22 00:20:14 (529 KB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20220719-S000000-E235959.V06.nc4.SUB.nc4’ saved [33158/33158]
#
# --2022-07-22 00:20:14--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGDL.06%2F2022%2F07%2F3B-DAY-L.MS.MRG.3IMERG.20220720-S000000-E235959.V06.nc4&FORMAT=bmM0Lw&BBOX=-18.3%2C21.885%2C-8.104%2C33.75&LABEL=3B-DAY-L.MS.MRG.3IMERG.20220720-S000000-E235959.V06.nc4.SUB.nc4&SHORTNAME=GPM_3IMERGDL&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitationCal
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... HTTP request sent, awaiting response... 200 OK
# Length: 35516 (35K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20220720-S000000-E235959.V06.nc4.SUB.nc4’
#
# 3B-DAY-L.MS.MRG.3IM 100%[===================>]  34.68K  --.-KB/s    in 0.06s
#
# 2022-07-22 00:20:16 (628 KB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20220720-S000000-E235959.V06.nc4.SUB.nc4’ saved [35516/35516]
#
# FINISHED --2022-07-22 00:20:16--
# Total wall clock time: 3h 45m 53s
# Downloaded: 8087 files, 417M in 12m 59s (549 KB/s)
# 200 OK
# Length: 35516 (35K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20220720-S000000-E235959.V06.nc4.SUB.nc4’
#
# 3B-DAY-L.MS.MRG.3IM 100%[===================>]  34.68K  --.-KB/s    in 0.06s
#
# 2022-07-22 00:20:16 (628 KB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20220720-S000000-E235959.V06.nc4.SUB.nc4’ saved [35516/35516]
#
# FINISHED --2022-07-22 00:20:16--
# Total wall clock time: 3h 45m 53s
# Downloaded: 8087 files, 417M in 12m 59s (549 KB/s)

# %% [markdown]
# ### 3.3. Configure the Python environment
# This code for calculating SPI is written in Python 3. It is recommended to use either the [Miniconda3](https://docs.conda.io/en/latest/miniconda.html) (minimal Anaconda) or Anaconda3 distribution. The below instructions will be Anaconda specific (although relevant to any Python [virtual environment](https://virtualenv.pypa.io/en/stable/)).
#
# A new Anaconda [environment](https://conda.io/docs/using/envs.html) can be created using the [conda](https://conda.io/docs/) environment management system that comes packaged with Anaconda. Note: you may need to restart the kernel to use some updated packages. The ```conda``` bash should be run in colab terminal which is provided for colab pro user.

# %% [markdown]
# ##### Conda
# ```conda``` is not preinstalled in the default configuration in Colab. Check the following blog to know more details about how to fix it.
#
# https://rjai.me/posts/google-colab-conda/

# %%
# new code
# !wget https://repo.anaconda.com/archive/Anaconda3-2020.02-Linux-x86_64.sh && bash Anaconda3-2020.02-Linux-x86_64.sh -bfp /usr/local
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# anaconda==2020.02=py37_0 -> tk==8.6.8=hbc83047_0
# seaborn==0.10.0=py_0 -> python[version='>=3.6'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# pyopenssl==19.1.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# sphinxcontrib-serializinghtml==1.1.3=py_0 -> python[version='>=3.5'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# pycurl==7.43.0.5=py37h1ba5d50_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# click==7.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# cryptography==2.8=py37h1ba5d50_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# dask==2.11.0=py_0 -> python[version='>=3.6'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# curl==7.68.0=hbc83047_0 -> krb5[version='>=1.17.1,<1.18.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0']
# attrs==19.3.0=py_0 -> python -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# prometheus_client==0.7.1=py_0 -> python -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# pytest-doctestplus==0.5.0=py_0 -> python -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# qtpy==1.9.0=py_0 -> python -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# py==1.8.1=py_0 -> python -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# sphinx==2.4.0=py_0 -> python[version='>=3.5'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# jupyter_core==4.6.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# rope==0.16.0=py_0 -> python -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# pytest-remotedata==0.3.2=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# pytest-astropy-header==0.1.2=py_0 -> python -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# scikit-learn==0.22.1=py37hd81dba3_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# python-jsonrpc-server==0.3.4=py_0 -> python -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# scipy==1.4.1=py37h0b6359f_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# matplotlib-base==3.1.3=py37hef1b27d_0 -> tk[version='>=8.6.8,<8.7.0a0']
# anaconda==2020.02=py37_0 -> krb5==1.17.1=h173b8e3_0 -> tk[version='>=8.6.8,<8.7.0a0']
# pyzmq==18.1.1=py37he6710b0_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# widgetsnbextension==3.5.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# python-dateutil==2.8.1=py_0 -> python -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# qtawesome==0.6.1=py_0 -> python -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# mamba -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# idna==2.8=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# prompt_toolkit==3.0.3=py_0 -> python[version='>=3.6'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# spyder-kernels==1.8.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# numba==0.48.0=py37h0573a6f_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# pyyaml==5.3=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# backports.tempfile==1.0=py_1 -> python -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# sortedcollections==1.1.2=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# patsy==0.5.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# anaconda-client==1.7.2=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# jupyter==1.0.0=py37_7 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# numpydoc==0.9.2=py_0 -> python -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# mccabe==0.6.1=py37_1 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# mpmath==1.1.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# traitlets==4.3.3=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# boto==2.49.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# msgpack-python==0.6.1=py37hfd86e86_1 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# sphinxcontrib-jsmath==1.0.1=py_0 -> python[version='>=3.5'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# tblib==1.6.0=py_0 -> python -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# brotlipy -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# pyflakes==2.1.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# backports==1.0=py_2 -> python -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# asn1crypto==1.3.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# zipp==2.2.0=py_0 -> python[version='>=3.6'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# bleach==3.1.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# babel==2.8.0=py_0 -> python -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# pyodbc==4.0.30=py37he6710b0_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# nltk==3.4.5=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# jsonschema==3.2.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# isort==4.3.21=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# joblib==0.14.1=py_0 -> python -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# testpath==0.4.4=py_0 -> python -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# matplotlib==3.1.3=py37_0 -> matplotlib-base==3.1.3=py37hef1b27d_0 -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# jupyter_console==6.1.0=py_0 -> python[version='>=3.5'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# pywavelets==1.1.1=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# path.py==12.4.0=0 -> python[version='>=3.5'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# jupyterlab==1.2.6=pyhf63ae98_0 -> python[version='>=3.5'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# decorator==4.4.1=py_0 -> python -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# bitarray==1.2.1=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# conda-package-handling==1.6.0=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# jeepney==0.4.2=py_0 -> python[version='>=3.5'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# multipledispatch==0.6.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# pip==20.0.2=py37_1 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# pydocstyle==4.0.1=py_0 -> python[version='>=3.4'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# conda-verify==3.4.2=py_1 -> python -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# docutils==0.16=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# hypothesis==5.5.4=py_0 -> python[version='>=3.5'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# anaconda-navigator==1.9.12=py37_0 -> pillow -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# wheel==0.34.2=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# qdarkstyle==2.8=py_0 -> python -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# imagesize==1.2.0=py_0 -> python -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# cffi==1.14.0=py37h2e261b9_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# xmltodict==0.12.0=py_0 -> python -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# mistune==0.8.4=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# pyparsing==2.4.6=py_0 -> python -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# ptyprocess==0.6.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# greenlet==0.4.15=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# tornado==6.0.3=py37h7b6447c_3 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# send2trash==1.5.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# python-language-server==0.31.7=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# pytest-arraydiff==0.3=py37h39e3cac_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# spyder==4.0.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# ipython_genutils==0.2.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# werkzeug==1.0.0=py_0 -> python -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# flake8==3.7.9=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# json5==0.9.1=py_0 -> python -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# gmpy2==2.0.8=py37h10f8cd9_2 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# astroid==2.3.3=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# urllib3==1.25.8=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# fsspec==0.6.2=py_0 -> python[version='>=3.5'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# keyring==21.1.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# pandas==1.0.1=py37h0573a6f_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# numexpr==2.7.1=py37h423224d_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# sphinxcontrib-qthelp==1.0.2=py_0 -> python[version='>=3.5'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# zict==1.0.0=py_0 -> python -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# conda-build==3.18.11=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# markupsafe==1.1.1=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# clyent==1.2.2=py37_1 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# kiwisolver==1.1.0=py37he6710b0_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# pathlib2==2.3.5=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# gevent==1.4.0=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# sortedcontainers==2.1.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# itsdangerous==1.1.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# path==13.1.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# navigator-updater==0.2.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# backports.shutil_get_terminal_size==1.0.0=py37_2 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# backcall==0.1.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# filelock==3.0.12=py_0 -> python -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# pycodestyle==2.5.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# pyxdg==0.26=py_0 -> python -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# pygments==2.5.2=py_0 -> python -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# toolz==0.10.0=py_0 -> python -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# sympy==1.5.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# simplegeneric==0.8.1=py37_2 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# llvmlite==0.31.0=py37hd408876_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# autopep8==1.4.4=py_0 -> python -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# flask==1.1.1=py_0 -> python -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# nose==1.3.7=py37_2 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# astropy==4.0=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# requests==2.22.0=py37_1 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# pillow==7.0.0=py37hb39fc2d_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0']
# yapf==0.28.0=py_0 -> python -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# dask-core==2.11.0=py_0 -> python[version='>=3.6'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# pycrypto==2.6.1=py37h14c3975_9 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# wurlitzer==2.0.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# openpyxl==3.0.3=py_0 -> python[version='>=3.6'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# pytest-openfiles==0.4.0=py_0 -> python -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# mkl_fft==1.0.15=py37ha843d7b_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# singledispatch==3.4.0.3=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# distributed==2.11.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# partd==1.1.0=py_0 -> python[version='>=3.5'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# python-libarchive-c==2.8=py37_13 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# xlsxwriter==1.2.7=py_0 -> python -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# importlib_metadata==1.5.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# numpy==1.18.1=py37h4f9e942_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# python==3.7.6=h0371630_2 -> tk[version='>=8.6.8,<8.7.0a0']
# defusedxml==0.6.0=py_0 -> python -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# bkcharts==0.2=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# sip==4.19.8=py37hf484d3e_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# jupyterlab_server==1.0.6=py_0 -> python[version='>=3.5'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# python_abi -> python=3.7 -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# pytest==5.3.5=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# et_xmlfile==1.0.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# sphinxcontrib-applehelp==1.0.1=py_0 -> python[version='>=3.5'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# ujson==1.35=py37h14c3975_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# webencodings==0.5.1=py37_1 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# contextlib2==0.6.0.post1=py_0 -> python -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# mkl-service==2.3.0=py37he904b0f_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# jinja2==2.11.1=py_0 -> python -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# backports.weakref==1.0.post1=py_1 -> python -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# libcurl==7.68.0=h20c2e04_0 -> krb5[version='>=1.17.1,<1.18.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0']
# fastcache==1.1.0=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# python=3.7 -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# secretstorage==3.1.2=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# tqdm==4.42.1=py_0 -> python -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# h5py==2.10.0=py37h7918eee_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# more-itertools==8.2.0=py_0 -> python[version='>=3.4'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# future==0.18.2=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# xlwt==1.3.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# alabaster==0.7.12=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0']
# krb5==1.17.1=h173b8e3_0 -> tk[version='>=8.6.8,<8.7.0a0']
#
# Package ld_impl_linux-64 conflicts for:
# pyflakes==2.1.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# certifi==2019.11.28=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# seaborn==0.10.0=py_0 -> python[version='>=3.6'] -> ld_impl_linux-64[version='>=2.34']
# atomicwrites==1.3.0=py37_1 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# snowballstemmer==2.0.0=py_0 -> python -> ld_impl_linux-64[version='>=2.34']
# pygments==2.5.2=py_0 -> python -> ld_impl_linux-64[version='>=2.34']
# qtawesome==0.6.1=py_0 -> python -> ld_impl_linux-64[version='>=2.34']
# ipykernel==5.1.4=py37h39e3cac_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# tblib==1.6.0=py_0 -> python -> ld_impl_linux-64[version='>=2.34']
# isort==4.3.21=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# python_abi -> python=3.7 -> ld_impl_linux-64[version='>=2.34']
# anaconda-client==1.7.2=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# conda-build==3.18.11=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# pytables==3.6.1=py37h71ec239_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# anaconda-navigator==1.9.12=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# importlib_metadata==1.5.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# cloudpickle==1.3.0=py_0 -> python[version='>=3'] -> ld_impl_linux-64[version='>=2.34']
# clyent==1.2.2=py37_1 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# pillow==7.0.0=py37hb39fc2d_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# backports==1.0=py_2 -> python -> ld_impl_linux-64[version='>=2.34']
# numexpr==2.7.1=py37h423224d_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# cryptography==2.8=py37h1ba5d50_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# mccabe==0.6.1=py37_1 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# pycrypto==2.6.1=py37h14c3975_9 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# pyrsistent==0.15.7=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# diff-match-patch==20181111=py_0 -> python -> ld_impl_linux-64[version='>=2.34']
# werkzeug==1.0.0=py_0 -> python -> ld_impl_linux-64[version='>=2.34']
# pytest-openfiles==0.4.0=py_0 -> python -> ld_impl_linux-64[version='>=2.34']
# nbformat==5.0.4=py_0 -> python[version='>=3.5'] -> ld_impl_linux-64[version='>=2.34']
# click==7.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# ply==3.11=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# setuptools==45.2.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# backports.shutil_get_terminal_size==1.0.0=py37_2 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# glob2==0.7=py_0 -> python -> ld_impl_linux-64[version='>=2.34']
# requests==2.22.0=py37_1 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# sphinxcontrib-applehelp==1.0.1=py_0 -> python[version='>=3.5'] -> ld_impl_linux-64[version='>=2.34']
# zict==1.0.0=py_0 -> python -> ld_impl_linux-64[version='>=2.34']
# backcall==0.1.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# jupyter_core==4.6.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# soupsieve==1.9.5=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# sphinxcontrib-jsmath==1.0.1=py_0 -> python[version='>=3.5'] -> ld_impl_linux-64[version='>=2.34']
# ruamel_yaml==0.15.87=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# flask==1.1.1=py_0 -> python -> ld_impl_linux-64[version='>=2.34']
# sphinxcontrib-serializinghtml==1.1.3=py_0 -> python[version='>=3.5'] -> ld_impl_linux-64[version='>=2.34']
# llvmlite==0.31.0=py37hd408876_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# pyodbc==4.0.30=py37he6710b0_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# imageio==2.6.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# pkginfo==1.5.0.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# imagesize==1.2.0=py_0 -> python -> ld_impl_linux-64[version='>=2.34']
# pytest==5.3.5=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# contextlib2==0.6.0.post1=py_0 -> python -> ld_impl_linux-64[version='>=2.34']
# hypothesis==5.5.4=py_0 -> python[version='>=3.5'] -> ld_impl_linux-64[version='>=2.34']
# jupyter_console==6.1.0=py_0 -> python[version='>=3.5'] -> ld_impl_linux-64[version='>=2.34']
# intervaltree==3.0.2=py_0 -> python -> ld_impl_linux-64[version='>=2.34']
# singledispatch==3.4.0.3=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# ipython_genutils==0.2.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# mkl_random==1.1.0=py37hd6b4f25_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# watchdog==0.10.2=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# path==13.1.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# pytest-arraydiff==0.3=py37h39e3cac_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# python-dateutil==2.8.1=py_0 -> python -> ld_impl_linux-64[version='>=2.34']
# partd==1.1.0=py_0 -> python[version='>=3.5'] -> ld_impl_linux-64[version='>=2.34']
# pycurl==7.43.0.5=py37h1ba5d50_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# terminado==0.8.3=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# wcwidth==0.1.8=py_0 -> python -> ld_impl_linux-64[version='>=2.34']
# simplegeneric==0.8.1=py37_2 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# idna==2.8=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# ipywidgets==7.5.1=py_0 -> python -> ld_impl_linux-64[version='>=2.34']
# lazy-object-proxy==1.4.3=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# jupyterlab_server==1.0.6=py_0 -> python[version='>=3.5'] -> ld_impl_linux-64[version='>=2.34']
# numpy==1.18.1=py37h4f9e942_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# markupsafe==1.1.1=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# keyring==21.1.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# fsspec==0.6.2=py_0 -> python[version='>=3.5'] -> ld_impl_linux-64[version='>=2.34']
# cycler==0.10.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# ld_impl_linux-64==2.33.1=h53a641e_7
# olefile==0.46=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# pyparsing==2.4.6=py_0 -> python -> ld_impl_linux-64[version='>=2.34']
# jupyter==1.0.0=py37_7 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# bleach==3.1.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# heapdict==1.0.1=py_0 -> python -> ld_impl_linux-64[version='>=2.34']
# nltk==3.4.5=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# autopep8==1.4.4=py_0 -> python -> ld_impl_linux-64[version='>=2.34']
# pycparser==2.19=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# sphinxcontrib==1.0=py37_1 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# jupyter_client==5.3.4=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# mistune==0.8.4=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# gevent==1.4.0=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# python-language-server==0.31.7=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# anaconda-project==0.8.4=py_0 -> python -> ld_impl_linux-64[version='>=2.34']
# lxml==4.5.0=py37hefd8a0e_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# patsy==0.5.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# numpydoc==0.9.2=py_0 -> python -> ld_impl_linux-64[version='>=2.34']
# traitlets==4.3.3=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# urllib3==1.25.8=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# h5py==2.10.0=py37h7918eee_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# attrs==19.3.0=py_0 -> python -> ld_impl_linux-64[version='>=2.34']
# joblib==0.14.1=py_0 -> python -> ld_impl_linux-64[version='>=2.34']
# conda-package-handling==1.6.0=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# yapf==0.28.0=py_0 -> python -> ld_impl_linux-64[version='>=2.34']
# notebook==6.0.3=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# pickleshare==0.7.5=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# kiwisolver==1.1.0=py37he6710b0_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# matplotlib==3.1.3=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# conda==4.8.2=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# sphinxcontrib-qthelp==1.0.2=py_0 -> python[version='>=3.5'] -> ld_impl_linux-64[version='>=2.34']
# pytest-remotedata==0.3.2=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# nbconvert==5.6.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# prompt_toolkit==3.0.3=py_0 -> python[version='>=3.6'] -> ld_impl_linux-64[version='>=2.34']
# scipy==1.4.1=py37h0b6359f_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# jdcal==1.4.1=py_0 -> python -> ld_impl_linux-64[version='>=2.34']
# bkcharts==0.2=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# _ipyw_jlab_nb_ext_conf==0.1.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# astropy==4.0=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# pyyaml==5.3=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# babel==2.8.0=py_0 -> python -> ld_impl_linux-64[version='>=2.34']
# wrapt==1.11.2=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# pywavelets==1.1.1=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# bottleneck==1.3.2=py37heb32a55_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# pytest-doctestplus==0.5.0=py_0 -> python -> ld_impl_linux-64[version='>=2.34']
# astroid==2.3.3=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# itsdangerous==1.1.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# filelock==3.0.12=py_0 -> python -> ld_impl_linux-64[version='>=2.34']
# send2trash==1.5.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# py-lief==0.9.0=py37h7725739_2 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# python=3.7 -> ld_impl_linux-64[version='>=2.34']
# entrypoints==0.3=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# bokeh==1.4.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# xlrd==1.2.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# scikit-learn==0.22.1=py37hd81dba3_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# sphinx==2.4.0=py_0 -> python[version='>=3.5'] -> ld_impl_linux-64[version='>=2.34']
# jsonschema==3.2.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# ujson==1.35=py37h14c3975_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# pytest-astropy-header==0.1.2=py_0 -> python -> ld_impl_linux-64[version='>=2.34']
# mock==4.0.1=py_0 -> python[version='>=3.6'] -> ld_impl_linux-64[version='>=2.34']
# sqlalchemy==1.3.13=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# xlsxwriter==1.2.7=py_0 -> python -> ld_impl_linux-64[version='>=2.34']
# pytest-astropy==0.8.0=py_0 -> python -> ld_impl_linux-64[version='>=2.34']
# mamba -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# dask-core==2.11.0=py_0 -> python[version='>=3.6'] -> ld_impl_linux-64[version='>=2.34']
# pycodestyle==2.5.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# qdarkstyle==2.8=py_0 -> python -> ld_impl_linux-64[version='>=2.34']
# prometheus_client==0.7.1=py_0 -> python -> ld_impl_linux-64[version='>=2.34']
# greenlet==0.4.15=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# jeepney==0.4.2=py_0 -> python[version='>=3.5'] -> ld_impl_linux-64[version='>=2.34']
# sphinxcontrib-htmlhelp==1.0.2=py_0 -> python[version='>=3.5'] -> ld_impl_linux-64[version='>=2.34']
# pandocfilters==1.4.2=py37_1 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# pyzmq==18.1.1=py37he6710b0_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# networkx==2.4=py_0 -> python[version='>=3.5'] -> ld_impl_linux-64[version='>=2.34']
# rope==0.16.0=py_0 -> python -> ld_impl_linux-64[version='>=2.34']
# mpmath==1.1.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# defusedxml==0.6.0=py_0 -> python -> ld_impl_linux-64[version='>=2.34']
# future==0.18.2=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# jedi==0.14.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# zipp==2.2.0=py_0 -> python[version='>=3.6'] -> ld_impl_linux-64[version='>=2.34']
# nose==1.3.7=py37_2 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# msgpack-python==0.6.1=py37hfd86e86_1 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# pyxdg==0.26=py_0 -> python -> ld_impl_linux-64[version='>=2.34']
# multipledispatch==0.6.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# fastcache==1.1.0=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# cytoolz==0.10.1=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# anaconda==2020.02=py37_0 -> ld_impl_linux-64==2.33.1=h53a641e_7
# cffi==1.14.0=py37h2e261b9_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# locket==0.2.0=py37_1 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# gmpy2==2.0.8=py37h10f8cd9_2 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# html5lib==1.0.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# dask==2.11.0=py_0 -> python[version='>=3.6'] -> ld_impl_linux-64[version='>=2.34']
# ptyprocess==0.6.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# alabaster==0.7.12=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# pexpect==4.8.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# anaconda==2020.02=py37_0 -> python==3.7.6=h0371630_2 -> ld_impl_linux-64
# parso==0.5.2=py_0 -> python -> ld_impl_linux-64[version='>=2.34']
# wheel==0.34.2=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# unicodecsv==0.14.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# pip==20.0.2=py37_1 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# numba==0.48.0=py37h0573a6f_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# sphinxcontrib-devhelp==1.0.1=py_0 -> python[version='>=3.5'] -> ld_impl_linux-64[version='>=2.34']
# secretstorage==3.1.2=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# pyopenssl==19.1.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# py==1.8.1=py_0 -> python -> ld_impl_linux-64[version='>=2.34']
# sympy==1.5.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# six==1.14.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# spyder-kernels==1.8.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# wurlitzer==2.0.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# argh==0.26.2=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# conda-verify==3.4.2=py_1 -> python -> ld_impl_linux-64[version='>=2.34']
# asn1crypto==1.3.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# psutil==5.6.7=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# pytz==2019.3=py_0 -> python -> ld_impl_linux-64[version='>=2.34']
# bitarray==1.2.1=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# matplotlib-base==3.1.3=py37hef1b27d_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# toolz==0.10.0=py_0 -> python -> ld_impl_linux-64[version='>=2.34']
# rtree==0.9.3=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# docutils==0.16=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# cython==0.29.15=py37he6710b0_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# sphinxcontrib-websupport==1.2.0=py_0 -> python -> ld_impl_linux-64[version='>=2.34']
# brotlipy -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# et_xmlfile==1.0.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# statsmodels==0.11.0=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# widgetsnbextension==3.5.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# pycosat==0.6.3=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# python-libarchive-c==2.8=py37_13 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# pyqt==5.9.2=py37h05f1152_2 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# sip==4.19.8=py37hf484d3e_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# pathtools==0.1.2=py_1 -> python -> ld_impl_linux-64[version='>=2.34']
# tqdm==4.42.1=py_0 -> python -> ld_impl_linux-64[version='>=2.34']
# backports.functools_lru_cache==1.6.1=py_0 -> python -> ld_impl_linux-64[version='>=2.34']
# numpy-base==1.18.1=py37hde5b4d6_1 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# pep8==1.7.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# ipython==7.12.0=py37h5ca1d4c_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# python-jsonrpc-server==0.3.4=py_0 -> python -> ld_impl_linux-64[version='>=2.34']
# xmltodict==0.12.0=py_0 -> python -> ld_impl_linux-64[version='>=2.34']
# jinja2==2.11.1=py_0 -> python -> ld_impl_linux-64[version='>=2.34']
# xlwt==1.3.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# spyder==4.0.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# flake8==3.7.9=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# packaging==20.1=py_0 -> python -> ld_impl_linux-64[version='>=2.34']
# sortedcontainers==2.1.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# testpath==0.4.4=py_0 -> python -> ld_impl_linux-64[version='>=2.34']
# qtconsole==4.6.0=py_1 -> python -> ld_impl_linux-64[version='>=2.34']
# more-itertools==8.2.0=py_0 -> python[version='>=3.4'] -> ld_impl_linux-64[version='>=2.34']
# tornado==6.0.3=py37h7b6447c_3 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# openpyxl==3.0.3=py_0 -> python[version='>=3.6'] -> ld_impl_linux-64[version='>=2.34']
# path.py==12.4.0=0 -> python[version='>=3.5'] -> ld_impl_linux-64[version='>=2.34']
# backports.tempfile==1.0=py_1 -> python -> ld_impl_linux-64[version='>=2.34']
# pydocstyle==4.0.1=py_0 -> python[version='>=3.4'] -> ld_impl_linux-64[version='>=2.34']
# sortedcollections==1.1.2=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# pylint==2.4.4=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# boto==2.49.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# jupyterlab==1.2.6=pyhf63ae98_0 -> python[version='>=3.5'] -> ld_impl_linux-64[version='>=2.34']
# decorator==4.4.1=py_0 -> python -> ld_impl_linux-64[version='>=2.34']
# pandas==1.0.1=py37h0573a6f_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# pysocks==1.7.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# webencodings==0.5.1=py37_1 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# colorama==0.4.3=py_0 -> python -> ld_impl_linux-64[version='>=2.34']
# pathlib2==2.3.5=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# python==3.7.6=h0371630_2 -> ld_impl_linux-64
# json5==0.9.1=py_0 -> python -> ld_impl_linux-64[version='>=2.34']
# navigator-updater==0.2.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# distributed==2.11.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# mkl-service==2.3.0=py37he904b0f_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# mkl_fft==1.0.15=py37ha843d7b_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# qtpy==1.9.0=py_0 -> python -> ld_impl_linux-64[version='>=2.34']
# chardet==3.0.4=py37_1003 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# scikit-image==0.16.2=py37h0573a6f_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
# backports.weakref==1.0.post1=py_1 -> python -> ld_impl_linux-64[version='>=2.34']
# pluggy==0.13.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64[version='>=2.34']
#
# Package zlib conflicts for:
# cryptography==2.8=py37h1ba5d50_0 -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# urllib3==1.25.8=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# xlrd==1.2.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# mock==4.0.1=py_0 -> python[version='>=3.6'] -> zlib[version='>=1.2.11,<1.3.0a0']
# tqdm==4.42.1=py_0 -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# traitlets==4.3.3=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# pyopenssl==19.1.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# contextlib2==0.6.0.post1=py_0 -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# heapdict==1.0.1=py_0 -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# setuptools==45.2.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# python=3.7 -> sqlite[version='>=3.30.1,<4.0a0'] -> zlib[version='>=1.2.12,<1.3.0a0']
# babel==2.8.0=py_0 -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# qtawesome==0.6.1=py_0 -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# ipython_genutils==0.2.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# tk==8.6.8=hbc83047_0 -> zlib[version='>=1.2.11,<1.3.0a0']
# backports.functools_lru_cache==1.6.1=py_0 -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# pycodestyle==2.5.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# pyqt==5.9.2=py37h05f1152_2 -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# jupyter==1.0.0=py37_7 -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# lxml==4.5.0=py37hefd8a0e_0 -> libxml2[version='>=2.9.9,<2.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# mccabe==0.6.1=py37_1 -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# pyzmq==18.1.1=py37he6710b0_0 -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# yapf==0.28.0=py_0 -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# pyxdg==0.26=py_0 -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# gevent==1.4.0=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# anaconda-project==0.8.4=py_0 -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# numba==0.48.0=py37h0573a6f_0 -> llvmlite[version='>=0.31.0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# pyflakes==2.1.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# openpyxl==3.0.3=py_0 -> python[version='>=3.6'] -> zlib[version='>=1.2.11,<1.3.0a0']
# sphinxcontrib-websupport==1.2.0=py_0 -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# pylint==2.4.4=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# pkginfo==1.5.0.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# conda-verify==3.4.2=py_1 -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# anaconda==2020.02=py37_0 -> zlib==1.2.11=h7b6447c_3
# alabaster==0.7.12=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# terminado==0.8.3=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# scipy==1.4.1=py37h0b6359f_0 -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# _ipyw_jlab_nb_ext_conf==0.1.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# scikit-learn==0.22.1=py37hd81dba3_0 -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# mamba -> libarchive[version='>=3.5.1,<3.6.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# sphinxcontrib-htmlhelp==1.0.2=py_0 -> python[version='>=3.5'] -> zlib[version='>=1.2.11,<1.3.0a0']
# locket==0.2.0=py37_1 -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# more-itertools==8.2.0=py_0 -> python[version='>=3.4'] -> zlib[version='>=1.2.11,<1.3.0a0']
# python==3.7.6=h0371630_2 -> zlib[version='>=1.2.11,<1.3.0a0']
# libnghttp2 -> zlib[version='>=1.2.11,<1.3.0a0']
# pyodbc==4.0.30=py37he6710b0_0 -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# markupsafe==1.1.1=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# mkl_random==1.1.0=py37hd6b4f25_0 -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# qtpy==1.9.0=py_0 -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# astropy==4.0=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# python-language-server==0.31.7=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# flask==1.1.1=py_0 -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# ipython==7.12.0=py37h5ca1d4c_0 -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# ...
# widgetsnbextension==3.5.1=py37_0 -> notebook[version='>=4.4.1'] -> ipython_genutils
# spyder==4.0.1=py37_0 -> qtconsole[version='>=4.6.0'] -> ipython_genutils
#
# Package yaml conflicts for:
# anaconda-navigator==1.9.12=py37_0 -> pyyaml[version='>=5.1'] -> yaml[version='>=0.1.7,<0.2.0a0']
# anaconda-client==1.7.2=py37_0 -> pyyaml -> yaml[version='>=0.1.7,<0.2.0a0']
# distributed==2.11.0=py37_0 -> pyyaml -> yaml[version='>=0.1.7,<0.2.0a0']
# conda-verify==3.4.2=py_1 -> pyyaml -> yaml[version='>=0.1.7,<0.2.0a0']
# yaml==0.1.7=had09818_2
# anaconda-project==0.8.4=py_0 -> ruamel_yaml -> yaml[version='>=0.1.7,<0.2.0a0|>=0.2.5,<0.3.0a0']
# pyyaml==5.3=py37h7b6447c_0 -> yaml[version='>=0.1.7,<0.2.0a0']
# conda-build==3.18.11=py37_0 -> pyyaml -> yaml[version='>=0.1.7,<0.2.0a0']
# conda==4.8.2=py37_0 -> ruamel_yaml[version='>=0.11.14,<0.16'] -> yaml[version='>=0.1.7,<0.2.0a0|>=0.2.5,<0.3.0a0']
# ruamel_yaml==0.15.87=py37h7b6447c_0 -> yaml[version='>=0.1.7,<0.2.0a0']
# anaconda==2020.02=py37_0 -> pyyaml==5.3=py37h7b6447c_0 -> yaml[version='>=0.1.7,<0.2.0a0']
# anaconda==2020.02=py37_0 -> yaml==0.1.7=had09818_2
# bokeh==1.4.0=py37_0 -> pyyaml[version='>=3.10'] -> yaml[version='>=0.1.7,<0.2.0a0']
# watchdog==0.10.2=py37_0 -> pyyaml[version='>=3.10'] -> yaml[version='>=0.1.7,<0.2.0a0']
#
# Package zict conflicts for:
# dask==2.11.0=py_0 -> distributed[version='>=2.11.0'] -> zict[version='>=0.1.3']
# distributed==2.11.0=py37_0 -> zict[version='>=0.1.3']
# zict==1.0.0=py_0
# anaconda==2020.02=py37_0 -> distributed==2.11.0=py37_0 -> zict[version='>=0.1.3']
# anaconda==2020.02=py37_0 -> zict==1.0.0=py_0
#
# Package pytest-arraydiff conflicts for:
# pytest-arraydiff==0.3=py37h39e3cac_0
# pytest-astropy==0.8.0=py_0 -> pytest-arraydiff[version='>=0.1']
# anaconda==2020.02=py37_0 -> pytest-astropy==0.8.0=py_0 -> pytest-arraydiff[version='>=0.1']
# astropy==4.0=py37h7b6447c_0 -> pytest-astropy -> pytest-arraydiff[version='>=0.1']
# anaconda==2020.02=py37_0 -> pytest-arraydiff==0.3=py37h39e3cac_0
#
# Package numexpr conflicts for:
# anaconda==2020.02=py37_0 -> numexpr==2.7.1=py37h423224d_0
# numexpr==2.7.1=py37h423224d_0
# pytables==3.6.1=py37h71ec239_0 -> numexpr
# anaconda==2020.02=py37_0 -> pytables==3.6.1=py37h71ec239_0 -> numexpr
#
# Package pandas conflicts for:
# seaborn==0.10.0=py_0 -> pandas[version='>=0.22.0']
# pandas==1.0.1=py37h0573a6f_0
# anaconda==2020.02=py37_0 -> pandas==1.0.1=py37h0573a6f_0
# anaconda==2020.02=py37_0 -> bkcharts==0.2=py37_0 -> pandas[version='>=0.21|>=0.22.0|>=0.23.0']
# dask==2.11.0=py_0 -> pandas[version='>=0.23.0']
# bkcharts==0.2=py37_0 -> pandas
# statsmodels==0.11.0=py37h7b6447c_0 -> pandas[version='>=0.21']
#
# Package imageio conflicts for:
# imageio==2.6.1=py37_0
# anaconda==2020.02=py37_0 -> scikit-image==0.16.2=py37h0573a6f_0 -> imageio[version='>=2.3.0']
# scikit-image==0.16.2=py37h0573a6f_0 -> imageio[version='>=2.3.0']
# anaconda==2020.02=py37_0 -> imageio==2.6.1=py37_0
#
# Package backports.functools_lru_cache conflicts for:
# backports.functools_lru_cache==1.6.1=py_0
# conda-verify==3.4.2=py_1 -> backports.functools_lru_cache
#
# Package networkx conflicts for:
# networkx==2.4=py_0
# anaconda==2020.02=py37_0 -> scikit-image==0.16.2=py37h0573a6f_0 -> networkx[version='>=2.0']
# scikit-image==0.16.2=py37h0573a6f_0 -> networkx[version='>=2.0']
# anaconda==2020.02=py37_0 -> networkx==2.4=py_0
#
# Package xmltodict conflicts for:
# anaconda-navigator==1.9.12=py37_0 -> xmltodict
# xmltodict==0.12.0=py_0
#
# Package backports conflicts for:
# backports.functools_lru_cache==1.6.1=py_0 -> backports
# get_terminal_size==1.0.0=haa9412d_0 -> backports.shutil_get_terminal_size -> backports
# backports.shutil_get_terminal_size==1.0.0=py37_2 -> backports
# backports.tempfile==1.0=py_1 -> backports
# backports.weakref==1.0.post1=py_1 -> backports
# anaconda==2020.02=py37_0 -> backports==1.0=py_2
# backports==1.0=py_2
# conda-verify==3.4.2=py_1 -> backports.functools_lru_cache -> backports
# anaconda==2020.02=py37_0 -> backports.shutil_get_terminal_size==1.0.0=py37_2 -> backports
#
# Package lz4-c conflicts for:
# libarchive==3.3.3=h5d8350f_5 -> lz4-c[version='>=1.8.1.2,<1.9.0a0']
# python-libarchive-c==2.8=py37_13 -> libarchive -> lz4-c[version='>=1.8.1.2,<1.9.0a0|>=1.9.3,<1.9.4.0a0']
# lz4-c==1.8.1.2=h14c3975_0
# mamba -> libarchive[version='>=3.5.1,<3.6.0a0'] -> lz4-c[version='>=1.9.3,<1.9.4.0a0']
# anaconda==2020.02=py37_0 -> lz4-c==1.8.1.2=h14c3975_0
# anaconda==2020.02=py37_0 -> blosc==1.16.3=hd408876_0 -> lz4-c[version='>=1.8.1.2,<1.9.0a0']
# pytables==3.6.1=py37h71ec239_0 -> blosc[version='>=1.16.3,<2.0a0'] -> lz4-c[version='>=1.8.1.2,<1.9.0a0']
# blosc==1.16.3=hd408876_0 -> lz4-c[version='>=1.8.1.2,<1.9.0a0']
#
# Package filelock conflicts for:
# conda-build==3.18.11=py37_0 -> filelock
# anaconda==2020.02=py37_0 -> filelock==3.0.12=py_0
# filelock==3.0.12=py_0
#
# Package sphinxcontrib-websupport conflicts for:
# anaconda==2020.02=py37_0 -> sphinxcontrib-websupport==1.2.0=py_0
# sphinxcontrib-websupport==1.2.0=py_0
#
# Package sphinxcontrib-htmlhelp conflicts for:
# sphinx==2.4.0=py_0 -> sphinxcontrib-htmlhelp
# spyder==4.0.1=py37_0 -> sphinx -> sphinxcontrib-htmlhelp
# numpydoc==0.9.2=py_0 -> sphinx -> sphinxcontrib-htmlhelp
# anaconda==2020.02=py37_0 -> sphinxcontrib-htmlhelp==1.0.2=py_0
# anaconda==2020.02=py37_0 -> sphinx==2.4.0=py_0 -> sphinxcontrib-htmlhelp
# sphinxcontrib-htmlhelp==1.0.2=py_0
#
# Package tbb conflicts for:
# anaconda==2020.02=py37_0 -> tbb==2020.0=hfd86e86_0
# anaconda==2020.02=py37_0 -> numba==0.48.0=py37h0573a6f_0 -> tbb[version='>=2019.8']
# tbb==2020.0=hfd86e86_0
# numba==0.48.0=py37h0573a6f_0 -> tbb[version='>=2019.8']
#
# Package jbig conflicts for:
# anaconda==2020.02=py37_0 -> jbig==2.1=hdba287a_0
# jbig==2.1=hdba287a_0
#
# Package libnghttp2 conflicts for:
# pycurl==7.43.0.5=py37h1ba5d50_0 -> libcurl[version='>=7.67.0,<8.0a0'] -> libnghttp2[version='>=1.43.0,<2.0a0']
# libnghttp2
# mamba -> libcurl[version='>=7.75.0,<8.0a0'] -> libnghttp2[version='>=1.43.0,<2.0a0']
#
# Package numba conflicts for:
# anaconda==2020.02=py37_0 -> numba==0.48.0=py37h0573a6f_0
# numba==0.48.0=py37h0573a6f_0
#
# Package pickleshare conflicts for:
# ipywidgets==7.5.1=py_0 -> ipython[version='>=4.0.0'] -> pickleshare
# pickleshare==0.7.5=py37_0
# ipykernel==5.1.4=py37h39e3cac_0 -> ipython[version='>=5.0'] -> pickleshare
# anaconda==2020.02=py37_0 -> ipython==7.12.0=py37h5ca1d4c_0 -> pickleshare
# ipython==7.12.0=py37h5ca1d4c_0 -> pickleshare
# anaconda==2020.02=py37_0 -> pickleshare==0.7.5=py37_0
# spyder==4.0.1=py37_0 -> pickleshare
# jupyter_console==6.1.0=py_0 -> ipython -> pickleshare
#
# Package qtpy conflicts for:
# spyder==4.0.1=py37_0 -> qtawesome[version='>=0.5.7'] -> qtpy
# qtawesome==0.6.1=py_0 -> qtpy
# anaconda==2020.02=py37_0 -> qtawesome==0.6.1=py_0 -> qtpy[version='>=1.5.0']
# anaconda==2020.02=py37_0 -> qtpy==1.9.0=py_0
# qtpy==1.9.0=py_0
# spyder==4.0.1=py37_0 -> qtpy[version='>=1.5.0']
# navigator-updater==0.2.1=py37_0 -> qtpy[version='>=1.2']
# anaconda-navigator==1.9.12=py37_0 -> qtpy[version='>=1.4.1']
#
# Package boto conflicts for:
# boto==2.49.0=py37_0
# anaconda==2020.02=py37_0 -> boto==2.49.0=py37_0
#
# Package backports.shutil_get_terminal_size conflicts for:
# anaconda==2020.02=py37_0 -> backports.shutil_get_terminal_size==1.0.0=py37_2
# anaconda==2020.02=py37_0 -> get_terminal_size==1.0.0=haa9412d_0 -> backports.shutil_get_terminal_size
# backports.shutil_get_terminal_size==1.0.0=py37_2
# get_terminal_size==1.0.0=haa9412d_0 -> backports.shutil_get_terminal_size
#
# Package astropy conflicts for:
# anaconda==2020.02=py37_0 -> astropy==4.0=py37h7b6447c_0
# astropy==4.0=py37h7b6447c_0
#
# Package liblief conflicts for:
# conda-build==3.18.11=py37_0 -> py-lief -> liblief==0.9.0=h7725739_2
# liblief==0.9.0=h7725739_2
# py-lief==0.9.0=py37h7725739_2 -> liblief==0.9.0=h7725739_2
# anaconda==2020.02=py37_0 -> liblief==0.9.0=h7725739_2
#
# Package docutils conflicts for:
# spyder==4.0.1=py37_0 -> sphinx -> docutils[version='>=0.12']
# anaconda==2020.02=py37_0 -> sphinx==2.4.0=py_0 -> docutils[version='>=0.12']
# numpydoc==0.9.2=py_0 -> sphinx -> docutils[version='>=0.12']
# docutils==0.16=py37_0
# anaconda==2020.02=py37_0 -> docutils==0.16=py37_0
# sphinx==2.4.0=py_0 -> docutils[version='>=0.12']
#
# Package ripgrep conflicts for:
# ripgrep==11.0.2=he32d670_0
# anaconda==2020.02=py37_0 -> ripgrep==11.0.2=he32d670_0
# conda-build==3.18.11=py37_0 -> ripgrep
#
# Package atomicwrites conflicts for:
# anaconda==2020.02=py37_0 -> atomicwrites==1.3.0=py37_1
# anaconda==2020.02=py37_0 -> spyder==4.0.1=py37_0 -> atomicwrites
# spyder==4.0.1=py37_0 -> atomicwrites
# atomicwrites==1.3.0=py37_1
#
# Package testpath conflicts for:
# testpath==0.4.4=py_0
# notebook==6.0.3=py37_0 -> nbconvert -> testpath
# anaconda==2020.02=py37_0 -> testpath==0.4.4=py_0
# spyder==4.0.1=py37_0 -> nbconvert -> testpath
# nbconvert==5.6.1=py37_0 -> testpath
# anaconda==2020.02=py37_0 -> nbconvert==5.6.1=py37_0 -> testpath
# jupyter==1.0.0=py37_7 -> nbconvert -> testpath
#
# Package patchelf conflicts for:
# anaconda==2020.02=py37_0 -> patchelf==0.10=he6710b0_0
# conda-build==3.18.11=py37_0 -> patchelf
# patchelf==0.10=he6710b0_0
#
# Package mccabe conflicts for:
# anaconda==2020.02=py37_0 -> flake8==3.7.9=py37_0 -> mccabe[version='>=0.6,<0.7|>=0.6.0,<0.7.0']
# mccabe==0.6.1=py37_1
# flake8==3.7.9=py37_0 -> mccabe[version='>=0.6.0,<0.7.0']
# anaconda==2020.02=py37_0 -> mccabe==0.6.1=py37_1
# python-language-server==0.31.7=py37_0 -> mccabe
# spyder==4.0.1=py37_0 -> pylint -> mccabe[version='>=0.6,<0.7']
# pylint==2.4.4=py37_0 -> mccabe[version='>=0.6,<0.7']
# python-language-server==0.31.7=py37_0 -> flake8 -> mccabe[version='>=0.6,<0.7|>=0.6.0,<0.7.0']
#
# Package mock conflicts for:
# pytables==3.6.1=py37h71ec239_0 -> mock
# mock==4.0.1=py_0
# anaconda==2020.02=py37_0 -> mock==4.0.1=py_0
# anaconda==2020.02=py37_0 -> pytables==3.6.1=py37h71ec239_0 -> mock
#
# Package bokeh conflicts for:
# bokeh==1.4.0=py37_0
# anaconda==2020.02=py37_0 -> bokeh==1.4.0=py37_0
# anaconda==2020.02=py37_0 -> dask==2.11.0=py_0 -> bokeh[version='>=1.0.0']
# dask==2.11.0=py_0 -> bokeh[version='>=1.0.0']
#
# Package jupyter conflicts for:
# jupyter==1.0.0=py37_7
# anaconda==2020.02=py37_0 -> jupyter==1.0.0=py37_7
#
# Package qtconsole conflicts for:
# anaconda==2020.02=py37_0 -> qtconsole==4.6.0=py_1
# spyder==4.0.1=py37_0 -> qtconsole[version='>=4.6.0']
# anaconda==2020.02=py37_0 -> jupyter==1.0.0=py37_7 -> qtconsole[version='>=4.6.0']
# jupyter==1.0.0=py37_7 -> qtconsole
# qtconsole==4.6.0=py_1
#
# Package fontconfig conflicts for:
# harfbuzz==1.8.8=hffaf4a1_0 -> cairo[version='>=1.14.12,<2.0a0'] -> fontconfig[version='>=2.13.0,<3.0a0']
# anaconda==2020.02=py37_0 -> cairo==1.14.12=h8948797_3 -> fontconfig[version='>=2.13.0,<3.0a0']
# qt==5.9.7=h5867ecd_1 -> fontconfig[version='>=2.13.0,<3.0a0']
# anaconda==2020.02=py37_0 -> fontconfig==2.13.0=h9420a91_0
# pango==1.42.4=h049681c_0 -> fontconfig[version='>=2.13.0,<3.0a0']
# cairo==1.14.12=h8948797_3 -> fontconfig[version='>=2.13.0,<3.0a0']
# fontconfig==2.13.0=h9420a91_0
# pyqt==5.9.2=py37h05f1152_2 -> qt=5.9 -> fontconfig[version='>=2.13.0,<3.0a0']
#
# Package pathlib2 conflicts for:
# anaconda==2020.02=py37_0 -> pathlib2==2.3.5=py37_0
# pathlib2==2.3.5=py37_0
#
# Package simplegeneric conflicts for:
# simplegeneric==0.8.1=py37_2
# anaconda==2020.02=py37_0 -> simplegeneric==0.8.1=py37_2
#
# Package xlrd conflicts for:
# xlrd==1.2.0=py37_0
# anaconda==2020.02=py37_0 -> xlrd==1.2.0=py37_0
#
# Package scikit-learn conflicts for:
# scikit-learn==0.22.1=py37hd81dba3_0
# anaconda==2020.02=py37_0 -> scikit-learn==0.22.1=py37hd81dba3_0
#
# Package libtool conflicts for:
# libtool==2.4.6=h7b6447c_5
# anaconda==2020.02=py37_0 -> libtool==2.4.6=h7b6447c_5
#
# Package blosc conflicts for:
# pytables==3.6.1=py37h71ec239_0 -> blosc[version='>=1.16.3,<2.0a0']
# anaconda==2020.02=py37_0 -> pytables==3.6.1=py37h71ec239_0 -> blosc[version='>=1.16.3,<2.0a0']
# blosc==1.16.3=hd408876_0
# anaconda==2020.02=py37_0 -> blosc==1.16.3=hd408876_0
#
# Package nltk conflicts for:
# nltk==3.4.5=py37_0
# anaconda==2020.02=py37_0 -> nltk==3.4.5=py37_0
#
# Package backports.weakref conflicts for:
# backports.weakref==1.0.post1=py_1
# conda-verify==3.4.2=py_1 -> backports.tempfile -> backports.weakref
# backports.tempfile==1.0=py_1 -> backports.weakref
#
# Package conda conflicts for:
# conda==4.8.2=py37_0
# mamba -> conda[version='>=4.8']
# conda-build==3.18.11=py37_0 -> conda[version='>=4.5']
#
# Package fribidi conflicts for:
# fribidi==1.0.5=h7b6447c_0
# anaconda==2020.02=py37_0 -> fribidi==1.0.5=h7b6447c_0
# pango==1.42.4=h049681c_0 -> fribidi[version='>=1.0.4,<2.0a0']
# anaconda==2020.02=py37_0 -> pango==1.42.4=h049681c_0 -> fribidi[version='>=1.0.4,<2.0a0']
#
# Package colorama conflicts for:
# colorama==0.4.3=py_0
# anaconda==2020.02=py37_0 -> colorama==0.4.3=py_0
#
# Package pycrypto conflicts for:
# anaconda==2020.02=py37_0 -> pycrypto==2.6.1=py37h14c3975_9
# pycrypto==2.6.1=py37h14c3975_9
#
# Package jdcal conflicts for:
# openpyxl==3.0.3=py_0 -> jdcal
# anaconda==2020.02=py37_0 -> openpyxl==3.0.3=py_0 -> jdcal
# anaconda==2020.02=py37_0 -> jdcal==1.4.1=py_0
# jdcal==1.4.1=py_0
#
# Package pango conflicts for:
# anaconda==2020.02=py37_0 -> pango==1.42.4=h049681c_0
# pango==1.42.4=h049681c_0
#
# Package pycurl conflicts for:
# pycurl==7.43.0.5=py37h1ba5d50_0
# anaconda==2020.02=py37_0 -> pycurl==7.43.0.5=py37h1ba5d50_0
#
# Package graphite2 conflicts for:
# graphite2==1.3.13=h23475e2_0
# anaconda==2020.02=py37_0 -> graphite2==1.3.13=h23475e2_0
# harfbuzz==1.8.8=hffaf4a1_0 -> graphite2[version='>=1.3.11,<2.0a0']
# anaconda==2020.02=py37_0 -> harfbuzz==1.8.8=hffaf4a1_0 -> graphite2[version='>=1.3.11,<2.0a0|>=1.3.12,<2.0a0']
# pango==1.42.4=h049681c_0 -> harfbuzz[version='>=1.7.6,<2.0a0'] -> graphite2[version='>=1.3.11,<2.0a0']
# pango==1.42.4=h049681c_0 -> graphite2[version='>=1.3.12,<2.0a0']
#
# Package flask conflicts for:
# anaconda==2020.02=py37_0 -> flask==1.1.1=py_0
# flask==1.1.1=py_0
#
# Package conda-package-handling conflicts for:
# conda-package-handling==1.6.0=py37h7b6447c_0
# conda-verify==3.4.2=py_1 -> conda-package-handling[version='>=1.0.4']
# conda==4.8.2=py37_0 -> conda-package-handling[version='>=1.3.0']
# conda-build==3.18.11=py37_0 -> conda[version='>=4.5'] -> conda-package-handling[version='>=1.3.0']
# mamba -> conda[version='>=4.8'] -> conda-package-handling[version='>=1.3.0']
# conda-build==3.18.11=py37_0 -> conda-package-handling[version='>=1.3']
#
# Package multipledispatch conflicts for:
# anaconda==2020.02=py37_0 -> multipledispatch==0.6.0=py37_0
# multipledispatch==0.6.0=py37_0
#
# Package contextlib2 conflicts for:
# contextlib2==0.6.0.post1=py_0
# anaconda==2020.02=py37_0 -> contextlib2==0.6.0.post1=py_0
#
# Package hypothesis conflicts for:
# hypothesis==5.5.4=py_0
# anaconda==2020.02=py37_0 -> hypothesis==5.5.4=py_0
# pytest-astropy==0.8.0=py_0 -> hypothesis
# astropy==4.0=py37h7b6447c_0 -> pytest-astropy -> hypothesis
# anaconda==2020.02=py37_0 -> pytest-astropy==0.8.0=py_0 -> hypothesis
#
# Package xlsxwriter conflicts for:
# xlsxwriter==1.2.7=py_0
# anaconda==2020.02=py37_0 -> xlsxwriter==1.2.7=py_0
#
# Package pytables conflicts for:
# pytables==3.6.1=py37h71ec239_0
# anaconda==2020.02=py37_0 -> pytables==3.6.1=py37h71ec239_0
#
# Package python-libarchive-c conflicts for:
# anaconda==2020.02=py37_0 -> python-libarchive-c==2.8=py37_13
# conda-build==3.18.11=py37_0 -> python-libarchive-c
# python-libarchive-c==2.8=py37_13
#
# Package sqlalchemy conflicts for:
# anaconda==2020.02=py37_0 -> sqlalchemy==1.3.13=py37h7b6447c_0
# sqlalchemy==1.3.13=py37h7b6447c_0
#
# Package pyodbc conflicts for:
# anaconda==2020.02=py37_0 -> pyodbc==4.0.30=py37he6710b0_0
# pyodbc==4.0.30=py37he6710b0_0
#
# Package libev conflicts for:
# libev
# libnghttp2 -> libev[version='>=4.11|>=4.33,<4.34.0a0']
#
# Package pkginfo conflicts for:
# anaconda==2020.02=py37_0 -> pkginfo==1.5.0.1=py37_0
# pkginfo==1.5.0.1=py37_0
# conda-build==3.18.11=py37_0 -> pkginfo
#
# Package statsmodels conflicts for:
# statsmodels==0.11.0=py37h7b6447c_0
# anaconda==2020.02=py37_0 -> statsmodels==0.11.0=py37h7b6447c_0
#
# Package bottleneck conflicts for:
# anaconda==2020.02=py37_0 -> bottleneck==1.3.2=py37heb32a55_0
# bottleneck==1.3.2=py37heb32a55_0
#
# Package curl conflicts for:
# anaconda==2020.02=py37_0 -> curl==7.68.0=hbc83047_0
# curl==7.68.0=hbc83047_0
#
# Package openpyxl conflicts for:
# anaconda==2020.02=py37_0 -> openpyxl==3.0.3=py_0
# openpyxl==3.0.3=py_0
#
# Package dask conflicts for:
# anaconda==2020.02=py37_0 -> dask==2.11.0=py_0
# dask==2.11.0=py_0

# %% [markdown]
# Any package that you install with Conda will be installed into the directory /usr/local/lib/python3.7/site-packages so you will need to add this directory to sys.path in order for these packages to be available for import.

# %%
# new code
import sys
sys.path.insert(0, "/usr/local/lib/python3.7/site-packages/")

# %% [markdown]
# Now that you have installed Conda you need to update Conda and all its dependencies to their most recent versions and update Python to 3.7. The conda update command then updates all of Conda’s dependencies to their most recent versions

# %%
# new code
# !conda install -yq python=3.7
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.

# %% [markdown]
# #### NCO
#
# NetCDF Operators (NCO) is a requirement and must be installed for utilization of this package. Instructions for installation on various platforms is available [here](http://nco.sourceforge.net/#Executables//) and other information related to NCO command can be found at the link: http://nco.sourceforge.net/nco.html. If using an Anaconda environment as advised above then it’s as simple as running the following command within the activated conda environment:

# %%
# !conda install -c conda-forge nco
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - nco
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     c-ares-1.18.1              |       h7f98852_0         113 KB  conda-forge
#     cudatoolkit-11.1.1         |      ha002fc5_10        1.20 GB  conda-forge
#     curl-7.83.1                |       h7bff187_0          89 KB  conda-forge
#     esmf-8.2.0                 | nompi_h61edca3_0        27.4 MB  conda-forge
#     expat-2.4.8                |       h27087fc_0         187 KB  conda-forge
#     gsl-2.7                    |       he838d99_0         3.2 MB  conda-forge
#     hdf4-4.2.15                |       h10796ff_3         950 KB  conda-forge
#     hdf5-1.12.1                |nompi_h2386368_104         3.5 MB  conda-forge
#     jpeg-9e                    |       h166bdaf_2         269 KB  conda-forge
#     keyutils-1.6.1             |       h166bdaf_0         115 KB  conda-forge
#     krb5-1.19.3                |       h3790be6_0         1.4 MB  conda-forge
#     libblas-3.9.0              |15_linux64_openblas          12 KB  conda-forge
#     libcblas-3.9.0             |15_linux64_openblas          12 KB  conda-forge
#     libcurl-7.83.1             |       h7bff187_0         342 KB  conda-forge
#     libgfortran-ng-12.1.0      |      h69a702a_16          23 KB  conda-forge
#     libgfortran5-12.1.0        |      hdcd56e2_16         1.8 MB  conda-forge
#     liblapack-3.9.0            |15_linux64_openblas          12 KB  conda-forge
#     libnetcdf-4.8.1            |nompi_h329d8a1_102         1.5 MB  conda-forge
#     libnghttp2-1.47.0          |       h727a467_0         808 KB  conda-forge
#     libopenblas-0.3.20         |pthreads_h78a6416_0        10.1 MB  conda-forge
#     libssh2-1.10.0             |       ha56f1ee_2         233 KB  conda-forge
#     libzip-1.9.2               |       hc869a4a_0          97 KB  conda-forge
#     nco-5.1.0                  |       hdef2bbc_0         2.2 MB  conda-forge
#     netcdf-fortran-4.5.4       |nompi_h2b6e579_100         1.3 MB  conda-forge
#     tempest-remap-2.1.1        |       hfda0864_0         1.3 MB  conda-forge
#     udunits2-2.2.28            |       hc3e0081_0         161 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        1.26 GB
#
# The following NEW packages will be INSTALLED:
#
#   cudatoolkit        conda-forge/linux-64::cudatoolkit-11.1.1-ha002fc5_10
#   curl               conda-forge/linux-64::curl-7.83.1-h7bff187_0
#   esmf               conda-forge/linux-64::esmf-8.2.0-nompi_h61edca3_0
#   expat              conda-forge/linux-64::expat-2.4.8-h27087fc_0
#   gsl                conda-forge/linux-64::gsl-2.7-he838d99_0
#   hdf4               conda-forge/linux-64::hdf4-4.2.15-h10796ff_3
#   hdf5               conda-forge/linux-64::hdf5-1.12.1-nompi_h2386368_104
#   jpeg               conda-forge/linux-64::jpeg-9e-h166bdaf_2
#   keyutils           conda-forge/linux-64::keyutils-1.6.1-h166bdaf_0
#   libblas            conda-forge/linux-64::libblas-3.9.0-15_linux64_openblas
#   libcblas           conda-forge/linux-64::libcblas-3.9.0-15_linux64_openblas
#   libgfortran-ng     conda-forge/linux-64::libgfortran-ng-12.1.0-h69a702a_16
#   libgfortran5       conda-forge/linux-64::libgfortran5-12.1.0-hdcd56e2_16
#   liblapack          conda-forge/linux-64::liblapack-3.9.0-15_linux64_openblas
#   libnetcdf          conda-forge/linux-64::libnetcdf-4.8.1-nompi_h329d8a1_102
#   libopenblas        conda-forge/linux-64::libopenblas-0.3.20-pthreads_h78a6416_0
#   libzip             conda-forge/linux-64::libzip-1.9.2-hc869a4a_0
#   nco                conda-forge/linux-64::nco-5.1.0-hdef2bbc_0
#   netcdf-fortran     conda-forge/linux-64::netcdf-fortran-4.5.4-nompi_h2b6e579_100
#   tempest-remap      conda-forge/linux-64::tempest-remap-2.1.1-hfda0864_0
#   udunits2           conda-forge/linux-64::udunits2-2.2.28-hc3e0081_0
#
# The following packages will be UPDATED:
#
#   c-ares                                  1.17.1-h7f98852_1 --> 1.18.1-h7f98852_0
#   krb5                                    1.17.2-h926e7f8_0 --> 1.19.3-h3790be6_0
#   libcurl                                 7.75.0-hc4aaa36_0 --> 7.83.1-h7bff187_0
#   libnghttp2                              1.43.0-h812cca2_0 --> 1.47.0-h727a467_0
#   libssh2                                  1.9.0-ha56f1ee_6 --> 1.10.0-ha56f1ee_2
#
#
#
# Downloading and Extracting Packages
# c-ares-1.18.1        | 113 KB    | : 100% 1.0/1 [00:00<00:00,  5.29it/s]
# libzip-1.9.2         | 97 KB     | : 100% 1.0/1 [00:00<00:00, 11.96it/s]
# libnetcdf-4.8.1      | 1.5 MB    | : 100% 1.0/1 [00:00<00:00,  2.63it/s]
# keyutils-1.6.1       | 115 KB    | : 100% 1.0/1 [00:00<00:00, 14.72it/s]
# krb5-1.19.3          | 1.4 MB    | : 100% 1.0/1 [00:00<00:00,  2.66it/s]
# esmf-8.2.0           | 27.4 MB   | : 100% 1.0/1 [00:06<00:00,  6.88s/it]
# libgfortran5-12.1.0  | 1.8 MB    | : 100% 1.0/1 [00:00<00:00,  2.18it/s]
# hdf4-4.2.15          | 950 KB    | : 100% 1.0/1 [00:00<00:00,  3.43it/s]
# libcurl-7.83.1       | 342 KB    | : 100% 1.0/1 [00:00<00:00,  9.95it/s]
# libopenblas-0.3.20   | 10.1 MB   | : 100% 1.0/1 [00:02<00:00,  2.39s/it]
# nco-5.1.0            | 2.2 MB    | : 100% 1.0/1 [00:00<00:00,  1.29it/s]
# libssh2-1.10.0       | 233 KB    | : 100% 1.0/1 [00:00<00:00,  9.25it/s]
# liblapack-3.9.0      | 12 KB     | : 100% 1.0/1 [00:00<00:00, 23.93it/s]
# netcdf-fortran-4.5.4 | 1.3 MB    | : 100% 1.0/1 [00:00<00:00,  3.25it/s]
# tempest-remap-2.1.1  | 1.3 MB    | : 100% 1.0/1 [00:00<00:00,  2.07it/s]
# cudatoolkit-11.1.1   | 1.20 GB   | : 100% 1.0/1 [04:00<00:00, 240.13s/it]
# libgfortran-ng-12.1. | 23 KB     | : 100% 1.0/1 [00:00<00:00, 17.46it/s]
# hdf5-1.12.1          | 3.5 MB    | : 100% 1.0/1 [00:00<00:00,  1.33it/s]
# curl-7.83.1          | 89 KB     | : 100% 1.0/1 [00:00<00:00, 17.11it/s]
# expat-2.4.8          | 187 KB    | : 100% 1.0/1 [00:00<00:00, 12.19it/s]
# libcblas-3.9.0       | 12 KB     | : 100% 1.0/1 [00:00<00:00, 20.57it/s]
# libnghttp2-1.47.0    | 808 KB    | : 100% 1.0/1 [00:00<00:00,  4.53it/s]
# jpeg-9e              | 269 KB    | : 100% 1.0/1 [00:00<00:00,  9.70it/s]
# gsl-2.7              | 3.2 MB    | : 100% 1.0/1 [00:00<00:00,  1.12it/s]
# libblas-3.9.0        | 12 KB     | : 100% 1.0/1 [00:00<00:00, 23.81it/s]
# udunits2-2.2.28      | 161 KB    | : 100% 1.0/1 [00:00<00:00,  8.79it/s]
# done
# done
# | By downloading and using the CUDA Toolkit conda packages, you accept the terms and conditions of the CUDA End User License Agreement (EULA): https://docs.nvidia.com/cuda/eula/index.html
#
# done

# %% [markdown]
# #### Climate-indices package
# Install ```climate-indices``` package. Once the environment has been activated then subsequent Python commands will run in this environment where the package dependencies for this project are present. Now the package can be added to the environment along with all required modules (dependencies) via [pip](https://pip.pypa.io/en/stable/):

# %%
# !pip install climate-indices
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting climate-indices
#   Downloading climate_indices-1.0.10-py3-none-any.whl (71 kB)
#      |████████████████████████████████| 71 kB 118 kB/s
# Collecting numpy
#   Downloading numpy-1.21.6-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
#      |████████████████████████████████| 15.7 MB 147 kB/s
# Collecting scipy
#   Downloading scipy-1.7.3-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (38.1 MB)
#      |████████████████████████████████| 38.1 MB 1.2 MB/s
# Collecting toolz
#   Downloading toolz-0.12.0-py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 3.6 MB/s
# Collecting netcdf4
#   Downloading netCDF4-1.6.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.1 MB)
#      |████████████████████████████████| 5.1 MB 38.9 MB/s
# Collecting dask
#   Downloading dask-2022.2.0-py3-none-any.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 56.4 MB/s
# Collecting numba
#   Downloading numba-0.55.2-cp37-cp37m-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 39.7 MB/s
# Collecting nco
#   Downloading nco-1.0.0-py2.py3-none-any.whl (10 kB)
# Collecting xarray
#   Downloading xarray-0.20.2-py3-none-any.whl (845 kB)
#      |████████████████████████████████| 845 kB 46.1 MB/s
# Collecting partd>=0.3.10
#   Downloading partd-1.2.0-py3-none-any.whl (19 kB)
# Collecting packaging>=20.0
#   Downloading packaging-21.3-py3-none-any.whl (40 kB)
#      |████████████████████████████████| 40 kB 4.8 MB/s
# Collecting pyyaml>=5.3.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 56.1 MB/s
# Collecting cloudpickle>=1.1.1
#   Downloading cloudpickle-2.1.0-py3-none-any.whl (25 kB)
# Collecting fsspec>=0.6.0
#   Downloading fsspec-2022.5.0-py3-none-any.whl (140 kB)
#      |████████████████████████████████| 140 kB 58.5 MB/s
# Collecting pyparsing!=3.0.5,>=2.0.2
#   Downloading pyparsing-3.0.9-py3-none-any.whl (98 kB)
#      |████████████████████████████████| 98 kB 7.1 MB/s
# Collecting locket
#   Downloading locket-1.0.0-py2.py3-none-any.whl (4.4 kB)
# Collecting cftime
#   Downloading cftime-1.6.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (231 kB)
#      |████████████████████████████████| 231 kB 49.6 MB/s
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/site-packages (from numba->climate-indices) (49.6.0.post20210108)
# Collecting llvmlite<0.39,>=0.38.0rc1
#   Downloading llvmlite-0.38.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.5 MB)
#      |████████████████████████████████| 34.5 MB 1.2 kB/s
# Collecting pandas>=1.1
#   Downloading pandas-1.3.5-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.3 MB)
#      |████████████████████████████████| 11.3 MB 45.9 MB/s
# Collecting typing-extensions>=3.7
#   Downloading typing_extensions-4.3.0-py3-none-any.whl (25 kB)
# Collecting importlib-metadata
#   Downloading importlib_metadata-4.12.0-py3-none-any.whl (21 kB)
# Collecting python-dateutil>=2.7.3
#   Downloading python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
#      |████████████████████████████████| 247 kB 54.3 MB/s
# Collecting pytz>=2017.3
#   Downloading pytz-2022.1-py2.py3-none-any.whl (503 kB)
#      |████████████████████████████████| 503 kB 50.7 MB/s
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas>=1.1->xarray->climate-indices) (1.15.0)
# Collecting zipp>=0.5
#   Downloading zipp-3.8.1-py3-none-any.whl (5.6 kB)
# Installing collected packages: zipp, typing-extensions, toolz, pytz, python-dateutil, pyparsing, numpy, locket, pyyaml, partd, pandas, packaging, llvmlite, importlib-metadata, fsspec, cloudpickle, cftime, xarray, scipy, numba, netcdf4, nco, dask, climate-indices
# Successfully installed cftime-1.6.1 climate-indices-1.0.10 cloudpickle-2.1.0 dask-2022.2.0 fsspec-2022.5.0 importlib-metadata-4.12.0 llvmlite-0.38.1 locket-1.0.0 nco-1.0.0 netcdf4-1.6.0 numba-0.55.2 numpy-1.21.6 packaging-21.3 pandas-1.3.5 partd-1.2.0 pyparsing-3.0.9 python-dateutil-2.8.2 pytz-2022.1 pyyaml-6.0 scipy-1.7.3 toolz-0.12.0 typing-extensions-4.3.0 xarray-0.20.2 zipp-3.8.1

# %% [markdown]
# ### 3.4. Preprocess data using NCO

# %% [markdown]
# 1. The original downloaded files from GPM IMERG is in mm/day, while to calculate monthly SPI the data must be in mm/month, we need to do a conversion process using  ```ncrcat``` to concatenate the data of the same month and year.
#
# 2. ```ncap2``` (arithmetic operator for NetCDF files) is then used to sum the concatenated data.

# %%
# %cd /content/drive/MyDrive/IWMI/IMERG_DailyData
# Out:
# /content/drive/MyDrive/IWMI/IMERG_DailyData

# %%
# !ncrcat /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.202201*.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_concat/3B-DAY-L.MS.MRG.3IMERG.20220101-S000000-E235959.V06.nc4.SUB.nc4

# %%
# !ncra -h -O -y ttl  /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_concat/3B-DAY-L.MS.MRG.3IMERG.20220101-S000000-E235959.V06.nc4.SUB.nc4  /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_month/3B-DAY-L.MS.MRG.3IMERG.20220101-S000000-E235959.V06.nc4.SUB.nc4

# %%
# !ncdump -h /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_month//3B-DAY-L.MS.MRG.3IMERG.20020101-S000000-E235959.V06.nc4.SUB.nc4
# Out:
# netcdf \3B-DAY-L.MS.MRG.3IMERG.20020101-S000000-E235959.V06.nc4.SUB {
# dimensions:
# 	time = UNLIMITED ; // (1 currently)
# 	bnds = 2 ;
# 	lon = 119 ;
# 	lat = 102 ;
# variables:
# 	double time(time) ;
# 		time:standard_name = "time" ;
# 		time:bounds = "time_bnds" ;
# 		time:units = "days since 1970-01-01 00:00:00Z" ;
# 		time:calendar = "standard" ;
# 		time:axis = "T" ;
# 		time:cell_methods = "time: mean" ;
# 	double time_bnds(time, bnds) ;
# 		time_bnds:cell_methods = "time: mean" ;
# 	float lon(lon) ;
# 		lon:standard_name = "longitude" ;
# 		lon:long_name = "Longitude" ;
# 		lon:units = "degrees_east" ;
# 		lon:axis = "X" ;
# 	float lat(lat) ;
# 		lat:standard_name = "latitude" ;
# 		lat:long_name = "Latitude" ;
# 		lat:units = "degrees_north" ;
# 		lat:axis = "Y" ;
# 	float precipitationCal(time, lon, lat) ;
# 		precipitationCal:long_name = "Daily accumulated precipitation (combined microwave-IR) estimate" ;
# 		precipitationCal:units = "mm" ;
# 		precipitationCal:_FillValue = -9999.9f ;
# 		precipitationCal:missing_value = -9999.9f ;
# 		precipitationCal:cell_methods = "time: mean time: sum" ;
#
# // global attributes:
# 		:CDI = "Climate Data Interface version 1.9.8 (https://mpimet.mpg.de/cdi)" ;
# 		:Conventions = "CF-1.6" ;
# 		:BeginDate = "2002-01-01" ;
# 		:BeginTime = "00:00:00.000Z" ;
# 		:EndDate = "2002-01-01" ;
# 		:EndTime = "23:59:59.999Z" ;
# 		:FileHeader = "StartGranuleDateTime=2002-01-01T00:00:00.000Z;\nStopGranuleDateTime=2002-01-01T23:59:59.999Z" ;
# 		:InputPointer = "3B-HHR-L.MS.MRG.3IMERG.20020101-S000000-E002959.0000.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20020101-S003000-E005959.0030.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20020101-S010000-E012959.0060.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20020101-S013000-E015959.0090.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20020101-S020000-E022959.0120.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20020101-S023000-E025959.0150.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20020101-S030000-E032959.0180.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20020101-S033000-E035959.0210.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20020101-S040000-E042959.0240.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20020101-S043000-E045959.0270.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20020101-S050000-E052959.0300.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20020101-S053000-E055959.0330.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20020101-S060000-E062959.0360.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20020101-S063000-E065959.0390.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20020101-S070000-E072959.0420.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20020101-S073000-E075959.0450.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20020101-S080000-E082959.0480.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20020101-S083000-E085959.0510.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20020101-S090000-E092959.0540.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20020101-S093000-E095959.0570.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20020101-S100000-E102959.0600.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20020101-S103000-E105959.0630.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20020101-S110000-E112959.0660.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20020101-S113000-E115959.0690.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20020101-S120000-E122959.0720.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20020101-S123000-E125959.0750.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20020101-S130000-E132959.0780.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20020101-S133000-E135959.0810.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20020101-S140000-E142959.0840.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20020101-S143000-E145959.0870.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20020101-S150000-E152959.0900.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20020101-S153000-E155959.0930.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20020101-S160000-E162959.0960.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20020101-S163000-E165959.0990.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20020101-S170000-E172959.1020.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20020101-S173000-E175959.1050.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20020101-S180000-E182959.1080.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20020101-S183000-E185959.1110.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20020101-S190000-E192959.1140.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20020101-S193000-E195959.1170.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20020101-S200000-E202959.1200.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20020101-S203000-E205959.1230.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20020101-S210000-E212959.1260.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20020101-S213000-E215959.1290.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20020101-S220000-E222959.1320.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20020101-S223000-E225959.1350.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20020101-S230000-E232959.1380.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20020101-S233000-E235959.1410.V06B.HDF5" ;
# 		:title = "GPM IMERG Late Precipitation L3 1 day 0.1 degree x 0.1 degree (GPM_3IMERGDL)" ;
# 		:DOI = "10.5067/GPM/IMERGDL/DAY/06" ;
# 		:ProductionTime = "2019-08-08T18:33:24.265Z" ;
# 		:history_L34RS = "\'Created by L34RS v1.4.3 @ NASA GES DISC on July 21 2022 20:50:55. Spatial: 21.885 33.75 -18.3 -8.104. Variables: precipitationCal\'" ;
# 		:CDO = "Climate Data Operators version 1.9.8 (https://mpimet.mpg.de/cdo)" ;
# 		:history = "Fri Jul 22 21:51:18 2022: ncrcat /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20020101-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20020102-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20020103-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20020104-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20020105-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20020106-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20020107-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20020108-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20020109-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20020110-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20020111-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20020112-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20020113-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20020114-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20020115-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20020116-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20020117-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20020118-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20020119-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20020120-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20020121-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20020122-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20020123-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20020124-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20020125-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20020126-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20020127-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20020128-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20020129-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20020130-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20020131-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_concat/3B-DAY-L.MS.MRG.3IMERG.20020101-S000000-E235959.V06.nc4.SUB.nc4" ;
# 		:NCO = "netCDF Operators version 5.1.0 (Homepage = http://nco.sf.net, Code = http://github.com/nco/nco)" ;
# }

# %% [markdown]
# 3. Navigate to ```IMERG_mm_month``` folder in terminal. Loops all files in the folder ```IMERG_mm_month``` to make ```time``` the record dimension/variable used for concatenating using ```Ncks``` command

# %%
# %cd /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_month
# Out:
# /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_month

# %%
# !for fl in *.nc4; do ncks --mk_rec_dmn time $fl -o $fl.TMP; mv $fl.TMP $fl; done
# Out:
# INFO: NCO stub function for nc_inq_filter_avail() reports an inquiry on filter availability of HDF5 filter ID = 307. Stub function employed because libnetcdf.a does not contain nc_inq_filter_avail(). Please rebuild NCO against netCDF library version 4.9.0 (released ~20220601) or later to support the capability to find and call filters besides DEFLATE, Shuffle, and Fletcher32.
# Exiting...
# ncks: WARNING nc_cdc_lst_bld() reports nco_inq_filter_avail() did not find Bzip2 filter (with HDF5 filter ID = 307) as an HDF5 shared library filter. This is probably fixable because this filter is supported by all default installations of netCDF version 4.9.0 or higher. HINT: If you build netCDF from source, please be sure it was configured with the following options: "--enable-nczarr" and "--with-plugin-dir=${HDF5_PLUGIN_PATH}". The latter is especially important in netCDF 4.9.0. Also, please be sure the library for the missing filter (e.g., libzstd.a, libblosc.a, libbz2.a) is in an automatically searched directory, e.g., $LD_LIBRARY_PATH or /usr/lib.
# INFO: NCO stub function for nc_inq_filter_avail() reports an inquiry on filter availability of HDF5 filter ID = 32015. Stub function employed because libnetcdf.a does not contain nc_inq_filter_avail(). Please rebuild NCO against netCDF library version 4.9.0 (released ~20220601) or later to support the capability to find and call filters besides DEFLATE, Shuffle, and Fletcher32.
# Exiting...
# ncks: WARNING nc_cdc_lst_bld() reports nco_inq_filter_avail() did not find Zstandard filter (with HDF5 filter ID = 32015) as an HDF5 shared library filter. This is probably fixable because this filter is supported by all default installations of netCDF version 4.9.0 or higher. HINT: If you build netCDF from source, please be sure it was configured with the following options: "--enable-nczarr" and "--with-plugin-dir=${HDF5_PLUGIN_PATH}". The latter is especially important in netCDF 4.9.0. Also, please be sure the library for the missing filter (e.g., libzstd.a, libblosc.a, libbz2.a) is in an automatically searched directory, e.g., $LD_LIBRARY_PATH or /usr/lib.
# INFO: NCO stub function for nc_inq_filter_avail() reports an inquiry on filter availability of HDF5 filter ID = 32001. Stub function employed because libnetcdf.a does not contain nc_inq_filter_avail(). Please rebuild NCO against netCDF library version 4.9.0 (released ~20220601) or later to support the capability to find and call filters besides DEFLATE, Shuffle, and Fletcher32.
# Exiting...
# ncks: WARNING nc_cdc_lst_bld() reports nco_inq_filter_avail() did not find Blosc filter (with HDF5 filter ID = 32001) as an HDF5 shared library filter. This is probably fixable because this filter is supported by all default installations of netCDF version 4.9.0 or higher. HINT: If you build netCDF from source, please be sure it was configured with the following options: "--enable-nczarr" and "--with-plugin-dir=${HDF5_PLUGIN_PATH}". The latter is especially important in netCDF 4.9.0. Also, please be sure the library for the missing filter (e.g., libzstd.a, libblosc.a, libbz2.a) is in an automatically searched directory, e.g., $LD_LIBRARY_PATH or /usr/lib.
# INFO: NCO stub function for nc_inq_filter_avail() reports an inquiry on filter availability of HDF5 filter ID = 307. Stub function employed because libnetcdf.a does not contain nc_inq_filter_avail(). Please rebuild NCO against netCDF library version 4.9.0 (released ~20220601) or later to support the capability to find and call filters besides DEFLATE, Shuffle, and Fletcher32.
# Exiting...
# ncks: WARNING nc_cdc_lst_bld() reports nco_inq_filter_avail() did not find Bzip2 filter (with HDF5 filter ID = 307) as an HDF5 shared library filter. This is probably fixable because this filter is supported by all default installations of netCDF version 4.9.0 or higher. HINT: If you build netCDF from source, please be sure it was configured with the following options: "--enable-nczarr" and "--with-plugin-dir=${HDF5_PLUGIN_PATH}". The latter is especially important in netCDF 4.9.0. Also, please be sure the library for the missing filter (e.g., libzstd.a, libblosc.a, libbz2.a) is in an automatically searched directory, e.g., $LD_LIBRARY_PATH or /usr/lib.
# INFO: NCO stub function for nc_inq_filter_avail() reports an inquiry on filter availability of HDF5 filter ID = 32015. Stub function employed because libnetcdf.a does not contain nc_inq_filter_avail(). Please rebuild NCO against netCDF library version 4.9.0 (released ~20220601) or later to support the capability to find and call filters besides DEFLATE, Shuffle, and Fletcher32.
# Exiting...
# ncks: WARNING nc_cdc_lst_bld() reports nco_inq_filter_avail() did not find Zstandard filter (with HDF5 filter ID = 32015) as an HDF5 shared library filter. This is probably fixable because this filter is supported by all default installations of netCDF version 4.9.0 or higher. HINT: If you build netCDF from source, please be sure it was configured with the following options: "--enable-nczarr" and "--with-plugin-dir=${HDF5_PLUGIN_PATH}". The latter is especially important in netCDF 4.9.0. Also, please be sure the library for the missing filter (e.g., libzstd.a, libblosc.a, libbz2.a) is in an automatically searched directory, e.g., $LD_LIBRARY_PATH or /usr/lib.
# INFO: NCO stub function for nc_inq_filter_avail() reports an inquiry on filter availability of HDF5 filter ID = 32001. Stub function employed because libnetcdf.a does not contain nc_inq_filter_avail(). Please rebuild NCO against netCDF library version 4.9.0 (released ~20220601) or later to support the capability to find and call filters besides DEFLATE, Shuffle, and Fletcher32.
# Exiting...
# ncks: WARNING nc_cdc_lst_bld() reports nco_inq_filter_avail() did not find Blosc filter (with HDF5 filter ID = 32001) as an HDF5 shared library filter. This is probably fixable because this filter is supported by all default installations of netCDF version 4.9.0 or higher. HINT: If you build netCDF from source, please be sure it was configured with the following options: "--enable-nczarr" and "--with-plugin-dir=${HDF5_PLUGIN_PATH}". The latter is especially important in netCDF 4.9.0. Also, please be sure the library for the missing filter (e.g., libzstd.a, libblosc.a, libbz2.a) is in an automatically searched directory, e.g., $LD_LIBRARY_PATH or /usr/lib.
# INFO: NCO stub function for nc_inq_filter_avail() reports an inquiry on filter availability of HDF5 filter ID = 307. Stub function employed because libnetcdf.a does not contain nc_inq_filter_avail(). Please rebuild NCO against netCDF library version 4.9.0 (released ~20220601) or later to support the capability to find and call filters besides DEFLATE, Shuffle, and Fletcher32.
# Exiting...
# ncks: WARNING nc_cdc_lst_bld() reports nco_inq_filter_avail() did not find Bzip2 filter (with HDF5 filter ID = 307) as an HDF5 shared library filter. This is probably fixable because this filter is supported by all default installations of netCDF version 4.9.0 or higher. HINT: If you build netCDF from source, please be sure it was configured with the following options: "--enable-nczarr" and "--with-plugin-dir=${HDF5_PLUGIN_PATH}". The latter is especially important in netCDF 4.9.0. Also, please be sure the library for the missing filter (e.g., libzstd.a, libblosc.a, libbz2.a) is in an automatically searched directory, e.g., $LD_LIBRARY_PATH or /usr/lib.
# INFO: NCO stub function for nc_inq_filter_avail() reports an inquiry on filter availability of HDF5 filter ID = 32015. Stub function employed because libnetcdf.a does not contain nc_inq_filter_avail(). Please rebuild NCO against netCDF library version 4.9.0 (released ~20220601) or later to support the capability to find and call filters besides DEFLATE, Shuffle, and Fletcher32.
# Exiting...
# ncks: WARNING nc_cdc_lst_bld() reports nco_inq_filter_avail() did not find Zstandard filter (with HDF5 filter ID = 32015) as an HDF5 shared library filter. This is probably fixable because this filter is supported by all default installations of netCDF version 4.9.0 or higher. HINT: If you build netCDF from source, please be sure it was configured with the following options: "--enable-nczarr" and "--with-plugin-dir=${HDF5_PLUGIN_PATH}". The latter is especially important in netCDF 4.9.0. Also, please be sure the library for the missing filter (e.g., libzstd.a, libblosc.a, libbz2.a) is in an automatically searched directory, e.g., $LD_LIBRARY_PATH or /usr/lib.
# INFO: NCO stub function for nc_inq_filter_avail() reports an inquiry on filter availability of HDF5 filter ID = 32001. Stub function employed because libnetcdf.a does not contain nc_inq_filter_avail(). Please rebuild NCO against netCDF library version 4.9.0 (released ~20220601) or later to support the capability to find and call filters besides DEFLATE, Shuffle, and Fletcher32.
# Exiting...
# ncks: WARNING nc_cdc_lst_bld() reports nco_inq_filter_avail() did not find Blosc filter (with HDF5 filter ID = 32001) as an HDF5 shared library filter. This is probably fixable because this filter is supported by all default installations of netCDF version 4.9.0 or higher. HINT: If you build netCDF from source, please be sure it was configured with the following options: "--enable-nczarr" and "--with-plugin-dir=${HDF5_PLUGIN_PATH}". The latter is especially important in netCDF 4.9.0. Also, please be sure the library for the missing filter (e.g., libzstd.a, libblosc.a, libbz2.a) is in an automatically searched directory, e.g., $LD_LIBRARY_PATH or /usr/lib.
# INFO: NCO stub function for nc_inq_filter_avail() reports an inquiry on filter availability of HDF5 filter ID = 307. Stub function employed because libnetcdf.a does not contain nc_inq_filter_avail(). Please rebuild NCO against netCDF library version 4.9.0 (released ~20220601) or later to support the capability to find and call filters besides DEFLATE, Shuffle, and Fletcher32.
# Exiting...
# ncks: WARNING nc_cdc_lst_bld() reports nco_inq_filter_avail() did not find Bzip2 filter (with HDF5 filter ID = 307) as an HDF5 shared library filter. This is probably fixable because this filter is supported by all default installations of netCDF version 4.9.0 or higher. HINT: If you build netCDF from source, please be sure it was configured with the following options: "--enable-nczarr" and "--with-plugin-dir=${HDF5_PLUGIN_PATH}". The latter is especially important in netCDF 4.9.0. Also, please be sure the library for the missing filter (e.g., libzstd.a, libblosc.a, libbz2.a) is in an automatically searched directory, e.g., $LD_LIBRARY_PATH or /usr/lib.
# INFO: NCO stub function for nc_inq_filter_avail() reports an inquiry on filter availability of HDF5 filter ID = 32015. Stub function employed because libnetcdf.a does not contain nc_inq_filter_avail(). Please rebuild NCO against netCDF library version 4.9.0 (released ~20220601) or later to support the capability to find and call filters besides DEFLATE, Shuffle, and Fletcher32.
# Exiting...
# ncks: WARNING nc_cdc_lst_bld() reports nco_inq_filter_avail() did not find Zstandard filter (with HDF5 filter ID = 32015) as an HDF5 shared library filter. This is probably fixable because this filter is supported by all default installations of netCDF version 4.9.0 or higher. HINT: If you build netCDF from source, please be sure it was configured with the following options: "--enable-nczarr" and "--with-plugin-dir=${HDF5_PLUGIN_PATH}". The latter is especially important in netCDF 4.9.0. Also, please be sure the library for the missing filter (e.g., libzstd.a, libblosc.a, libbz2.a) is in an automatically searched directory, e.g., $LD_LIBRARY_PATH or /usr/lib.
# INFO: NCO stub function for nc_inq_filter_avail() reports an inquiry on filter availability of HDF5 filter ID = 32001. Stub function employed because libnetcdf.a does not contain nc_inq_filter_avail(). Please rebuild NCO against netCDF library version 4.9.0 (released ~20220601) or later to support the capability to find and call filters besides DEFLATE, Shuffle, and Fletcher32.
# Exiting...
# ncks: WARNING nc_cdc_lst_bld() reports nco_inq_filter_avail() did not find Blosc filter (with HDF5 filter ID = 32001) as an HDF5 shared library filter. This is probably fixable because this filter is supported by all default installations of netCDF version 4.9.0 or higher. HINT: If you build netCDF from source, please be sure it was configured with the following options: "--enable-nczarr" and "--with-plugin-dir=${HDF5_PLUGIN_PATH}". The latter is especially important in netCDF 4.9.0. Also, please be sure the library for the missing filter (e.g., libzstd.a, libblosc.a, libbz2.a) is in an automatically searched directory, e.g., $LD_LIBRARY_PATH or /usr/lib.
# INFO: NCO stub function for nc_inq_filter_avail() reports an inquiry on filter availability of HDF5 filter ID = 307. Stub function employed because libnetcdf.a does not contain nc_inq_filter_avail(). Please rebuild NCO against netCDF library version 4.9.0 (released ~20220601) or later to support the capability to find and call filters besides DEFLATE, Shuffle, and Fletcher32.
# Exiting...
# ncks: WARNING nc_cdc_lst_bld() reports nco_inq_filter_avail() did not find Bzip2 filter (with HDF5 filter ID = 307) as an HDF5 shared library filter. This is probably fixable because this filter is supported by all default installations of netCDF version 4.9.0 or higher. HINT: If you build netCDF from source, please be sure it was configured with the following options: "--enable-nczarr" and "--with-plugin-dir=${HDF5_PLUGIN_PATH}". The latter is especially important in netCDF 4.9.0. Also, please be sure the library for the missing filter (e.g., libzstd.a, libblosc.a, libbz2.a) is in an automatically searched directory, e.g., $LD_LIBRARY_PATH or /usr/lib.
# INFO: NCO stub function for nc_inq_filter_avail() reports an inquiry on filter availability of HDF5 filter ID = 32015. Stub function employed because libnetcdf.a does not contain nc_inq_filter_avail(). Please rebuild NCO against netCDF library version 4.9.0 (released ~20220601) or later to support the capability to find and call filters besides DEFLATE, Shuffle, and Fletcher32.
# Exiting...
# ncks: WARNING nc_cdc_lst_bld() reports nco_inq_filter_avail() did not find Zstandard filter (with HDF5 filter ID = 32015) as an HDF5 shared library filter. This is probably fixable because this filter is supported by all default installations of netCDF version 4.9.0 or higher. HINT: If you build netCDF from source, please be sure it was configured with the following options: "--enable-nczarr" and "--with-plugin-dir=${HDF5_PLUGIN_PATH}". The latter is especially important in netCDF 4.9.0. Also, please be sure the library for the missing filter (e.g., libzstd.a, libblosc.a, libbz2.a) is in an automatically searched directory, e.g., $LD_LIBRARY_PATH or /usr/lib.
# INFO: NCO stub function for nc_inq_filter_avail() reports an inquiry on filter availability of HDF5 filter ID = 32001. Stub function employed because libnetcdf.a does not contain nc_inq_filter_avail(). Please rebuild NCO against netCDF library version 4.9.0 (released ~20220601) or later to support the capability to find and call filters besides DEFLATE, Shuffle, and Fletcher32.
# Exiting...
# ncks: WARNING nc_cdc_lst_bld() reports nco_inq_filter_avail() did not find Blosc filter (with HDF5 filter ID = 32001) as an HDF5 shared library filter. This is probably fixable because this filter is supported by all default installations of netCDF version 4.9.0 or higher. HINT: If you build netCDF from source, please be sure it was configured with the following options: "--enable-nczarr" and "--with-plugin-dir=${HDF5_PLUGIN_PATH}". The latter is especially important in netCDF 4.9.0. Also, please be sure the library for the missing filter (e.g., libzstd.a, libblosc.a, libbz2.a) is in an automatically searched directory, e.g., $LD_LIBRARY_PATH or /usr/lib.
# INFO: NCO stub function for nc_inq_filter_avail() reports an inquiry on filter availability of HDF5 filter ID = 307. Stub function employed because libnetcdf.a does not contain nc_inq_filter_avail(). Please rebuild NCO against netCDF library version 4.9.0 (released ~20220601) or later to support the capability to find and call filters besides DEFLATE, Shuffle, and Fletcher32.
# Exiting...
# ncks: WARNING nc_cdc_lst_bld() reports nco_inq_filter_avail() did not find Bzip2 filter (with HDF5 filter ID = 307) as an HDF5 shared library filter. This is probably fixable because this filter is supported by all default installations of netCDF version 4.9.0 or higher. HINT: If you build netCDF from source, please be sure it was configured with the following options: "--enable-nczarr" and "--with-plugin-dir=${HDF5_PLUGIN_PATH}". The latter is especially important in netCDF 4.9.0. Also, please be sure the library for the missing filter (e.g., libzstd.a, libblosc.a, libbz2.a) is in an automatically searched directory, e.g., $LD_LIBRARY_PATH or /usr/lib.
# INFO: NCO stub function for nc_inq_filter_avail() reports an inquiry on filter availability of HDF5 filter ID = 32015. Stub function employed because libnetcdf.a does not contain nc_inq_filter_avail(). Please rebuild NCO against netCDF library version 4.9.0 (released ~20220601) or later to support the capability to find and call filters besides DEFLATE, Shuffle, and Fletcher32.
# Exiting...
# ncks: WARNING nc_cdc_lst_bld() reports nco_inq_filter_avail() did not find Zstandard filter (with HDF5 filter ID = 32015) as an HDF5 shared library filter. This is probably fixable because this filter is supported by all default installations of netCDF version 4.9.0 or higher. HINT: If you build netCDF from source, please be sure it was configured with the following options: "--enable-nczarr" and "--with-plugin-dir=${HDF5_PLUGIN_PATH}". The latter is especially important in netCDF 4.9.0. Also, please be sure the library for the missing filter (e.g., libzstd.a, libblosc.a, libbz2.a) is in an automatically searched directory, e.g., $LD_LIBRARY_PATH or /usr/lib.
# INFO: NCO stub function for nc_inq_filter_avail() reports an inquiry on filter availability of HDF5 filter ID = 32001. Stub function employed because libnetcdf.a does not contain nc_inq_filter_avail(). Please rebuild NCO against netCDF library version 4.9.0 (released ~20220601) or later to support the capability to find and call filters besides DEFLATE, Shuffle, and Fletcher32.
# Exiting...
# ncks: WARNING nc_cdc_lst_bld() reports nco_inq_filter_avail() did not find Blosc filter (with HDF5 filter ID = 32001) as an HDF5 shared library filter. This is probably fixable because this filter is supported by all default installations of netCDF version 4.9.0 or higher. HINT: If you build netCDF from source, please be sure it was configured with the following options: "--enable-nczarr" and "--with-plugin-dir=${HDF5_PLUGIN_PATH}". The latter is especially important in netCDF 4.9.0. Also, please be sure the library for the missing filter (e.g., libzstd.a, libblosc.a, libbz2.a) is in an automatically searched directory, e.g., $LD_LIBRARY_PATH or /usr/lib.
# INFO: NCO stub function for nc_inq_filter_avail() reports an inquiry on filter availability of HDF5 filter ID = 307. Stub function employed because libnetcdf.a does not contain nc_inq_filter_avail(). Please rebuild NCO against netCDF library version 4.9.0 (released ~20220601) or later to support the capability to find and call filters besides DEFLATE, Shuffle, and Fletcher32.
# Exiting...
# ncks: WARNING nc_cdc_lst_bld() reports nco_inq_filter_avail() did not find Bzip2 filter (with HDF5 filter ID = 307) as an HDF5 shared library filter. This is probably fixable because this filter is supported by all default installations of netCDF version 4.9.0 or higher. HINT: If you build netCDF from source, please be sure it was configured with the following options: "--enable-nczarr" and "--with-plugin-dir=${HDF5_PLUGIN_PATH}". The latter is especially important in netCDF 4.9.0. Also, please be sure the library for the missing filter (e.g., libzstd.a, libblosc.a, libbz2.a) is in an automatically searched directory, e.g., $LD_LIBRARY_PATH or /usr/lib.
# INFO: NCO stub function for nc_inq_filter_avail() reports an inquiry on filter availability of HDF5 filter ID = 32015. Stub function employed because libnetcdf.a does not contain nc_inq_filter_avail(). Please rebuild NCO against netCDF library version 4.9.0 (released ~20220601) or later to support the capability to find and call filters besides DEFLATE, Shuffle, and Fletcher32.
# Exiting...
# ncks: WARNING nc_cdc_lst_bld() reports nco_inq_filter_avail() did not find Zstandard filter (with HDF5 filter ID = 32015) as an HDF5 shared library filter. This is probably fixable because this filter is supported by all default installations of netCDF version 4.9.0 or higher. HINT: If you build netCDF from source, please be sure it was configured with the following options: "--enable-nczarr" and "--with-plugin-dir=${HDF5_PLUGIN_PATH}". The latter is especially important in netCDF 4.9.0. Also, please be sure the library for the missing filter (e.g., libzstd.a, libblosc.a, libbz2.a) is in an automatically searched directory, e.g., $LD_LIBRARY_PATH or /usr/lib.
# INFO: NCO stub function for nc_inq_filter_avail() reports an inquiry on filter availability of HDF5 filter ID = 32001. Stub function employed because libnetcdf.a does not contain nc_inq_filter_avail(). Please rebuild NCO against netCDF library version 4.9.0 (released ~20220601) or later to support the capability to find and call filters besides DEFLATE, Shuffle, and Fletcher32.
# Exiting...
# ncks: WARNING nc_cdc_lst_bld() reports nco_inq_filter_avail() did not find Blosc filter (with HDF5 filter ID = 32001) as an HDF5 shared library filter. This is probably fixable because this filter is supported by all default installations of netCDF version 4.9.0 or higher. HINT: If you build netCDF from source, please be sure it was configured with the following options: "--enable-nczarr" and "--with-plugin-dir=${HDF5_PLUGIN_PATH}". The latter is especially important in netCDF 4.9.0. Also, please be sure the library for the missing filter (e.g., libzstd.a, libblosc.a, libbz2.a) is in an automatically searched directory, e.g., $LD_LIBRARY_PATH or /usr/lib.
# INFO: NCO stub function for nc_inq_filter_avail() reports an inquiry on filter availability of HDF5 filter ID = 307. Stub function employed because libnetcdf.a does not contain nc_inq_filter_avail(). Please rebuild NCO against netCDF library version 4.9.0 (released ~20220601) or later to support the capability to find and call filters besides DEFLATE, Shuffle, and Fletcher32.
# Exiting...
# ncks: WARNING nc_cdc_lst_bld() reports nco_inq_filter_avail() did not find Bzip2 filter (with HDF5 filter ID = 307) as an HDF5 shared library filter. This is probably fixable because this filter is supported by all default installations of netCDF version 4.9.0 or higher. HINT: If you build netCDF from source, please be sure it was configured with the following options: "--enable-nczarr" and "--with-plugin-dir=${HDF5_PLUGIN_PATH}". The latter is especially important in netCDF 4.9.0. Also, please be sure the library for the missing filter (e.g., libzstd.a, libblosc.a, libbz2.a) is in an automatically searched directory, e.g., $LD_LIBRARY_PATH or /usr/lib.
# INFO: NCO stub function for nc_inq_filter_avail() reports an inquiry on filter availability of HDF5 filter ID = 32015. Stub function employed because libnetcdf.a does not contain nc_inq_filter_avail(). Please rebuild NCO against netCDF library version 4.9.0 (released ~20220601) or later to support the capability to find and call filters besides DEFLATE, Shuffle, and Fletcher32.
# Exiting...
# ncks: WARNING nc_cdc_lst_bld() reports nco_inq_filter_avail() did not find Zstandard filter (with HDF5 filter ID = 32015) as an HDF5 shared library filter. This is probably fixable because this filter is supported by all default installations of netCDF version 4.9.0 or higher. HINT: If you build netCDF from source, please be sure it was configured with the following options: "--enable-nczarr" and "--with-plugin-dir=${HDF5_PLUGIN_PATH}". The latter is especially important in netCDF 4.9.0. Also, please be sure the library for the missing filter (e.g., libzstd.a, libblosc.a, libbz2.a) is in an automatically searched directory, e.g., $LD_LIBRARY_PATH or /usr/lib.
# INFO: NCO stub function for nc_inq_filter_avail() reports an inquiry on filter availability of HDF5 filter ID = 32001. Stub function employed because libnetcdf.a does not contain nc_inq_filter_avail(). Please rebuild NCO against netCDF library version 4.9.0 (released ~20220601) or later to support the capability to find and call filters besides DEFLATE, Shuffle, and Fletcher32.
# Exiting...
# ncks: WARNING nc_cdc_lst_bld() reports nco_inq_filter_avail() did not find Blosc filter (with HDF5 filter ID = 32001) as an HDF5 shared library filter. This is probably fixable because this filter is supported by all default installations of netCDF version 4.9.0 or higher. HINT: If you build netCDF from source, please be sure it was configured with the following options: "--enable-nczarr" and "--with-plugin-dir=${HDF5_PLUGIN_PATH}". The latter is especially important in netCDF 4.9.0. Also, please be sure the library for the missing filter (e.g., libzstd.a, libblosc.a, libbz2.a) is in an automatically searched directory, e.g., $LD_LIBRARY_PATH or /usr/lib.
# INFO: NCO stub function for nc_inq_filter_avail() reports an inquiry on filter availability of HDF5 filter ID = 307. Stub function employed because libnetcdf.a does not contain nc_inq_filter_avail(). Please rebuild NCO against netCDF library version 4.9.0 (released ~20220601) or later to support the capability to find and call filters besides DEFLATE, Shuffle, and Fletcher32.
# Exiting...
# ncks: WARNING nc_cdc_lst_bld() reports nco_inq_filter_avail() did not find Bzip2 filter (with HDF5 filter ID = 307) as an HDF5 shared library filter. This is probably fixable because this filter is supported by all default installations of netCDF version 4.9.0 or higher. HINT: If you build netCDF from source, please be sure it was configured with the following options: "--enable-nczarr" and "--with-plugin-dir=${HDF5_PLUGIN_PATH}". The latter is especially important in netCDF 4.9.0. Also, please be sure the library for the missing filter (e.g., libzstd.a, libblosc.a, libbz2.a) is in an automatically searched directory, e.g., $LD_LIBRARY_PATH or /usr/lib.
# INFO: NCO stub function for nc_inq_filter_avail() reports an inquiry on filter availability of HDF5 filter ID = 32015. Stub function employed because libnetcdf.a does not contain nc_inq_filter_avail(). Please rebuild NCO against netCDF library version 4.9.0 (released ~20220601) or later to support the capability to find and call filters besides DEFLATE, Shuffle, and Fletcher32.
# Exiting...
# ncks: WARNING nc_cdc_lst_bld() reports nco_inq_filter_avail() did not find Zstandard filter (with HDF5 filter ID = 32015) as an HDF5 shared library filter. This is probably fixable because this filter is supported by all default installations of netCDF version 4.9.0 or higher. HINT: If you build netCDF from source, please be sure it was configured with the following options: "--enable-nczarr" and "--with-plugin-dir=${HDF5_PLUGIN_PATH}". The latter is especially important in netCDF 4.9.0. Also, please be sure the library for the missing filter (e.g., libzstd.a, libblosc.a, libbz2.a) is in an automatically searched directory, e.g., $LD_LIBRARY_PATH or /usr/lib.
# INFO: NCO stub function for nc_inq_filter_avail() reports an inquiry on filter availability of HDF5 filter ID = 32001. Stub function employed because libnetcdf.a does not contain nc_inq_filter_avail(). Please rebuild NCO against netCDF library version 4.9.0 (released ~20220601) or later to support the capability to find and call filters besides DEFLATE, Shuffle, and Fletcher32.
# Exiting...
# ncks: WARNING nc_cdc_lst_bld() reports nco_inq_filter_avail() did not find Blosc filter (with HDF5 filter ID = 32001) as an HDF5 shared library filter. This is probably fixable because this filter is supported by all default installations of netCDF version 4.9.0 or higher. HINT: If you build netCDF from source, please be sure it was configured with the following options: "--enable-nczarr" and "--with-plugin-dir=${HDF5_PLUGIN_PATH}". The latter is especially important in netCDF 4.9.0. Also, please be sure the library for the missing filter (e.g., libzstd.a, libblosc.a, libbz2.a) is in an automatically searched directory, e.g., $LD_LIBRARY_PATH or /usr/lib.
# INFO: NCO stub function for nc_inq_filter_avail() reports an inquiry on filter availability of HDF5 filter ID = 307. Stub function employed because libnetcdf.a does not contain nc_inq_filter_avail(). Please rebuild NCO against netCDF library version 4.9.0 (released ~20220601) or later to support the capability to find and call filters besides DEFLATE, Shuffle, and Fletcher32.
# Exiting...
# ncks: WARNING nc_cdc_lst_bld() reports nco_inq_filter_avail() did not find Bzip2 filter (with HDF5 filter ID = 307) as an HDF5 shared library filter. This is probably fixable because this filter is supported by all default installations of netCDF version 4.9.0 or higher. HINT: If you build netCDF from source, please be sure it was configured with the following options: "--enable-nczarr" and "--with-plugin-dir=${HDF5_PLUGIN_PATH}". The latter is especially important in netCDF 4.9.0. Also, please be sure the library for the missing filter (e.g., libzstd.a, libblosc.a, libbz2.a) is in an automatically searched directory, e.g., $LD_LIBRARY_PATH or /usr/lib.
# INFO: NCO stub function for nc_inq_filter_avail() reports an inquiry on filter availability of HDF5 filter ID = 32015. Stub function employed because libnetcdf.a does not contain nc_inq_filter_avail(). Please rebuild NCO against netCDF library version 4.9.0 (released ~20220601) or later to support the capability to find and call filters besides DEFLATE, Shuffle, and Fletcher32.
# Exiting...
# ncks: WARNING nc_cdc_lst_bld() reports nco_inq_filter_avail() did not find Zstandard filter (with HDF5 filter ID = 32015) as an HDF5 shared library filter. This is probably fixable because this filter is supported by all default installations of netCDF version 4.9.0 or higher. HINT: If you build netCDF from source, please be sure it was configured with the following options: "--enable-nczarr" and "--with-plugin-dir=${HDF5_PLUGIN_PATH}". The latter is especially important in netCDF 4.9.0. Also, please be sure the library for the missing filter (e.g., libzstd.a, libblosc.a, libbz2.a) is in an automatically searched directory, e.g., $LD_LIBRARY_PATH or /usr/lib.
# INFO: NCO stub function for nc_inq_filter_avail() reports an inquiry on filter availability of HDF5 filter ID = 32001. Stub function employed because libnetcdf.a does not contain nc_inq_filter_avail(). Please rebuild NCO against netCDF library version 4.9.0 (released ~20220601) or later to support the capability to find and call filters besides DEFLATE, Shuffle, and Fletcher32.
# Exiting...
# ncks: WARNING nc_cdc_lst_bld() reports nco_inq_filter_avail() did not find Blosc filter (with HDF5 filter ID = 32001) as an HDF5 shared library filter. This is probably fixable because this filter is supported by all default installations of netCDF version 4.9.0 or higher. HINT: If you build netCDF from source, please be sure it was configured with the following options: "--enable-nczarr" and "--with-plugin-dir=${HDF5_PLUGIN_PATH}". The latter is especially important in netCDF 4.9.0. Also, please be sure the library for the missing filter (e.g., libzstd.a, libblosc.a, libbz2.a) is in an automatically searched directory, e.g., $LD_LIBRARY_PATH or /usr/lib.
# INFO: NCO stub function for nc_inq_filter_avail() reports an inquiry on filter availability of HDF5 filter ID = 307. Stub function employed because libnetcdf.a does not contain nc_inq_filter_avail(). Please rebuild NCO against netCDF library version 4.9.0 (released ~20220601) or later to support the capability to find and call filters besides DEFLATE, Shuffle, and Fletcher32.
# Exiting...
# ncks: WARNING nc_cdc_lst_bld() reports nco_inq_filter_avail() did not find Bzip2 filter (with HDF5 filter ID = 307) as an HDF5 shared library filter. This is probably fixable because this filter is supported by all default installations of netCDF version 4.9.0 or higher. HINT: If you build netCDF from source, please be sure it was configured with the following options: "--enable-nczarr" and "--with-plugin-dir=${HDF5_PLUGIN_PATH}". The latter is especially important in netCDF 4.9.0. Also, please be sure the library for the missing filter (e.g., libzstd.a, libblosc.a, libbz2.a) is in an automatically searched directory, e.g., $LD_LIBRARY_PATH or /usr/lib.
# INFO: NCO stub function for nc_inq_filter_avail() reports an inquiry on filter availability of HDF5 filter ID = 32015. Stub function employed because libnetcdf.a does not contain nc_inq_filter_avail(). Please rebuild NCO against netCDF library version 4.9.0 (released ~20220601) or later to support the capability to find and call filters besides DEFLATE, Shuffle, and Fletcher32.
# Exiting...
# ncks: WARNING nc_cdc_lst_bld() reports nco_inq_filter_avail() did not find Zstandard filter (with HDF5 filter ID = 32015) as an HDF5 shared library filter. This is probably fixable because this filter is supported by all default installations of netCDF version 4.9.0 or higher. HINT: If you build netCDF from source, please be sure it was configured with the following options: "--enable-nczarr" and "--with-plugin-dir=${HDF5_PLUGIN_PATH}". The latter is especially important in netCDF 4.9.0. Also, please be sure the library for the missing filter (e.g., libzstd.a, libblosc.a, libbz2.a) is in an automatically searched directory, e.g., $LD_LIBRARY_PATH or /usr/lib.
# INFO: NCO stub function for nc_inq_filter_avail() reports an inquiry on filter availability of HDF5 filter ID = 32001. Stub function employed because libnetcdf.a does not contain nc_inq_filter_avail(). Please rebuild NCO against netCDF library version 4.9.0 (released ~20220601) or later to support the capability to find and call filters besides DEFLATE, Shuffle, and Fletcher32.
# Exiting...
# ncks: WARNING nc_cdc_lst_bld() reports nco_inq_filter_avail() did not find Blosc filter (with HDF5 filter ID = 32001) as an HDF5 shared library filter. This is probably fixable because this filter is supported by all default installations of netCDF version 4.9.0 or higher. HINT: If you build netCDF from source, please be sure it was configured with the following options: "--enable-nczarr" and "--with-plugin-dir=${HDF5_PLUGIN_PATH}". The latter is especially important in netCDF 4.9.0. Also, please be sure the library for the missing filter (e.g., libzstd.a, libblosc.a, libbz2.a) is in an automatically searched directory, e.g., $LD_LIBRARY_PATH or /usr/lib.
# INFO: NCO stub function for nc_inq_filter_avail() reports an inquiry on filter availability of HDF5 filter ID = 307. Stub function employed because libnetcdf.a does not contain nc_inq_filter_avail(). Please rebuild NCO against netCDF library version 4.9.0 (released ~20220601) or later to support the capability to find and call filters besides DEFLATE, Shuffle, and Fletcher32.
# Exiting...
# ncks: WARNING nc_cdc_lst_bld() reports nco_inq_filter_avail() did not find Bzip2 filter (with HDF5 filter ID = 307) as an HDF5 shared library filter. This is probably fixable because this filter is supported by all default installations of netCDF version 4.9.0 or higher. HINT: If you build netCDF from source, please be sure it was configured with the following options: "--enable-nczarr" and "--with-plugin-dir=${HDF5_PLUGIN_PATH}". The latter is especially important in netCDF 4.9.0. Also, please be sure the library for the missing filter (e.g., libzstd.a, libblosc.a, libbz2.a) is in an automatically searched directory, e.g., $LD_LIBRARY_PATH or /usr/lib.
# INFO: NCO stub function for nc_inq_filter_avail() reports an inquiry on filter availability of HDF5 filter ID = 32015. Stub function employed because libnetcdf.a does not contain nc_inq_filter_avail(). Please rebuild NCO against netCDF library version 4.9.0 (released ~20220601) or later to support the capability to find and call filters besides DEFLATE, Shuffle, and Fletcher32.
# Exiting...
# ncks: WARNING nc_cdc_lst_bld() reports nco_inq_filter_avail() did not find Zstandard filter (with HDF5 filter ID = 32015) as an HDF5 shared library filter. This is probably fixable because this filter is supported by all default installations of netCDF version 4.9.0 or higher. HINT: If you build netCDF from source, please be sure it was configured with the following options: "--enable-nczarr" and "--with-plugin-dir=${HDF5_PLUGIN_PATH}". The latter is especially important in netCDF 4.9.0. Also, please be sure the library for the missing filter (e.g., libzstd.a, libblosc.a, libbz2.a) is in an automatically searched directory, e.g., $LD_LIBRARY_PATH or /usr/lib.
# INFO: NCO stub function for nc_inq_filter_avail() reports an inquiry on filter availability of HDF5 filter ID = 32001. Stub function employed because libnetcdf.a does not contain nc_inq_filter_avail(). Please rebuild NCO against netCDF library version 4.9.0 (released ~20220601) or later to support the capability to find and call filters besides DEFLATE, Shuffle, and Fletcher32.
# Exiting...
# ncks: WARNING nc_cdc_lst_bld() reports nco_inq_filter_avail() did not find Blosc filter (with HDF5 filter ID = 32001) as an HDF5 shared library filter. This is probably fixable because this filter is supported by all default installations of netCDF version 4.9.0 or higher. HINT: If you build netCDF from source, please be sure it was configured with the following options: "--enable-nczarr" and "--with-plugin-dir=${HDF5_PLUGIN_PATH}". The latter is especially important in netCDF 4.9.0. Also, please be sure the library for the missing filter (e.g., libzstd.a, libblosc.a, libbz2.a) is in an automatically searched directory, e.g., $LD_LIBRARY_PATH or /usr/lib.
# INFO: NCO stub function for nc_inq_filter_avail() reports an inquiry on filter availability of HDF5 filter ID = 307. Stub function employed because libnetcdf.a does not contain nc_inq_filter_avail(). Please rebuild NCO against netCDF library version 4.9.0 (released ~20220601) or later to support the capability to find and call filters besides DEFLATE, Shuffle, and Fletcher32.
# Exiting...
# ncks: WARNING nc_cdc_lst_bld() reports nco_inq_filter_avail() did not find Bzip2 filter (with HDF5 filter ID = 307) as an HDF5 shared library filter. This is probably fixable because this filter is supported by all default installations of netCDF version 4.9.0 or higher. HINT: If you build netCDF from source, please be sure it was configured with the following options: "--enable-nczarr" and "--with-plugin-dir=${HDF5_PLUGIN_PATH}". The latter is especially important in netCDF 4.9.0. Also, please be sure the library for the missing filter (e.g., libzstd.a, libblosc.a, libbz2.a) is in an automatically searched directory, e.g., $LD_LIBRARY_PATH or /usr/lib.
# INFO: NCO stub function for nc_inq_filter_avail() reports an inquiry on filter availability of HDF5 filter ID = 32015. Stub function employed because libnetcdf.a does not contain nc_inq_filter_avail(). Please rebuild NCO against netCDF library version 4.9.0 (released ~20220601) or later to support the capability to find and call filters besides DEFLATE, Shuffle, and Fletcher32.
# Exiting...
# ncks: WARNING nc_cdc_lst_bld() reports nco_inq_filter_avail() did not find Zstandard filter (with HDF5 filter ID = 32015) as an HDF5 shared library filter. This is probably fixable because this filter is supported by all default installations of netCDF version 4.9.0 or higher. HINT: If you build netCDF from source, please be sure it was configured with the following options: "--enable-nczarr" and "--with-plugin-dir=${HDF5_PLUGIN_PATH}". The latter is especially important in netCDF 4.9.0. Also, please be sure the library for the missing filter (e.g., libzstd.a, libblosc.a, libbz2.a) is in an automatically searched directory, e.g., $LD_LIBRARY_PATH or /usr/lib.
# INFO: NCO stub function for nc_inq_filter_avail() reports an inquiry on filter availability of HDF5 filter ID = 32001. Stub function employed because libnetcdf.a does not contain nc_inq_filter_avail(). Please rebuild NCO against netCDF library version 4.9.0 (released ~20220601) or later to support the capability to find and call filters besides DEFLATE, Shuffle, and Fletcher32.
# Exiting...
# ncks: WARNING nc_cdc_lst_bld() reports nco_inq_filter_avail() did not find Blosc filter (with HDF5 filter ID = 32001) as an HDF5 shared library filter. This is probably fixable because this filter is supported by all default installations of netCDF version 4.9.0 or higher. HINT: If you build netCDF from source, please be sure it was configured with the following options: "--enable-nczarr" and "--with-plugin-dir=${HDF5_PLUGIN_PATH}". The latter is especially important in netCDF 4.9.0. Also, please be sure the library for the missing filter (e.g., libzstd.a, libblosc.a, libbz2.a) is in an automatically searched directory, e.g., $LD_LIBRARY_PATH or /usr/lib.
# INFO: NCO stub function for nc_inq_filter_avail() reports an inquiry on filter availability of HDF5 filter ID = 307. Stub function employed because libnetcdf.a does not contain nc_inq_filter_avail(). Please rebuild NCO against netCDF library version 4.9.0 (released ~20220601) or later to support the capability to find and call filters besides DEFLATE, Shuffle, and Fletcher32.
# Exiting...
# ncks: WARNING nc_cdc_lst_bld() reports nco_inq_filter_avail() did not find Bzip2 filter (with HDF5 filter ID = 307) as an HDF5 shared library filter. This is probably fixable because this filter is supported by all default installations of netCDF version 4.9.0 or higher. HINT: If you build netCDF from source, please be sure it was configured with the following options: "--enable-nczarr" and "--with-plugin-dir=${HDF5_PLUGIN_PATH}". The latter is especially important in netCDF 4.9.0. Also, please be sure the library for the missing filter (e.g., libzstd.a, libblosc.a, libbz2.a) is in an automatically searched directory, e.g., $LD_LIBRARY_PATH or /usr/lib.
# INFO: NCO stub function for nc_inq_filter_avail() reports an inquiry on filter availability of HDF5 filter ID = 32015. Stub function employed because libnetcdf.a does not contain nc_inq_filter_avail(). Please rebuild NCO against netCDF library version 4.9.0 (released ~20220601) or later to support the capability to find and call filters besides DEFLATE, Shuffle, and Fletcher32.
# Exiting...
# ncks: WARNING nc_cdc_lst_bld() reports nco_inq_filter_avail() did not find Zstandard filter (with HDF5 filter ID = 32015) as an HDF5 shared library filter. This is probably fixable because this filter is supported by all default installations of netCDF version 4.9.0 or higher. HINT: If you build netCDF from source, please be sure it was configured with the following options: "--enable-nczarr" and "--with-plugin-dir=${HDF5_PLUGIN_PATH}". The latter is especially important in netCDF 4.9.0. Also, please be sure the library for the missing filter (e.g., libzstd.a, libblosc.a, libbz2.a) is in an automatically searched directory, e.g., $LD_LIBRARY_PATH or /usr/lib.
# INFO: NCO stub function for nc_inq_filter_avail() reports an inquiry on filter availability of HDF5 filter ID = 32001. Stub function employed because libnetcdf.a does not contain nc_inq_filter_avail(). Please rebuild NCO against netCDF library version 4.9.0 (released ~20220601) or later to support the capability to find and call filters besides DEFLATE, Shuffle, and Fletcher32.
# Exiting...
# ncks: WARNING nc_cdc_lst_bld() reports nco_inq_filter_avail() did not find Blosc filter (with HDF5 filter ID = 32001) as an HDF5 shared library filter. This is probably fixable because this filter is supported by all default installations of netCDF version 4.9.0 or higher. HINT: If you build netCDF from source, please be sure it was configured with the following options: "--enable-nczarr" and "--with-plugin-dir=${HDF5_PLUGIN_PATH}". The latter is especially important in netCDF 4.9.0. Also, please be sure the library for the missing filter (e.g., libzstd.a, libblosc.a, libbz2.a) is in an automatically searched directory, e.g., $LD_LIBRARY_PATH or /usr/lib.
# INFO: NCO stub function for nc_inq_filter_avail() reports an inquiry on filter availability of HDF5 filter ID = 307. Stub function employed because libnetcdf.a does not contain nc_inq_filter_avail(). Please rebuild NCO against netCDF library version 4.9.0 (released ~20220601) or later to support the capability to find and call filters besides DEFLATE, Shuffle, and Fletcher32.
# Exiting...
# ncks: WARNING nc_cdc_lst_bld() reports nco_inq_filter_avail() did not find Bzip2 filter (with HDF5 filter ID = 307) as an HDF5 shared library filter. This is probably fixable because this filter is supported by all default installations of netCDF version 4.9.0 or higher. HINT: If you build netCDF from source, please be sure it was configured with the following options: "--enable-nczarr" and "--with-plugin-dir=${HDF5_PLUGIN_PATH}". The latter is especially important in netCDF 4.9.0. Also, please be sure the library for the missing filter (e.g., libzstd.a, libblosc.a, libbz2.a) is in an automatically searched directory, e.g., $LD_LIBRARY_PATH or /usr/lib.
# INFO: NCO stub function for nc_inq_filter_avail() reports an inquiry on filter availability of HDF5 filter ID = 32015. Stub function employed because libnetcdf.a does not contain nc_inq_filter_avail(). Please rebuild NCO against netCDF library version 4.9.0 (released ~20220601) or later to support the capability to find and call filters besides DEFLATE, Shuffle, and Fletcher32.
# Exiting...
# ncks: WARNING nc_cdc_lst_bld() reports nco_inq_filter_avail() did not find Zstandard filter (with HDF5 filter ID = 32015) as an HDF5 shared library filter. This is probably fixable because this filter is supported by all default installations of netCDF version 4.9.0 or higher. HINT: If you build netCDF from source, please be sure it was configured with the following options: "--enable-nczarr" and "--with-plugin-dir=${HDF5_PLUGIN_PATH}". The latter is especially important in netCDF 4.9.0. Also, please be sure the library for the missing filter (e.g., libzstd.a, libblosc.a, libbz2.a) is in an automatically searched directory, e.g., $LD_LIBRARY_PATH or /usr/lib.
# INFO: NCO stub function for nc_inq_filter_avail() reports an inquiry on filter availability of HDF5 filter ID = 32001. Stub function employed because libnetcdf.a does not contain nc_inq_filter_avail(). Please rebuild NCO against netCDF library version 4.9.0 (released ~20220601) or later to support the capability to find and call filters besides DEFLATE, Shuffle, and Fletcher32.
# Exiting...
# ncks: WARNING nc_cdc_lst_bld() reports nco_inq_filter_avail() did not find Blosc filter (with HDF5 filter ID = 32001) as an HDF5 shared library filter. This is probably fixable because this filter is supported by all default installations of netCDF version 4.9.0 or higher. HINT: If you build netCDF from source, please be sure it was configured with the following options: "--enable-nczarr" and "--with-plugin-dir=${HDF5_PLUGIN_PATH}". The latter is especially important in netCDF 4.9.0. Also, please be sure the library for the missing filter (e.g., libzstd.a, libblosc.a, libbz2.a) is in an automatically searched directory, e.g., $LD_LIBRARY_PATH or /usr/lib.
# INFO: NCO stub function for nc_inq_filter_avail() reports an inquiry on filter availability of HDF5 filter ID = 307. Stub function employed because libnetcdf.a does not contain nc_inq_filter_avail(). Please rebuild NCO against netCDF library version 4.9.0 (released ~20220601) or later to support the capability to find and call filters besides DEFLATE, Shuffle, and Fletcher32.
# Exiting...
# ...
# INFO: NCO stub function for nc_inq_filter_avail() reports an inquiry on filter availability of HDF5 filter ID = 307. Stub function employed because libnetcdf.a does not contain nc_inq_filter_avail(). Please rebuild NCO against netCDF library version 4.9.0 (released ~20220601) or later to support the capability to find and call filters besides DEFLATE, Shuffle, and Fletcher32.
# Exiting...
# ncks: WARNING nc_cdc_lst_bld() reports nco_inq_filter_avail() did not find Bzip2 filter (with HDF5 filter ID = 307) as an HDF5 shared library filter. This is probably fixable because this filter is supported by all default installations of netCDF version 4.9.0 or higher. HINT: If you build netCDF from source, please be sure it was configured with the following options: "--enable-nczarr" and "--with-plugin-dir=${HDF5_PLUGIN_PATH}". The latter is especially important in netCDF 4.9.0. Also, please be sure the library for the missing filter (e.g., libzstd.a, libblosc.a, libbz2.a) is in an automatically searched directory, e.g., $LD_LIBRARY_PATH or /usr/lib.
# INFO: NCO stub function for nc_inq_filter_avail() reports an inquiry on filter availability of HDF5 filter ID = 32015. Stub function employed because libnetcdf.a does not contain nc_inq_filter_avail(). Please rebuild NCO against netCDF library version 4.9.0 (released ~20220601) or later to support the capability to find and call filters besides DEFLATE, Shuffle, and Fletcher32.
# Exiting...
# ncks: WARNING nc_cdc_lst_bld() reports nco_inq_filter_avail() did not find Zstandard filter (with HDF5 filter ID = 32015) as an HDF5 shared library filter. This is probably fixable because this filter is supported by all default installations of netCDF version 4.9.0 or higher. HINT: If you build netCDF from source, please be sure it was configured with the following options: "--enable-nczarr" and "--with-plugin-dir=${HDF5_PLUGIN_PATH}". The latter is especially important in netCDF 4.9.0. Also, please be sure the library for the missing filter (e.g., libzstd.a, libblosc.a, libbz2.a) is in an automatically searched directory, e.g., $LD_LIBRARY_PATH or /usr/lib.
# INFO: NCO stub function for nc_inq_filter_avail() reports an inquiry on filter availability of HDF5 filter ID = 32001. Stub function employed because libnetcdf.a does not contain nc_inq_filter_avail(). Please rebuild NCO against netCDF library version 4.9.0 (released ~20220601) or later to support the capability to find and call filters besides DEFLATE, Shuffle, and Fletcher32.
# Exiting...
# ncks: WARNING nc_cdc_lst_bld() reports nco_inq_filter_avail() did not find Blosc filter (with HDF5 filter ID = 32001) as an HDF5 shared library filter. This is probably fixable because this filter is supported by all default installations of netCDF version 4.9.0 or higher. HINT: If you build netCDF from source, please be sure it was configured with the following options: "--enable-nczarr" and "--with-plugin-dir=${HDF5_PLUGIN_PATH}". The latter is especially important in netCDF 4.9.0. Also, please be sure the library for the missing filter (e.g., libzstd.a, libblosc.a, libbz2.a) is in an automatically searched directory, e.g., $LD_LIBRARY_PATH or /usr/lib.
# INFO: NCO stub function for nc_inq_filter_avail() reports an inquiry on filter availability of HDF5 filter ID = 307. Stub function employed because libnetcdf.a does not contain nc_inq_filter_avail(). Please rebuild NCO against netCDF library version 4.9.0 (released ~20220601) or later to support the capability to find and call filters besides DEFLATE, Shuffle, and Fletcher32.
# Exiting...
# ncks: WARNING nc_cdc_lst_bld() reports nco_inq_filter_avail() did not find Bzip2 filter (with HDF5 filter ID = 307) as an HDF5 shared library filter. This is probably fixable because this filter is supported by all default installations of netCDF version 4.9.0 or higher. HINT: If you build netCDF from source, please be sure it was configured with the following options: "--enable-nczarr" and "--with-plugin-dir=${HDF5_PLUGIN_PATH}". The latter is especially important in netCDF 4.9.0. Also, please be sure the library for the missing filter (e.g., libzstd.a, libblosc.a, libbz2.a) is in an automatically searched directory, e.g., $LD_LIBRARY_PATH or /usr/lib.
# INFO: NCO stub function for nc_inq_filter_avail() reports an inquiry on filter availability of HDF5 filter ID = 32015. Stub function employed because libnetcdf.a does not contain nc_inq_filter_avail(). Please rebuild NCO against netCDF library version 4.9.0 (released ~20220601) or later to support the capability to find and call filters besides DEFLATE, Shuffle, and Fletcher32.
# Exiting...
# ncks: WARNING nc_cdc_lst_bld() reports nco_inq_filter_avail() did not find Zstandard filter (with HDF5 filter ID = 32015) as an HDF5 shared library filter. This is probably fixable because this filter is supported by all default installations of netCDF version 4.9.0 or higher. HINT: If you build netCDF from source, please be sure it was configured with the following options: "--enable-nczarr" and "--with-plugin-dir=${HDF5_PLUGIN_PATH}". The latter is especially important in netCDF 4.9.0. Also, please be sure the library for the missing filter (e.g., libzstd.a, libblosc.a, libbz2.a) is in an automatically searched directory, e.g., $LD_LIBRARY_PATH or /usr/lib.
# INFO: NCO stub function for nc_inq_filter_avail() reports an inquiry on filter availability of HDF5 filter ID = 32001. Stub function employed because libnetcdf.a does not contain nc_inq_filter_avail(). Please rebuild NCO against netCDF library version 4.9.0 (released ~20220601) or later to support the capability to find and call filters besides DEFLATE, Shuffle, and Fletcher32.
# Exiting...
# ncks: WARNING nc_cdc_lst_bld() reports nco_inq_filter_avail() did not find Blosc filter (with HDF5 filter ID = 32001) as an HDF5 shared library filter. This is probably fixable because this filter is supported by all default installations of netCDF version 4.9.0 or higher. HINT: If you build netCDF from source, please be sure it was configured with the following options: "--enable-nczarr" and "--with-plugin-dir=${HDF5_PLUGIN_PATH}". The latter is especially important in netCDF 4.9.0. Also, please be sure the library for the missing filter (e.g., libzstd.a, libblosc.a, libbz2.a) is in an automatically searched directory, e.g., $LD_LIBRARY_PATH or /usr/lib.
# INFO: NCO stub function for nc_inq_filter_avail() reports an inquiry on filter availability of HDF5 filter ID = 307. Stub function employed because libnetcdf.a does not contain nc_inq_filter_avail(). Please rebuild NCO against netCDF library version 4.9.0 (released ~20220601) or later to support the capability to find and call filters besides DEFLATE, Shuffle, and Fletcher32.
# Exiting...
# ncks: WARNING nc_cdc_lst_bld() reports nco_inq_filter_avail() did not find Bzip2 filter (with HDF5 filter ID = 307) as an HDF5 shared library filter. This is probably fixable because this filter is supported by all default installations of netCDF version 4.9.0 or higher. HINT: If you build netCDF from source, please be sure it was configured with the following options: "--enable-nczarr" and "--with-plugin-dir=${HDF5_PLUGIN_PATH}". The latter is especially important in netCDF 4.9.0. Also, please be sure the library for the missing filter (e.g., libzstd.a, libblosc.a, libbz2.a) is in an automatically searched directory, e.g., $LD_LIBRARY_PATH or /usr/lib.
# INFO: NCO stub function for nc_inq_filter_avail() reports an inquiry on filter availability of HDF5 filter ID = 32015. Stub function employed because libnetcdf.a does not contain nc_inq_filter_avail(). Please rebuild NCO against netCDF library version 4.9.0 (released ~20220601) or later to support the capability to find and call filters besides DEFLATE, Shuffle, and Fletcher32.
# Exiting...
# ncks: WARNING nc_cdc_lst_bld() reports nco_inq_filter_avail() did not find Zstandard filter (with HDF5 filter ID = 32015) as an HDF5 shared library filter. This is probably fixable because this filter is supported by all default installations of netCDF version 4.9.0 or higher. HINT: If you build netCDF from source, please be sure it was configured with the following options: "--enable-nczarr" and "--with-plugin-dir=${HDF5_PLUGIN_PATH}". The latter is especially important in netCDF 4.9.0. Also, please be sure the library for the missing filter (e.g., libzstd.a, libblosc.a, libbz2.a) is in an automatically searched directory, e.g., $LD_LIBRARY_PATH or /usr/lib.
# INFO: NCO stub function for nc_inq_filter_avail() reports an inquiry on filter availability of HDF5 filter ID = 32001. Stub function employed because libnetcdf.a does not contain nc_inq_filter_avail(). Please rebuild NCO against netCDF library version 4.9.0 (released ~20220601) or later to support the capability to find and call filters besides DEFLATE, Shuffle, and Fletcher32.
# Exiting...
# ncks: WARNING nc_cdc_lst_bld() reports nco_inq_filter_avail() did not find Blosc filter (with HDF5 filter ID = 32001) as an HDF5 shared library filter. This is probably fixable because this filter is supported by all default installations of netCDF version 4.9.0 or higher. HINT: If you build netCDF from source, please be sure it was configured with the following options: "--enable-nczarr" and "--with-plugin-dir=${HDF5_PLUGIN_PATH}". The latter is especially important in netCDF 4.9.0. Also, please be sure the library for the missing filter (e.g., libzstd.a, libblosc.a, libbz2.a) is in an automatically searched directory, e.g., $LD_LIBRARY_PATH or /usr/lib.
# INFO: NCO stub function for nc_inq_filter_avail() reports an inquiry on filter availability of HDF5 filter ID = 307. Stub function employed because libnetcdf.a does not contain nc_inq_filter_avail(). Please rebuild NCO against netCDF library version 4.9.0 (released ~20220601) or later to support the capability to find and call filters besides DEFLATE, Shuffle, and Fletcher32.
# Exiting...
# ncks: WARNING nc_cdc_lst_bld() reports nco_inq_filter_avail() did not find Bzip2 filter (with HDF5 filter ID = 307) as an HDF5 shared library filter. This is probably fixable because this filter is supported by all default installations of netCDF version 4.9.0 or higher. HINT: If you build netCDF from source, please be sure it was configured with the following options: "--enable-nczarr" and "--with-plugin-dir=${HDF5_PLUGIN_PATH}". The latter is especially important in netCDF 4.9.0. Also, please be sure the library for the missing filter (e.g., libzstd.a, libblosc.a, libbz2.a) is in an automatically searched directory, e.g., $LD_LIBRARY_PATH or /usr/lib.
# INFO: NCO stub function for nc_inq_filter_avail() reports an inquiry on filter availability of HDF5 filter ID = 32015. Stub function employed because libnetcdf.a does not contain nc_inq_filter_avail(). Please rebuild NCO against netCDF library version 4.9.0 (released ~20220601) or later to support the capability to find and call filters besides DEFLATE, Shuffle, and Fletcher32.
# Exiting...
# ncks: WARNING nc_cdc_lst_bld() reports nco_inq_filter_avail() did not find Zstandard filter (with HDF5 filter ID = 32015) as an HDF5 shared library filter. This is probably fixable because this filter is supported by all default installations of netCDF version 4.9.0 or higher. HINT: If you build netCDF from source, please be sure it was configured with the following options: "--enable-nczarr" and "--with-plugin-dir=${HDF5_PLUGIN_PATH}". The latter is especially important in netCDF 4.9.0. Also, please be sure the library for the missing filter (e.g., libzstd.a, libblosc.a, libbz2.a) is in an automatically searched directory, e.g., $LD_LIBRARY_PATH or /usr/lib.
# INFO: NCO stub function for nc_inq_filter_avail() reports an inquiry on filter availability of HDF5 filter ID = 32001. Stub function employed because libnetcdf.a does not contain nc_inq_filter_avail(). Please rebuild NCO against netCDF library version 4.9.0 (released ~20220601) or later to support the capability to find and call filters besides DEFLATE, Shuffle, and Fletcher32.
# Exiting...
# ncks: WARNING nc_cdc_lst_bld() reports nco_inq_filter_avail() did not find Blosc filter (with HDF5 filter ID = 32001) as an HDF5 shared library filter. This is probably fixable because this filter is supported by all default installations of netCDF version 4.9.0 or higher. HINT: If you build netCDF from source, please be sure it was configured with the following options: "--enable-nczarr" and "--with-plugin-dir=${HDF5_PLUGIN_PATH}". The latter is especially important in netCDF 4.9.0. Also, please be sure the library for the missing filter (e.g., libzstd.a, libblosc.a, libbz2.a) is in an automatically searched directory, e.g., $LD_LIBRARY_PATH or /usr/lib.
# INFO: NCO stub function for nc_inq_filter_avail() reports an inquiry on filter availability of HDF5 filter ID = 307. Stub function employed because libnetcdf.a does not contain nc_inq_filter_avail(). Please rebuild NCO against netCDF library version 4.9.0 (released ~20220601) or later to support the capability to find and call filters besides DEFLATE, Shuffle, and Fletcher32.
# Exiting...
# ncks: WARNING nc_cdc_lst_bld() reports nco_inq_filter_avail() did not find Bzip2 filter (with HDF5 filter ID = 307) as an HDF5 shared library filter. This is probably fixable because this filter is supported by all default installations of netCDF version 4.9.0 or higher. HINT: If you build netCDF from source, please be sure it was configured with the following options: "--enable-nczarr" and "--with-plugin-dir=${HDF5_PLUGIN_PATH}". The latter is especially important in netCDF 4.9.0. Also, please be sure the library for the missing filter (e.g., libzstd.a, libblosc.a, libbz2.a) is in an automatically searched directory, e.g., $LD_LIBRARY_PATH or /usr/lib.
# INFO: NCO stub function for nc_inq_filter_avail() reports an inquiry on filter availability of HDF5 filter ID = 32015. Stub function employed because libnetcdf.a does not contain nc_inq_filter_avail(). Please rebuild NCO against netCDF library version 4.9.0 (released ~20220601) or later to support the capability to find and call filters besides DEFLATE, Shuffle, and Fletcher32.
# Exiting...
# ncks: WARNING nc_cdc_lst_bld() reports nco_inq_filter_avail() did not find Zstandard filter (with HDF5 filter ID = 32015) as an HDF5 shared library filter. This is probably fixable because this filter is supported by all default installations of netCDF version 4.9.0 or higher. HINT: If you build netCDF from source, please be sure it was configured with the following options: "--enable-nczarr" and "--with-plugin-dir=${HDF5_PLUGIN_PATH}". The latter is especially important in netCDF 4.9.0. Also, please be sure the library for the missing filter (e.g., libzstd.a, libblosc.a, libbz2.a) is in an automatically searched directory, e.g., $LD_LIBRARY_PATH or /usr/lib.
# INFO: NCO stub function for nc_inq_filter_avail() reports an inquiry on filter availability of HDF5 filter ID = 32001. Stub function employed because libnetcdf.a does not contain nc_inq_filter_avail(). Please rebuild NCO against netCDF library version 4.9.0 (released ~20220601) or later to support the capability to find and call filters besides DEFLATE, Shuffle, and Fletcher32.
# Exiting...
# ncks: WARNING nc_cdc_lst_bld() reports nco_inq_filter_avail() did not find Blosc filter (with HDF5 filter ID = 32001) as an HDF5 shared library filter. This is probably fixable because this filter is supported by all default installations of netCDF version 4.9.0 or higher. HINT: If you build netCDF from source, please be sure it was configured with the following options: "--enable-nczarr" and "--with-plugin-dir=${HDF5_PLUGIN_PATH}". The latter is especially important in netCDF 4.9.0. Also, please be sure the library for the missing filter (e.g., libzstd.a, libblosc.a, libbz2.a) is in an automatically searched directory, e.g., $LD_LIBRARY_PATH or /usr/lib.

# %% [markdown]
# 4. Concatenates all ```.nc4``` files in ```IMERG_mm_month``` folder into one ```.nc4``` file named ```IMERG_concat.nc4``` using ```ncrcat``` command

# %%
# !ncrcat -h *.nc4 IMERG_concat.nc4
# Out:
# INFO: NCO stub function for nc_inq_filter_avail() reports an inquiry on filter availability of HDF5 filter ID = 307. Stub function employed because libnetcdf.a does not contain nc_inq_filter_avail(). Please rebuild NCO against netCDF library version 4.9.0 (released ~20220601) or later to support the capability to find and call filters besides DEFLATE, Shuffle, and Fletcher32.
# Exiting...
# ncrcat: WARNING nc_cdc_lst_bld() reports nco_inq_filter_avail() did not find Bzip2 filter (with HDF5 filter ID = 307) as an HDF5 shared library filter. This is probably fixable because this filter is supported by all default installations of netCDF version 4.9.0 or higher. HINT: If you build netCDF from source, please be sure it was configured with the following options: "--enable-nczarr" and "--with-plugin-dir=${HDF5_PLUGIN_PATH}". The latter is especially important in netCDF 4.9.0. Also, please be sure the library for the missing filter (e.g., libzstd.a, libblosc.a, libbz2.a) is in an automatically searched directory, e.g., $LD_LIBRARY_PATH or /usr/lib.
# INFO: NCO stub function for nc_inq_filter_avail() reports an inquiry on filter availability of HDF5 filter ID = 32015. Stub function employed because libnetcdf.a does not contain nc_inq_filter_avail(). Please rebuild NCO against netCDF library version 4.9.0 (released ~20220601) or later to support the capability to find and call filters besides DEFLATE, Shuffle, and Fletcher32.
# Exiting...
# ncrcat: WARNING nc_cdc_lst_bld() reports nco_inq_filter_avail() did not find Zstandard filter (with HDF5 filter ID = 32015) as an HDF5 shared library filter. This is probably fixable because this filter is supported by all default installations of netCDF version 4.9.0 or higher. HINT: If you build netCDF from source, please be sure it was configured with the following options: "--enable-nczarr" and "--with-plugin-dir=${HDF5_PLUGIN_PATH}". The latter is especially important in netCDF 4.9.0. Also, please be sure the library for the missing filter (e.g., libzstd.a, libblosc.a, libbz2.a) is in an automatically searched directory, e.g., $LD_LIBRARY_PATH or /usr/lib.
# INFO: NCO stub function for nc_inq_filter_avail() reports an inquiry on filter availability of HDF5 filter ID = 32001. Stub function employed because libnetcdf.a does not contain nc_inq_filter_avail(). Please rebuild NCO against netCDF library version 4.9.0 (released ~20220601) or later to support the capability to find and call filters besides DEFLATE, Shuffle, and Fletcher32.
# Exiting...
# ncrcat: WARNING nc_cdc_lst_bld() reports nco_inq_filter_avail() did not find Blosc filter (with HDF5 filter ID = 32001) as an HDF5 shared library filter. This is probably fixable because this filter is supported by all default installations of netCDF version 4.9.0 or higher. HINT: If you build netCDF from source, please be sure it was configured with the following options: "--enable-nczarr" and "--with-plugin-dir=${HDF5_PLUGIN_PATH}". The latter is especially important in netCDF 4.9.0. Also, please be sure the library for the missing filter (e.g., libzstd.a, libblosc.a, libbz2.a) is in an automatically searched directory, e.g., $LD_LIBRARY_PATH or /usr/lib.

# %% [markdown]
# 5. Check the header

# %%
# !ncdump -h IMERG_concat.nc4
# Out:
# netcdf IMERG_concat {
# dimensions:
# 	lat = 102 ;
# 	lon = 119 ;
# 	time = UNLIMITED ; // (266 currently)
# 	bnds = 2 ;
# variables:
# 	float lat(lat) ;
# 		lat:standard_name = "latitude" ;
# 		lat:long_name = "Latitude" ;
# 		lat:units = "degrees_north" ;
# 		lat:axis = "Y" ;
# 	float lon(lon) ;
# 		lon:standard_name = "longitude" ;
# 		lon:long_name = "Longitude" ;
# 		lon:units = "degrees_east" ;
# 		lon:axis = "X" ;
# 	float precipitationCal(time, lon, lat) ;
# 		precipitationCal:long_name = "Daily accumulated precipitation (combined microwave-IR) estimate" ;
# 		precipitationCal:units = "mm" ;
# 		precipitationCal:_FillValue = -9999.9f ;
# 		precipitationCal:missing_value = -9999.9f ;
# 		precipitationCal:cell_methods = "time: mean time: sum" ;
# 	double time(time) ;
# 		time:standard_name = "time" ;
# 		time:bounds = "time_bnds" ;
# 		time:units = "days since 1970-01-01 00:00:00Z" ;
# 		time:calendar = "standard" ;
# 		time:axis = "T" ;
# 		time:cell_methods = "time: mean" ;
# 	double time_bnds(time, bnds) ;
# 		time_bnds:cell_methods = "time: mean" ;
#
# // global attributes:
# 		:CDI = "Climate Data Interface version 1.9.8 (https://mpimet.mpg.de/cdi)" ;
# 		:Conventions = "CF-1.6" ;
# 		:BeginDate = "2000-06-01" ;
# 		:BeginTime = "00:00:00.000Z" ;
# 		:EndDate = "2000-06-01" ;
# 		:EndTime = "23:59:59.999Z" ;
# 		:FileHeader = "StartGranuleDateTime=2000-06-01T00:00:00.000Z;\nStopGranuleDateTime=2000-06-01T23:59:59.999Z" ;
# 		:InputPointer = "3B-HHR-L.MS.MRG.3IMERG.20000601-S000000-E002959.0000.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S003000-E005959.0030.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S010000-E012959.0060.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S013000-E015959.0090.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S020000-E022959.0120.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S023000-E025959.0150.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S030000-E032959.0180.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S033000-E035959.0210.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S040000-E042959.0240.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S043000-E045959.0270.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S050000-E052959.0300.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S053000-E055959.0330.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S060000-E062959.0360.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S063000-E065959.0390.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S070000-E072959.0420.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S073000-E075959.0450.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S080000-E082959.0480.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S083000-E085959.0510.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S090000-E092959.0540.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S093000-E095959.0570.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S100000-E102959.0600.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S103000-E105959.0630.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S110000-E112959.0660.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S113000-E115959.0690.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S120000-E122959.0720.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S123000-E125959.0750.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S130000-E132959.0780.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S133000-E135959.0810.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S140000-E142959.0840.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S143000-E145959.0870.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S150000-E152959.0900.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S153000-E155959.0930.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S160000-E162959.0960.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S163000-E165959.0990.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S170000-E172959.1020.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S173000-E175959.1050.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S180000-E182959.1080.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S183000-E185959.1110.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S190000-E192959.1140.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S193000-E195959.1170.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S200000-E202959.1200.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S203000-E205959.1230.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S210000-E212959.1260.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S213000-E215959.1290.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S220000-E222959.1320.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S223000-E225959.1350.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S230000-E232959.1380.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S233000-E235959.1410.V06B.HDF5" ;
# 		:title = "GPM IMERG Late Precipitation L3 1 day 0.1 degree x 0.1 degree (GPM_3IMERGDL)" ;
# 		:DOI = "10.5067/GPM/IMERGDL/DAY/06" ;
# 		:ProductionTime = "2019-08-07T19:51:27.150Z" ;
# 		:history_L34RS = "\'Created by L34RS v1.4.3 @ NASA GES DISC on July 21 2022 20:34:27. Spatial: 21.885 33.75 -18.3 -8.104. Variables: precipitationCal\'" ;
# 		:CDO = "Climate Data Operators version 1.9.8 (https://mpimet.mpg.de/cdo)" ;
# 		:history = "Sat Jul 23 06:52:38 2022: ncks --mk_rec_dmn time 3B-DAY-L.MS.MRG.3IMERG.20000601-S000000-E235959.V06.nc4.SUB.nc4 -o 3B-DAY-L.MS.MRG.3IMERG.20000601-S000000-E235959.V06.nc4.SUB.nc4.TMP\nFri Jul 22 21:46:58 2022: ncrcat /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000601-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000602-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000603-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000604-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000605-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000606-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000607-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000608-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000609-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000610-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000611-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000612-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000613-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000614-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000615-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000616-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000617-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000618-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000619-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000620-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000621-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000622-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000623-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000624-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000625-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000626-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000627-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000628-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000629-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000630-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_concat/3B-DAY-L.MS.MRG.3IMERG.20000601-S000000-E235959.V06.nc4.SUB.nc4" ;
# 		:NCO = "netCDF Operators version 5.1.0 (Homepage = http://nco.sf.net, Code = http://github.com/nco/nco)" ;
# }

# %% [markdown]
# 6. And the variables for ```precipitation``` is ```time,lon,lat``` but SPI calculation required:
#     - ```lat,lon,time``` or
#     - ```time,lat,lon```

# %% [markdown]
# 7. Let's re-order the variables into ```time,lat,lon``` using ```ncpdq``` command, to be able running the SPI code in Python

# %%
# !ncpdq -a time,lat,lon IMERG_concat.nc4 IMERG_concat_ncpdq0.nc4
# Out:
# INFO: NCO stub function for nc_inq_filter_avail() reports an inquiry on filter availability of HDF5 filter ID = 307. Stub function employed because libnetcdf.a does not contain nc_inq_filter_avail(). Please rebuild NCO against netCDF library version 4.9.0 (released ~20220601) or later to support the capability to find and call filters besides DEFLATE, Shuffle, and Fletcher32.
# Exiting...
# ncpdq: WARNING nc_cdc_lst_bld() reports nco_inq_filter_avail() did not find Bzip2 filter (with HDF5 filter ID = 307) as an HDF5 shared library filter. This is probably fixable because this filter is supported by all default installations of netCDF version 4.9.0 or higher. HINT: If you build netCDF from source, please be sure it was configured with the following options: "--enable-nczarr" and "--with-plugin-dir=${HDF5_PLUGIN_PATH}". The latter is especially important in netCDF 4.9.0. Also, please be sure the library for the missing filter (e.g., libzstd.a, libblosc.a, libbz2.a) is in an automatically searched directory, e.g., $LD_LIBRARY_PATH or /usr/lib.
# INFO: NCO stub function for nc_inq_filter_avail() reports an inquiry on filter availability of HDF5 filter ID = 32015. Stub function employed because libnetcdf.a does not contain nc_inq_filter_avail(). Please rebuild NCO against netCDF library version 4.9.0 (released ~20220601) or later to support the capability to find and call filters besides DEFLATE, Shuffle, and Fletcher32.
# Exiting...
# ncpdq: WARNING nc_cdc_lst_bld() reports nco_inq_filter_avail() did not find Zstandard filter (with HDF5 filter ID = 32015) as an HDF5 shared library filter. This is probably fixable because this filter is supported by all default installations of netCDF version 4.9.0 or higher. HINT: If you build netCDF from source, please be sure it was configured with the following options: "--enable-nczarr" and "--with-plugin-dir=${HDF5_PLUGIN_PATH}". The latter is especially important in netCDF 4.9.0. Also, please be sure the library for the missing filter (e.g., libzstd.a, libblosc.a, libbz2.a) is in an automatically searched directory, e.g., $LD_LIBRARY_PATH or /usr/lib.
# INFO: NCO stub function for nc_inq_filter_avail() reports an inquiry on filter availability of HDF5 filter ID = 32001. Stub function employed because libnetcdf.a does not contain nc_inq_filter_avail(). Please rebuild NCO against netCDF library version 4.9.0 (released ~20220601) or later to support the capability to find and call filters besides DEFLATE, Shuffle, and Fletcher32.
# Exiting...
# ncpdq: WARNING nc_cdc_lst_bld() reports nco_inq_filter_avail() did not find Blosc filter (with HDF5 filter ID = 32001) as an HDF5 shared library filter. This is probably fixable because this filter is supported by all default installations of netCDF version 4.9.0 or higher. HINT: If you build netCDF from source, please be sure it was configured with the following options: "--enable-nczarr" and "--with-plugin-dir=${HDF5_PLUGIN_PATH}". The latter is especially important in netCDF 4.9.0. Also, please be sure the library for the missing filter (e.g., libzstd.a, libblosc.a, libbz2.a) is in an automatically searched directory, e.g., $LD_LIBRARY_PATH or /usr/lib.

# %% [markdown]
# 8. Check again the header for ```IMERG_concat_ncpdq0.nc4```

# %%
# !ncdump -h IMERG_concat_ncpdq0.nc4
# Out:
# netcdf IMERG_concat_ncpdq0 {
# dimensions:
# 	lat = 102 ;
# 	lon = 119 ;
# 	time = UNLIMITED ; // (266 currently)
# 	bnds = 2 ;
# variables:
# 	float lat(lat) ;
# 		lat:standard_name = "latitude" ;
# 		lat:long_name = "Latitude" ;
# 		lat:units = "degrees_north" ;
# 		lat:axis = "Y" ;
# 	float lon(lon) ;
# 		lon:standard_name = "longitude" ;
# 		lon:long_name = "Longitude" ;
# 		lon:units = "degrees_east" ;
# 		lon:axis = "X" ;
# 	float precipitationCal(time, lat, lon) ;
# 		precipitationCal:long_name = "Daily accumulated precipitation (combined microwave-IR) estimate" ;
# 		precipitationCal:units = "mm" ;
# 		precipitationCal:_FillValue = -9999.9f ;
# 		precipitationCal:missing_value = -9999.9f ;
# 		precipitationCal:cell_methods = "time: mean time: sum" ;
# 	double time(time) ;
# 		time:standard_name = "time" ;
# 		time:bounds = "time_bnds" ;
# 		time:units = "days since 1970-01-01 00:00:00Z" ;
# 		time:calendar = "standard" ;
# 		time:axis = "T" ;
# 		time:cell_methods = "time: mean" ;
# 	double time_bnds(time, bnds) ;
# 		time_bnds:cell_methods = "time: mean" ;
#
# // global attributes:
# 		:CDI = "Climate Data Interface version 1.9.8 (https://mpimet.mpg.de/cdi)" ;
# 		:Conventions = "CF-1.6" ;
# 		:BeginDate = "2000-06-01" ;
# 		:BeginTime = "00:00:00.000Z" ;
# 		:EndDate = "2000-06-01" ;
# 		:EndTime = "23:59:59.999Z" ;
# 		:FileHeader = "StartGranuleDateTime=2000-06-01T00:00:00.000Z;\nStopGranuleDateTime=2000-06-01T23:59:59.999Z" ;
# 		:InputPointer = "3B-HHR-L.MS.MRG.3IMERG.20000601-S000000-E002959.0000.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S003000-E005959.0030.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S010000-E012959.0060.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S013000-E015959.0090.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S020000-E022959.0120.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S023000-E025959.0150.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S030000-E032959.0180.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S033000-E035959.0210.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S040000-E042959.0240.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S043000-E045959.0270.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S050000-E052959.0300.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S053000-E055959.0330.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S060000-E062959.0360.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S063000-E065959.0390.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S070000-E072959.0420.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S073000-E075959.0450.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S080000-E082959.0480.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S083000-E085959.0510.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S090000-E092959.0540.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S093000-E095959.0570.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S100000-E102959.0600.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S103000-E105959.0630.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S110000-E112959.0660.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S113000-E115959.0690.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S120000-E122959.0720.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S123000-E125959.0750.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S130000-E132959.0780.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S133000-E135959.0810.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S140000-E142959.0840.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S143000-E145959.0870.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S150000-E152959.0900.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S153000-E155959.0930.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S160000-E162959.0960.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S163000-E165959.0990.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S170000-E172959.1020.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S173000-E175959.1050.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S180000-E182959.1080.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S183000-E185959.1110.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S190000-E192959.1140.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S193000-E195959.1170.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S200000-E202959.1200.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S203000-E205959.1230.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S210000-E212959.1260.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S213000-E215959.1290.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S220000-E222959.1320.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S223000-E225959.1350.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S230000-E232959.1380.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S233000-E235959.1410.V06B.HDF5" ;
# 		:title = "GPM IMERG Late Precipitation L3 1 day 0.1 degree x 0.1 degree (GPM_3IMERGDL)" ;
# 		:DOI = "10.5067/GPM/IMERGDL/DAY/06" ;
# 		:ProductionTime = "2019-08-07T19:51:27.150Z" ;
# 		:history_L34RS = "\'Created by L34RS v1.4.3 @ NASA GES DISC on July 21 2022 20:34:27. Spatial: 21.885 33.75 -18.3 -8.104. Variables: precipitationCal\'" ;
# 		:CDO = "Climate Data Operators version 1.9.8 (https://mpimet.mpg.de/cdo)" ;
# 		:history = "Sat Jul 23 06:53:35 2022: ncpdq -a time,lat,lon IMERG_concat.nc4 IMERG_concat_ncpdq0.nc4\nSat Jul 23 06:52:38 2022: ncks --mk_rec_dmn time 3B-DAY-L.MS.MRG.3IMERG.20000601-S000000-E235959.V06.nc4.SUB.nc4 -o 3B-DAY-L.MS.MRG.3IMERG.20000601-S000000-E235959.V06.nc4.SUB.nc4.TMP\nFri Jul 22 21:46:58 2022: ncrcat /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000601-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000602-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000603-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000604-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000605-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000606-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000607-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000608-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000609-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000610-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000611-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000612-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000613-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000614-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000615-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000616-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000617-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000618-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000619-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000620-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000621-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000622-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000623-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000624-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000625-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000626-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000627-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000628-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000629-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000630-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMER ...
# 		:NCO = "netCDF Operators version 5.1.0 (Homepage = http://nco.sf.net, Code = http://github.com/nco/nco)" ;
# }

# %% [markdown]
# 9. And the variables for ```precipitation``` is ```time,lat,lon```, it means the result is correct. But the unit still in ```mm/hr```, we need to edit to ```mm```

# %% [markdown]
# 10. SPI code does not recognized unit ```mm/day``` or ```mm/month```, we need to edit into ```mm```. To edit the unit attribute names, we will use ```ncatted``` command, follow below code:

# %%
# !ncatted -a units,precipitationCal,modify,c,'mm' IMERG_concat_ncpdq0.nc4 IMERG_concat_ncpdq1.nc4

# %% [markdown]
# 11. Check again the header for IMERG_concat_ncpdq1.nc4, to make sure everything is correct.

# %%
# !ncdump -h IMERG_concat_ncpdq1.nc4
# Out:
# netcdf IMERG_concat_ncpdq1 {
# dimensions:
# 	lat = 102 ;
# 	lon = 119 ;
# 	time = UNLIMITED ; // (266 currently)
# 	bnds = 2 ;
# variables:
# 	float lat(lat) ;
# 		lat:standard_name = "latitude" ;
# 		lat:long_name = "Latitude" ;
# 		lat:units = "degrees_north" ;
# 		lat:axis = "Y" ;
# 	float lon(lon) ;
# 		lon:standard_name = "longitude" ;
# 		lon:long_name = "Longitude" ;
# 		lon:units = "degrees_east" ;
# 		lon:axis = "X" ;
# 	float precipitationCal(time, lat, lon) ;
# 		precipitationCal:long_name = "Daily accumulated precipitation (combined microwave-IR) estimate" ;
# 		precipitationCal:units = "mm" ;
# 		precipitationCal:_FillValue = -9999.9f ;
# 		precipitationCal:missing_value = -9999.9f ;
# 		precipitationCal:cell_methods = "time: mean time: sum" ;
# 	double time(time) ;
# 		time:standard_name = "time" ;
# 		time:bounds = "time_bnds" ;
# 		time:units = "days since 1970-01-01 00:00:00Z" ;
# 		time:calendar = "standard" ;
# 		time:axis = "T" ;
# 		time:cell_methods = "time: mean" ;
# 	double time_bnds(time, bnds) ;
# 		time_bnds:cell_methods = "time: mean" ;
#
# // global attributes:
# 		:CDI = "Climate Data Interface version 1.9.8 (https://mpimet.mpg.de/cdi)" ;
# 		:Conventions = "CF-1.6" ;
# 		:BeginDate = "2000-06-01" ;
# 		:BeginTime = "00:00:00.000Z" ;
# 		:EndDate = "2000-06-01" ;
# 		:EndTime = "23:59:59.999Z" ;
# 		:FileHeader = "StartGranuleDateTime=2000-06-01T00:00:00.000Z;\nStopGranuleDateTime=2000-06-01T23:59:59.999Z" ;
# 		:InputPointer = "3B-HHR-L.MS.MRG.3IMERG.20000601-S000000-E002959.0000.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S003000-E005959.0030.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S010000-E012959.0060.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S013000-E015959.0090.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S020000-E022959.0120.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S023000-E025959.0150.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S030000-E032959.0180.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S033000-E035959.0210.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S040000-E042959.0240.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S043000-E045959.0270.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S050000-E052959.0300.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S053000-E055959.0330.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S060000-E062959.0360.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S063000-E065959.0390.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S070000-E072959.0420.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S073000-E075959.0450.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S080000-E082959.0480.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S083000-E085959.0510.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S090000-E092959.0540.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S093000-E095959.0570.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S100000-E102959.0600.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S103000-E105959.0630.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S110000-E112959.0660.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S113000-E115959.0690.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S120000-E122959.0720.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S123000-E125959.0750.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S130000-E132959.0780.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S133000-E135959.0810.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S140000-E142959.0840.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S143000-E145959.0870.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S150000-E152959.0900.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S153000-E155959.0930.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S160000-E162959.0960.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S163000-E165959.0990.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S170000-E172959.1020.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S173000-E175959.1050.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S180000-E182959.1080.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S183000-E185959.1110.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S190000-E192959.1140.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S193000-E195959.1170.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S200000-E202959.1200.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S203000-E205959.1230.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S210000-E212959.1260.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S213000-E215959.1290.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S220000-E222959.1320.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S223000-E225959.1350.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S230000-E232959.1380.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S233000-E235959.1410.V06B.HDF5" ;
# 		:title = "GPM IMERG Late Precipitation L3 1 day 0.1 degree x 0.1 degree (GPM_3IMERGDL)" ;
# 		:DOI = "10.5067/GPM/IMERGDL/DAY/06" ;
# 		:ProductionTime = "2019-08-07T19:51:27.150Z" ;
# 		:history_L34RS = "\'Created by L34RS v1.4.3 @ NASA GES DISC on July 21 2022 20:34:27. Spatial: 21.885 33.75 -18.3 -8.104. Variables: precipitationCal\'" ;
# 		:CDO = "Climate Data Operators version 1.9.8 (https://mpimet.mpg.de/cdo)" ;
# 		:NCO = "netCDF Operators version 5.1.0 (Homepage = http://nco.sf.net, Code = http://github.com/nco/nco)" ;
# 		:history = "Sat Jul 23 06:54:05 2022: ncatted -a units,precipitationCal,modify,c,mm IMERG_concat_ncpdq0.nc4 IMERG_concat_ncpdq1.nc4\nSat Jul 23 06:53:35 2022: ncpdq -a time,lat,lon IMERG_concat.nc4 IMERG_concat_ncpdq0.nc4\nSat Jul 23 06:52:38 2022: ncks --mk_rec_dmn time 3B-DAY-L.MS.MRG.3IMERG.20000601-S000000-E235959.V06.nc4.SUB.nc4 -o 3B-DAY-L.MS.MRG.3IMERG.20000601-S000000-E235959.V06.nc4.SUB.nc4.TMP\nFri Jul 22 21:46:58 2022: ncrcat /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000601-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000602-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000603-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000604-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000605-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000606-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000607-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000608-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000609-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000610-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000611-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000612-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000613-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000614-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000615-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000616-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000617-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000618-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000619-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000620-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000621-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000622-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000623-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000624-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000625-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000626-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000627-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000628-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_day/3B-DAY-L.MS.MRG.3IMERG.20000629-S000000-E235959.V06.nc4.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/IMER ...
# }

# %% [markdown]
# 12. And the ```units``` already in ```mm```

# %% [markdown]
# 13. Once this has completed the dataset can be used as input to this package for computing SPI. From above picture, some of the precipitation attribute are still wrong: ```DimensionNames``` and ```Units```. We can leave it as is, SPI code will only read ```units``` and ```variables``` ```precipitation(time,lat,lon)```

# %% [markdown]
# ## 4. Running SPI code

# %% [markdown]
# 1. We will use ```IMERG_concat_ncpdq1.nc4``` as ```input```, let's move this data to ```Input``` folder.
#     - Move using ```mv oldlocation newlocation``` command: ```mv /IMERG_mm_month/IMERG_concat_ncpdq1.nc4 /Input/IMERG_concat_ncpdq1.nc4```

# %%
# !mv /content/drive/MyDrive/IWMI/IMERG_DailyData/IMERG_mm_month/IMERG_concat_ncpdq1.nc4 /content/drive/MyDrive/IWMI/IMERG_DailyData/Input/IMERG_concat_ncpdq1.nc4

# %% [markdown]
# 2. Run the code

# %%
# new code
# !conda install -c anaconda numpy
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - numpy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     blas-1.0                   |         openblas          48 KB  anaconda
#     ca-certificates-2022.4.26  |       h06a4308_0         132 KB  anaconda
#     certifi-2022.6.15          |   py37h06a4308_0         156 KB  anaconda
#     conda-4.13.0               |   py37h06a4308_0         990 KB  anaconda
#     numpy-1.21.5               |   py37hf838250_3          10 KB  anaconda
#     numpy-base-1.21.5          |   py37h1e6e340_3         6.1 MB  anaconda
#     ------------------------------------------------------------
#                                            Total:         7.4 MB
#
# The following NEW packages will be INSTALLED:
#
#   blas               anaconda/linux-64::blas-1.0-openblas
#   numpy              anaconda/linux-64::numpy-1.21.5-py37hf838250_3
#   numpy-base         anaconda/linux-64::numpy-base-1.21.5-py37h1e6e340_3
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates    conda-forge::ca-certificates-2022.6.1~ --> anaconda::ca-certificates-2022.4.26-h06a4308_0
#   certifi            conda-forge::certifi-2022.6.15-py37h8~ --> anaconda::certifi-2022.6.15-py37h06a4308_0
#   conda              conda-forge::conda-4.13.0-py37h89c186~ --> anaconda::conda-4.13.0-py37h06a4308_0
#
#
#
# Downloading and Extracting Packages
# conda-4.13.0         | 990 KB    | : 100% 1.0/1 [00:00<00:00,  1.97it/s]
# certifi-2022.6.15    | 156 KB    | : 100% 1.0/1 [00:00<00:00, 16.49it/s]
# ca-certificates-2022 | 132 KB    | : 100% 1.0/1 [00:00<00:00, 16.91it/s]
# blas-1.0             | 48 KB     | : 100% 1.0/1 [00:00<00:00, 14.61it/s]
# numpy-base-1.21.5    | 6.1 MB    | : 100% 1.0/1 [00:02<00:00,  2.36s/it]
# numpy-1.21.5         | 10 KB     | : 100% 1.0/1 [00:00<00:00,  5.63it/s]
# done
# done
# done

# %%
# new code
# !conda upgrade numpy
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - numpy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _openmp_mutex-4.5          |            2_gnu          23 KB  conda-forge
#     brotlipy-0.7.0             |py37h540881e_1004         342 KB  conda-forge
#     charset-normalizer-2.1.0   |     pyhd8ed1ab_0          35 KB  conda-forge
#     colorama-0.4.5             |     pyhd8ed1ab_0          18 KB  conda-forge
#     conda-package-handling-1.8.1|   py37h540881e_1         1.0 MB  conda-forge
#     cryptography-37.0.4        |   py37h38fbfac_0         1.5 MB  conda-forge
#     idna-3.3                   |     pyhd8ed1ab_0          55 KB  conda-forge
#     ld_impl_linux-64-2.36.1    |       hea4e1c9_2         667 KB  conda-forge
#     numpy-1.21.6               |   py37h976b520_0         6.1 MB  conda-forge
#     pip-22.2                   |     pyhd8ed1ab_0         1.5 MB  conda-forge
#     pycosat-0.6.3              |py37h540881e_1010         107 KB  conda-forge
#     pycparser-2.21             |     pyhd8ed1ab_0         100 KB  conda-forge
#     pyopenssl-22.0.0           |     pyhd8ed1ab_0          49 KB  conda-forge
#     pysocks-1.7.1              |   py37h89c1867_5          28 KB  conda-forge
#     requests-2.28.1            |     pyhd8ed1ab_0          53 KB  conda-forge
#     ruamel_yaml-0.15.80        |py37h540881e_1007         259 KB  conda-forge
#     setuptools-63.2.0          |   py37h89c1867_0         1.4 MB  conda-forge
#     six-1.16.0                 |     pyh6c4a22f_0          14 KB  conda-forge
#     tqdm-4.64.0                |     pyhd8ed1ab_0          81 KB  conda-forge
#     urllib3-1.26.10            |     pyhd8ed1ab_0         101 KB  conda-forge
#     wheel-0.37.1               |     pyhd8ed1ab_0          31 KB  conda-forge
#     yaml-0.2.5                 |       h7f98852_2          87 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        13.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   charset-normalizer conda-forge/noarch::charset-normalizer-2.1.0-pyhd8ed1ab_0
#   colorama           conda-forge/noarch::colorama-0.4.5-pyhd8ed1ab_0
#
# The following packages will be REMOVED:
#
#   blas-1.0-openblas
#   chardet-4.0.0-py37h89c1867_1
#   cudatoolkit-11.1.1-ha002fc5_10
#   icu-68.1-h58526e2_0
#   libarchive-3.5.1-h3f442fb_1
#   libiconv-1.16-h516909a_0
#   libsolv-0.7.17-h780b84a_0
#   libxml2-2.9.10-h72842e0_3
#   lz4-c-1.9.3-h9c3ff4c_0
#   lzo-2.10-h516909a_1000
#   mamba-0.8.0-py37h7f483ca_0
#   numpy-base-1.21.5-py37h1e6e340_3
#   reproc-14.2.1-h36c2ea0_0
#   reproc-cpp-14.2.1-h58526e2_0
#   zstd-1.4.9-ha95c52a_0
#
# The following packages will be UPDATED:
#
#   _openmp_mutex                                   4.5-1_gnu --> 4.5-2_gnu
#   brotlipy                          0.7.0-py37h5e8e339_1001 --> 0.7.0-py37h540881e_1004
#   ca-certificates    anaconda::ca-certificates-2022.4.26-h~ --> conda-forge::ca-certificates-2022.6.15-ha878542_0
#   conda               anaconda::conda-4.13.0-py37h06a4308_0 --> conda-forge::conda-4.13.0-py37h89c1867_1
#   conda-package-han~                   1.7.2-py37hb5d75c8_0 --> 1.8.1-py37h540881e_1
#   cryptography                         3.4.5-py37h5d9358c_1 --> 37.0.4-py37h38fbfac_0
#   idna                                    2.10-pyh9f0ad1d_0 --> 3.3-pyhd8ed1ab_0
#   ld_impl_linux-64                        2.35.1-hea4e1c9_2 --> 2.36.1-hea4e1c9_2
#   numpy               anaconda::numpy-1.21.5-py37hf838250_3 --> conda-forge::numpy-1.21.6-py37h976b520_0
#   pip                                   21.0.1-pyhd8ed1ab_0 --> 22.2-pyhd8ed1ab_0
#   pycosat                           0.6.3-py37h5e8e339_1006 --> 0.6.3-py37h540881e_1010
#   pycparser                               2.20-pyh9f0ad1d_2 --> 2.21-pyhd8ed1ab_0
#   pyopenssl                             20.0.1-pyhd8ed1ab_0 --> 22.0.0-pyhd8ed1ab_0
#   pysocks                              1.7.1-py37h89c1867_3 --> 1.7.1-py37h89c1867_5
#   requests                              2.25.1-pyhd3deb0d_0 --> 2.28.1-pyhd8ed1ab_0
#   ruamel_yaml                     0.15.80-py37h5e8e339_1004 --> 0.15.80-py37h540881e_1007
#   setuptools                          49.6.0-py37h89c1867_3 --> 63.2.0-py37h89c1867_0
#   six                                   1.15.0-pyh9f0ad1d_0 --> 1.16.0-pyh6c4a22f_0
#   tqdm                                  4.59.0-pyhd8ed1ab_0 --> 4.64.0-pyhd8ed1ab_0
#   urllib3                               1.26.3-pyhd8ed1ab_0 --> 1.26.10-pyhd8ed1ab_0
#   wheel                                 0.36.2-pyhd3deb0d_0 --> 0.37.1-pyhd8ed1ab_0
#   yaml                                     0.2.5-h516909a_0 --> 0.2.5-h7f98852_2
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   certifi            anaconda::certifi-2022.6.15-py37h06a4~ --> conda-forge::certifi-2022.6.15-py37h89c1867_0
#
#
#
# Downloading and Extracting Packages
# _openmp_mutex-4.5    | 23 KB     | : 100% 1.0/1 [00:00<00:00,  7.92it/s]
# six-1.16.0           | 14 KB     | : 100% 1.0/1 [00:00<00:00, 25.67it/s]
# urllib3-1.26.10      | 101 KB    | : 100% 1.0/1 [00:00<00:00,  9.30it/s]
# numpy-1.21.6         | 6.1 MB    | : 100% 1.0/1 [00:01<00:00,  1.71s/it]
# colorama-0.4.5       | 18 KB     | : 100% 1.0/1 [00:00<00:00, 25.45it/s]
# pycparser-2.21       | 100 KB    | : 100% 1.0/1 [00:00<00:00, 13.16it/s]
# pyopenssl-22.0.0     | 49 KB     | : 100% 1.0/1 [00:00<00:00, 21.70it/s]
# requests-2.28.1      | 53 KB     | : 100% 1.0/1 [00:00<00:00, 11.49it/s]
# idna-3.3             | 55 KB     | : 100% 1.0/1 [00:00<00:00, 20.72it/s]
# pysocks-1.7.1        | 28 KB     | : 100% 1.0/1 [00:00<00:00, 24.72it/s]
# yaml-0.2.5           | 87 KB     | : 100% 1.0/1 [00:00<00:00, 17.51it/s]
# conda-package-handli | 1.0 MB    | : 100% 1.0/1 [00:00<00:00,  4.51it/s]
# cryptography-37.0.4  | 1.5 MB    | : 100% 1.0/1 [00:00<00:00,  1.47it/s]
# tqdm-4.64.0          | 81 KB     | : 100% 1.0/1 [00:00<00:00, 17.17it/s]
# ld_impl_linux-64-2.3 | 667 KB    | : 100% 1.0/1 [00:00<00:00,  5.08it/s]
# setuptools-63.2.0    | 1.4 MB    | : 100% 1.0/1 [00:00<00:00,  1.93it/s]
# pycosat-0.6.3        | 107 KB    | : 100% 1.0/1 [00:00<00:00, 17.30it/s]
# charset-normalizer-2 | 35 KB     | : 100% 1.0/1 [00:00<00:00, 23.52it/s]
# wheel-0.37.1         | 31 KB     | : 100% 1.0/1 [00:00<00:00, 23.99it/s]
# brotlipy-0.7.0       | 342 KB    | : 100% 1.0/1 [00:00<00:00, 11.39it/s]
# ruamel_yaml-0.15.80  | 259 KB    | : 100% 1.0/1 [00:00<00:00,  8.58it/s]
# pip-22.2             | 1.5 MB    | : 100% 1.0/1 [00:00<00:00,  1.72it/s]
# done
# done
# done

# %%
# !process_climate_indices --index spi --periodicity monthly --netcdf_precip /content/drive/MyDrive/IWMI/IMERG_DailyData/Input/IMERG_concat_ncpdq1.nc4 --var_name_precip precipitationCal --output_file_base /content/drive/MyDrive/IWMI/IMERG_DailyData/Output/IMERG --scales 1 2 3 6 9 12 --calibration_start_year 2000 --calibration_end_year 2022 --multiprocessing all
# Out:
# 2022-07-23  06:57:25 INFO Start time:    2022-07-23 06:57:25.011990
# 2022-07-23  06:57:25 INFO Computing 1-month SPI/Pearson
# 2022-07-23  06:58:08 INFO Computing 1-month SPI/Gamma
# 2022-07-23  06:58:30 INFO Computing 2-month SPI/Pearson
# 2022-07-23  06:59:10 INFO Computing 2-month SPI/Gamma
# 2022-07-23  06:59:32 INFO Computing 3-month SPI/Pearson
# 2022-07-23  07:00:11 INFO Computing 3-month SPI/Gamma
# 2022-07-23  07:00:35 INFO Computing 6-month SPI/Pearson
# 2022-07-23  07:01:13 INFO Computing 6-month SPI/Gamma
# 2022-07-23  07:01:35 INFO Computing 9-month SPI/Pearson
# 2022-07-23  07:02:14 INFO Computing 9-month SPI/Gamma
# 2022-07-23  07:02:35 INFO Computing 12-month SPI/Pearson
# 2022-07-23  07:03:12 INFO Computing 12-month SPI/Gamma
# 2022-07-23  07:03:36 INFO End time:      2022-07-23 07:03:36.390787
# 2022-07-23  07:03:36 INFO Elapsed time:  0:06:11.378797

# %%
# new code
# change the order of the to be readable by QGIS (SPI3, SPI6, SPI9, SPI12)
# !ncpdq -a time,lat,lon /content/drive/MyDrive/IWMI/IMERG_DailyData/Output/IMERG_spi_gamma_09.nc /content/drive/MyDrive/IWMI/IMERG_DailyData/Output/QGIS_spi_gamma_09.nc
# Out:
# INFO: NCO stub function for nc_inq_filter_avail() reports an inquiry on filter availability of HDF5 filter ID = 307. Stub function employed because libnetcdf.a does not contain nc_inq_filter_avail(). Please rebuild NCO against netCDF library version 4.9.0 (released ~20220601) or later to support the capability to find and call filters besides DEFLATE, Shuffle, and Fletcher32.
# Exiting...
# ncpdq: WARNING nc_cdc_lst_bld() reports nco_inq_filter_avail() did not find Bzip2 filter (with HDF5 filter ID = 307) as an HDF5 shared library filter. This is probably fixable because this filter is supported by all default installations of netCDF version 4.9.0 or higher. HINT: If you build netCDF from source, please be sure it was configured with the following options: "--enable-nczarr" and "--with-plugin-dir=${HDF5_PLUGIN_PATH}". The latter is especially important in netCDF 4.9.0. Also, please be sure the library for the missing filter (e.g., libzstd.a, libblosc.a, libbz2.a) is in an automatically searched directory, e.g., $LD_LIBRARY_PATH or /usr/lib.
# INFO: NCO stub function for nc_inq_filter_avail() reports an inquiry on filter availability of HDF5 filter ID = 32015. Stub function employed because libnetcdf.a does not contain nc_inq_filter_avail(). Please rebuild NCO against netCDF library version 4.9.0 (released ~20220601) or later to support the capability to find and call filters besides DEFLATE, Shuffle, and Fletcher32.
# Exiting...
# ncpdq: WARNING nc_cdc_lst_bld() reports nco_inq_filter_avail() did not find Zstandard filter (with HDF5 filter ID = 32015) as an HDF5 shared library filter. This is probably fixable because this filter is supported by all default installations of netCDF version 4.9.0 or higher. HINT: If you build netCDF from source, please be sure it was configured with the following options: "--enable-nczarr" and "--with-plugin-dir=${HDF5_PLUGIN_PATH}". The latter is especially important in netCDF 4.9.0. Also, please be sure the library for the missing filter (e.g., libzstd.a, libblosc.a, libbz2.a) is in an automatically searched directory, e.g., $LD_LIBRARY_PATH or /usr/lib.
# INFO: NCO stub function for nc_inq_filter_avail() reports an inquiry on filter availability of HDF5 filter ID = 32001. Stub function employed because libnetcdf.a does not contain nc_inq_filter_avail(). Please rebuild NCO against netCDF library version 4.9.0 (released ~20220601) or later to support the capability to find and call filters besides DEFLATE, Shuffle, and Fletcher32.
# Exiting...
# ncpdq: WARNING nc_cdc_lst_bld() reports nco_inq_filter_avail() did not find Blosc filter (with HDF5 filter ID = 32001) as an HDF5 shared library filter. This is probably fixable because this filter is supported by all default installations of netCDF version 4.9.0 or higher. HINT: If you build netCDF from source, please be sure it was configured with the following options: "--enable-nczarr" and "--with-plugin-dir=${HDF5_PLUGIN_PATH}". The latter is especially important in netCDF 4.9.0. Also, please be sure the library for the missing filter (e.g., libzstd.a, libblosc.a, libbz2.a) is in an automatically searched directory, e.g., $LD_LIBRARY_PATH or /usr/lib.

# %% [markdown]
# ## 5. Interpret the result using Panoply
#
# The visualization can be employed with Panoply, which is independent with the google colab.

# %% [markdown]
# 1. Launch the Panoply desktop application
# 2. Open the SPI file ```/Output/IMERG_spi_gamma_01.nc``` in Panoply
# 3. From the Datasets tab select spi_gamma_01 and click Create Plot
# 4. In the Create Plot window select ‘Create a georeferenced <<Longitude Latitude>> plot’ and click Create
# 5. When the Plot window opens:
#     - Array tab: Change the time into 238 to view the latest/last data ~ Mar 2020
#     - Scale tab: Change value on Min -3, Max 3, Major 6, Color Table CB_RdBu_09.cpt
#     - Map tab: Change value on Center on Lon 115.0, Lat -8.5, then Zoom in the map through menu-editor Plot > Zoom Plot In few times until Bali island bigger.
#     - Overlays tab: Change Overlay 1 to MWDB_Coasts_Countries_1.cnob
#     - To explore the values in the array, click on the Array 1 tab at the top of the window

# %% [markdown]
# ## End
