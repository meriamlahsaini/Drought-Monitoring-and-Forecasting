# %% [markdown]
# # Satellite-based monitoring of dry and wet conditions using Standardized Precipitation Index (SPI)  colab version

# %% [markdown]
# Surajit Ghosh |Rim | IWMI

# %% [markdown]
# The SPI analysis is following the training conducted in 28 Jan 2020 by [NASA ARSET](https://arset.gsfc.nasa.gov) on **Application of GPM IMERG Reanalysis for Assessing Extreme Dry and Wet Periods**. Link: https://arset.gsfc.nasa.gov/water/webinars/IMERG-2020
#
# Some of the step have been modified and adjusted based on experiencing of several problems during the training, and latest version of [Climate Indices in Python](https://github.com/monocongo/climate_indices) software is used in this tutorial. While NASA ARSET training still used the official release version from [U.S. Drought Portal](https://www.drought.gov/drought/python-climate-indices)

# %% [markdown]
# ## 1. Objectives
# - Learn how to bulk download IMERG data from NASA GES DISC
# - Determine how to calculate the Standardized Precipitation Index (SPI) for assessing extreme dry and wet periods

# %% [markdown]
# ### 1.1. Outline
# - Background on the Standardized Precipitation Index (SPI)
#     - SPI Interpretation
# - Software and Data Preparation
#     - Case Study: Zambia
#     - Install Supporting Software
#     - Data Acquisition
#     - Configure the Conda and python environment
#     - Pre-process data using NetCDF Operator ([NCO](http://nco.sourceforge.net/nco.html))
# - Running SPI code
#     - Pre-compute SPI distribution fitting variables (Optional analysis)
# - Interpret the result using Panoply

# %% [markdown]
# ## 2. Background on the Standardized Precipitation Index
# First developed by T.B. McKee et al. (1993) and used by Guttman (1999)
# - Used for estimating meteorological conditions based on precipitation alone
# - Wet or dry conditions can be monitored on a variety of time scales from sub seasonal to interannual
# - Can be compared across regions with markedly difference climates
# - Does not consider the intensity of precipitation and its potential impacts on runoff, streamflow, and water availability
# - Expressed as the number of standard deviations from the long term mean, for a normally distributed random variable, and fitted probability distribution for the actual precipitation record
# - SPI values < 1 indicate a condition of drought, the more negative the value the more severe the drought condition. SPI values > +1 indicate wetter conditions compared to a climatology

# %% [markdown]
# ### 2.1. SPI Interpretation
# https://drought.unl.edu/droughtmonitoring/SPI.aspx
#
# - 1 month: Similar to a map displaying the percent of normal precipitation for a month. Reflects relatively short term conditions. Its application can be related closely with short term soil moisture and crop stress.
# - 3 month: Provides a comparison of the precipitation over a specific 3 month period with the precipitation totals from the same 3 month period for all the years included in the historical record. Reflects short and medium term moisture conditions and provides a seasonal estimation of precipitation.
# - 6 month: Compares the precipitation for that period with the same 6 month period over the historical record. A 6 month SPI can be very effective in showing the precipitation over distinct seasons and may be associated with anomalous streamflow and reservoir levels.
# - 9 month: Provides an indication of precipitation patterns over a medium time scale. SPI values below 1.5 for these time scales are usually a good indication that significant impacts are occurring in agriculture and may be showing up in other sectors as well.
# - 12 month: Reflects long term precipitation patterns. Longer SPIs tend toward zero unless a specific trend is taking place. SPIs of these time scales are probably tied to streamflow, reservoir levels, and even groundwater levels at the longer time scales. In some locations of the country, the 12 month SPI is most closely related with the Palmer Index, and the two indices should reflect similar conditions.
#
#  (Source: J. Keyantash)

# %% [markdown]
# ### 2.2. Reference
# - Guttman, N. B., 1999: Accepting the Standardized Precipitation Index: A calculation algorithm. J. Amer. Water Resour. Assoc., 35(2), 311-322. [Link](https://climatedataguide.ucar.edu/climate-data/standardized-precipitation-index-spi)
# - Keyantash, John & National Center for Atmospheric Research Staff (Eds). "The Climate Data Guide: Standardized Precipitation Index (SPI)." Retrieved from https://climatedataguide.ucar.edu/climate-data/standardized-precipitation-index-spi
# - Lloyd Hughes, B., and M. A. Saunders, 2002: A drought climatology for Europe. Int. J. Climatol., DOI:10.1002/joc.846 [Link](https://rmets.onlinelibrary.wiley.com/doi/epdf/10.1002/joc.846)
# - McKee, T.B., N. J. Doesken, and J. Kliest, 1993: The relationship of drought frequency and duration to time scales. In Proceedings of the 8th Conference of Applied Climatology, 17 22 January, Anaheim, CA. American Meterological Society, Boston, MA. 179-18. [Link](https://www.droughtmanagement.info/literature/AMS_Relationship_Drought_Frequency_Duration_Time_Scales_1993.pdf)
# - National Drought Mitigation Center (NDMC) at the University of Nebraska Lincoln. [Link](https://drought.unl.edu/droughtmonitoring/SPI.aspx)
# - World Meteorological Organization (WMO), 2012: Standardized Precipitation Index User Guide. [Link](https://library.wmo.int/doc_num.php?explnum_id=7768)
# - Climate Indices in Python https://climate-indices.readthedocs.io/en/latest/

# %% [markdown]
# ## 3. Software and Data Preparation
# Case study: Zambia

# %% [markdown]
# ### 3.1. Install Supporting Software
# **If you encounter a problem, please look for a online solution.** The installation and configuration described below is performed in the colab terminal.
#
# 1. However, to visualize the results, you need to download and install [Panoply Data Viewer](https://www.giss.nasa.gov/tools/panoply/) from [NASA GISS](https://www.giss.nasa.gov/tools/panoply/download/) on your machine:
#     - macOS: https://www.giss.nasa.gov/tools/panoply/download/PanoplyMacOS-4.11.4.dmg
#     - Windows: https://www.giss.nasa.gov/tools/panoply/download/PanoplyWin-4.11.4.zip
#     - Linux: https://www.giss.nasa.gov/tools/panoply/download/PanoplyJ-4.11.4.zip

# %%
# new code
# !pip install condacolab
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting condacolab
#   Downloading condacolab-0.1.3-py3-none-any.whl (6.8 kB)
# Installing collected packages: condacolab
# Successfully installed condacolab-0.1.3

# %%
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/latest/download/Mambaforge-colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:31
# 🔁 Restarting kernel...

# %% [markdown]
# 2. Install ```wget``` package. ues ```wget``` to download IMERG data and use wget to prepare conda distribution in colab

# %%
# !pip install wget
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9680 sha256=0bdb7b6a90445d72131b3cb3d04cc478cf0148147e14b0b30ad95a4278a44936
#   Stored in directory: /root/.cache/pip/wheels/a1/b6/7c/0e63e34eb06634181c63adacca38b79ff8f35c37e3c13e3c02
# Successfully built wget
# Installing collected packages: wget
# Successfully installed wget-3.2

# %% [markdown]
# ### 3.2. Data Acquisition
# 1. Download monthly IMERG data from GES DISC: More detailed instructions can be found from EARTHDATA website https://disc.gsfc.nasa.gov/data-access
#     - Using a web browser, go to NASA Goddard Earth Sciences (GES) Data and Information Services Center (DISC): https://disc.gsfc.nasa.gov/
#     - Type “IMERG” in the search bar and click on the search icon
#     - Select IMERG Version 6 Level 3 data at “monthly” temporal resolution and click on the “Subset/Get Data” icon
#     - Leave the default date range since we want the entire time series
#     - Under Spatial Subset enter ```114.3, -9, 115.8, -8``` This spatial subset is for **Zambia**
#     - Under Variables select only ```precipitation```
#     - Leave the default parameters under Grid
#     - Under File Format select "netCDF"
#     - Click Get Data
#     - Data links windows will popup and you may click **"Download links list"**
#     - You will get a txt file with similar filename like this one **subset_GPM_3IMERGM_06_20210117_064353.txt**
#     - Upload this txt file into your specified download folder in this case folder **IMERG_mm_hr**
#     - Run the code to download the data to folder **IMERG_mm_hr**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# remember to change the download txt file name, output dir, your username and password
# !wget --user=rimu --password=theworldisfullofcrap1A. -P /content/drive/MyDrive/IWMI/IMERG_mm_hr --content-disposition -i  /content/drive/MyDrive/IWMI/IMERG_mm_hr/subset_GPM_3IMERGM_06_20220628_083705.txt
# Out:
# --2022-07-19 10:00:33--  https://docserver.gesdisc.eosdis.nasa.gov/public/project/GPM/IMERG_ATBD_V06.pdf
# Resolving docserver.gesdisc.eosdis.nasa.gov (docserver.gesdisc.eosdis.nasa.gov)... 198.118.197.32, 2001:4d0:241a:4041::32
# Connecting to docserver.gesdisc.eosdis.nasa.gov (docserver.gesdisc.eosdis.nasa.gov)|198.118.197.32|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2486295 (2.4M) [application/pdf]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/IMERG_ATBD_V06.pdf.1’
#
# IMERG_ATBD_V06.pdf. 100%[===================>]   2.37M  --.-KB/s    in 0.06s
#
# 2022-07-19 10:00:33 (41.3 MB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/IMERG_ATBD_V06.pdf.1’ saved [2486295/2486295]
#
# --2022-07-19 10:00:33--  https://gpm1.gesdisc.eosdis.nasa.gov/data/GPM_L3/doc/README.GPM.pdf
# Resolving gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)... 198.118.197.50, 2001:4d0:241a:4041::50
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 400392 (391K) [application/pdf]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/README.GPM.pdf.1’
#
# README.GPM.pdf.1    100%[===================>] 391.01K  --.-KB/s    in 0.01s
#
# 2022-07-19 10:00:33 (28.8 MB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/README.GPM.pdf.1’ saved [400392/400392]
#
# --2022-07-19 10:00:33--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGM.06%2F2000%2F3B-MO.MS.MRG.3IMERG.20000601-S000000-E235959.06.V06B.HDF5&FORMAT=bmM0Lw&BBOX=-18.318%2C21.533%2C-7.947%2C33.926&LABEL=3B-MO.MS.MRG.3IMERG.20000601-S000000-E235959.06.V06B.HDF5.SUB.nc4&SHORTNAME=GPM_3IMERGM&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitation
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# The name is too long, 343 chars total.
# Trying to shorten...
# New name is HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGM.06%2F2000%2F3B-MO.MS.MRG.3IMERG.20000601-S000000-E235959.06.V06B.HDF5&FORMAT=bmM0Lw&BBOX=-18.318,21.533,-7.947,33.926&LABEL=3B-MO.MS.MRG.3IMERG.20000601-S000000-E235959.06.V06B.H.
# Location: https://urs.earthdata.nasa.gov/oauth/authorize/?scope=uid&app_type=401&client_id=e2WVk8Pw6weeLUKZYOxvTQ&response_type=code&redirect_uri=https%3A%2F%2Fgpm1.gesdisc.eosdis.nasa.gov%2Fdata-redirect&state=... [following]
# --2022-07-19 10:00:33--  https://urs.earthdata.nasa.gov/oauth/authorize/?scope=uid&app_type=401&client_id=e2WVk8Pw6weeLUKZYOxvTQ&response_type=code&redirect_uri=https%3A%2F%2Fgpm1.gesdisc.eosdis.nasa.gov%2Fdata-redirect&state=...
# Resolving urs.earthdata.nasa.gov (urs.earthdata.nasa.gov)... 198.118.243.33, 2001:4d0:241a:4081::89
# Connecting to urs.earthdata.nasa.gov (urs.earthdata.nasa.gov)|198.118.243.33|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Please enter your Earthdata Login credentials. If you do not have a Earthdata Login, create one at https://urs.earthdata.nasa.gov//users/new"
# Reusing existing connection to urs.earthdata.nasa.gov:443.
# HTTP request sent, awaiting response... 302 Found
# The name is too long, 694 chars total.
# Trying to shorten...
# New name is index.html?scope=uid&app_type=401&client_id=e2WVk8Pw6weeLUKZYOxvTQ&response_type=code&redirect_uri=https:%2F%2Fgpm1.gesdisc.eosdis.nasa.gov%2Fdata-redirect&state=aHR0cHM6Ly9ncG0xLmdlc2Rpc2MuZW9zZGlzLm5hc2EuZ292L2RhYWMtYmluL09URi9IVFRQX3.
# Location: https://gpm1.gesdisc.eosdis.nasa.gov/data-redirect?code=55405b2f4affd682f02866ffcd4aeb8bc699b86436013501552adbe61a58e6bd&state=... [following]
# --2022-07-19 10:00:34--  https://gpm1.gesdisc.eosdis.nasa.gov/data-redirect?code=55405b2f4affd682f02866ffcd4aeb8bc699b86436013501552adbe61a58e6bd&state=...
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# The name is too long, 622 chars total.
# Trying to shorten...
# New name is data-redirect?code=55405b2f4affd682f02866ffcd4aeb8bc699b86436013501552adbe61a58e6bd&state=aHR0cHM6Ly9ncG0xLmdlc2Rpc2MuZW9zZGlzLm5hc2EuZ292L2RhYWMtYmluL09URi9IVFRQX3NlcnZpY2VzLmNnaT9GSUxFTkFNRT0lMkZkYXRhJTJGR1BNX0wzJTJGR1BNXzNJTUVSR00uMD.
# Location: https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGM.06%2F2000%2F3B-MO.MS.MRG.3IMERG.20000601-S000000-E235959.06.V06B.HDF5&FORMAT=bmM0Lw&BBOX=-18.318%2C21.533%2C-7.947%2C33.926&LABEL=3B-MO.MS.MRG.3IMERG.20000601-S000000-E235959.06.V06B.HDF5.SUB.nc4&SHORTNAME=GPM_3IMERGM&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitation [following]
# --2022-07-19 10:00:34--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGM.06%2F2000%2F3B-MO.MS.MRG.3IMERG.20000601-S000000-E235959.06.V06B.HDF5&FORMAT=bmM0Lw&BBOX=-18.318%2C21.533%2C-7.947%2C33.926&LABEL=3B-MO.MS.MRG.3IMERG.20000601-S000000-E235959.06.V06B.HDF5.SUB.nc4&SHORTNAME=GPM_3IMERGM&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitation
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 63995 (62K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20000601-S000000-E235959.06.V06B.HDF5.SUB.nc4’
#
# 3B-MO.MS.MRG.3IMERG 100%[===================>]  62.50K  --.-KB/s    in 0.003s
#
# 2022-07-19 10:00:37 (21.4 MB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20000601-S000000-E235959.06.V06B.HDF5.SUB.nc4’ saved [63995/63995]
#
# --2022-07-19 10:00:37--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGM.06%2F2000%2F3B-MO.MS.MRG.3IMERG.20000701-S000000-E235959.07.V06B.HDF5&FORMAT=bmM0Lw&BBOX=-18.318%2C21.533%2C-7.947%2C33.926&LABEL=3B-MO.MS.MRG.3IMERG.20000701-S000000-E235959.07.V06B.HDF5.SUB.nc4&SHORTNAME=GPM_3IMERGM&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitation
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 64501 (63K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20000701-S000000-E235959.07.V06B.HDF5.SUB.nc4’
#
# 3B-MO.MS.MRG.3IMERG 100%[===================>]  62.99K  --.-KB/s    in 0.05s
#
# 2022-07-19 10:00:39 (1.34 MB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20000701-S000000-E235959.07.V06B.HDF5.SUB.nc4’ saved [64501/64501]
#
# --2022-07-19 10:00:39--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGM.06%2F2000%2F3B-MO.MS.MRG.3IMERG.20000801-S000000-E235959.08.V06B.HDF5&FORMAT=bmM0Lw&BBOX=-18.318%2C21.533%2C-7.947%2C33.926&LABEL=3B-MO.MS.MRG.3IMERG.20000801-S000000-E235959.08.V06B.HDF5.SUB.nc4&SHORTNAME=GPM_3IMERGM&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitation
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 64235 (63K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20000801-S000000-E235959.08.V06B.HDF5.SUB.nc4’
#
# 3B-MO.MS.MRG.3IMERG 100%[===================>]  62.73K  --.-KB/s    in 0.005s
#
# 2022-07-19 10:00:42 (11.9 MB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20000801-S000000-E235959.08.V06B.HDF5.SUB.nc4’ saved [64235/64235]
#
# --2022-07-19 10:00:42--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGM.06%2F2000%2F3B-MO.MS.MRG.3IMERG.20000901-S000000-E235959.09.V06B.HDF5&FORMAT=bmM0Lw&BBOX=-18.318%2C21.533%2C-7.947%2C33.926&LABEL=3B-MO.MS.MRG.3IMERG.20000901-S000000-E235959.09.V06B.HDF5.SUB.nc4&SHORTNAME=GPM_3IMERGM&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitation
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 64194 (63K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20000901-S000000-E235959.09.V06B.HDF5.SUB.nc4’
#
# 3B-MO.MS.MRG.3IMERG 100%[===================>]  62.69K  --.-KB/s    in 0.002s
#
# 2022-07-19 10:00:44 (29.8 MB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20000901-S000000-E235959.09.V06B.HDF5.SUB.nc4’ saved [64194/64194]
#
# --2022-07-19 10:00:44--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGM.06%2F2000%2F3B-MO.MS.MRG.3IMERG.20001001-S000000-E235959.10.V06B.HDF5&FORMAT=bmM0Lw&BBOX=-18.318%2C21.533%2C-7.947%2C33.926&LABEL=3B-MO.MS.MRG.3IMERG.20001001-S000000-E235959.10.V06B.HDF5.SUB.nc4&SHORTNAME=GPM_3IMERGM&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitation
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 63324 (62K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20001001-S000000-E235959.10.V06B.HDF5.SUB.nc4’
#
# 3B-MO.MS.MRG.3IMERG 100%[===================>]  61.84K  --.-KB/s    in 0.004s
#
# 2022-07-19 10:00:46 (14.4 MB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20001001-S000000-E235959.10.V06B.HDF5.SUB.nc4’ saved [63324/63324]
#
# --2022-07-19 10:00:46--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGM.06%2F2000%2F3B-MO.MS.MRG.3IMERG.20001101-S000000-E235959.11.V06B.HDF5&FORMAT=bmM0Lw&BBOX=-18.318%2C21.533%2C-7.947%2C33.926&LABEL=3B-MO.MS.MRG.3IMERG.20001101-S000000-E235959.11.V06B.HDF5.SUB.nc4&SHORTNAME=GPM_3IMERGM&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitation
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 61900 (60K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20001101-S000000-E235959.11.V06B.HDF5.SUB.nc4’
#
# 3B-MO.MS.MRG.3IMERG 100%[===================>]  60.45K  --.-KB/s    in 0.002s
#
# 2022-07-19 10:00:49 (27.5 MB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20001101-S000000-E235959.11.V06B.HDF5.SUB.nc4’ saved [61900/61900]
#
# --2022-07-19 10:00:49--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGM.06%2F2000%2F3B-MO.MS.MRG.3IMERG.20001201-S000000-E235959.12.V06B.HDF5&FORMAT=bmM0Lw&BBOX=-18.318%2C21.533%2C-7.947%2C33.926&LABEL=3B-MO.MS.MRG.3IMERG.20001201-S000000-E235959.12.V06B.HDF5.SUB.nc4&SHORTNAME=GPM_3IMERGM&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitation
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 62061 (61K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20001201-S000000-E235959.12.V06B.HDF5.SUB.nc4’
#
# 3B-MO.MS.MRG.3IMERG 100%[===================>]  60.61K  --.-KB/s    in 0.004s
#
# 2022-07-19 10:00:51 (15.2 MB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20001201-S000000-E235959.12.V06B.HDF5.SUB.nc4’ saved [62061/62061]
#
# --2022-07-19 10:00:51--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGM.06%2F2001%2F3B-MO.MS.MRG.3IMERG.20010101-S000000-E235959.01.V06B.HDF5&FORMAT=bmM0Lw&BBOX=-18.318%2C21.533%2C-7.947%2C33.926&LABEL=3B-MO.MS.MRG.3IMERG.20010101-S000000-E235959.01.V06B.HDF5.SUB.nc4&SHORTNAME=GPM_3IMERGM&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitation
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 62514 (61K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20010101-S000000-E235959.01.V06B.HDF5.SUB.nc4’
#
# 3B-MO.MS.MRG.3IMERG 100%[===================>]  61.05K  --.-KB/s    in 0.002s
#
# 2022-07-19 10:00:53 (26.5 MB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20010101-S000000-E235959.01.V06B.HDF5.SUB.nc4’ saved [62514/62514]
#
# --2022-07-19 10:00:53--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGM.06%2F2001%2F3B-MO.MS.MRG.3IMERG.20010201-S000000-E235959.02.V06B.HDF5&FORMAT=bmM0Lw&BBOX=-18.318%2C21.533%2C-7.947%2C33.926&LABEL=3B-MO.MS.MRG.3IMERG.20010201-S000000-E235959.02.V06B.HDF5.SUB.nc4&SHORTNAME=GPM_3IMERGM&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitation
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 62215 (61K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20010201-S000000-E235959.02.V06B.HDF5.SUB.nc4’
#
# 3B-MO.MS.MRG.3IMERG 100%[===================>]  60.76K  --.-KB/s    in 0.003s
#
# 2022-07-19 10:00:55 (18.4 MB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20010201-S000000-E235959.02.V06B.HDF5.SUB.nc4’ saved [62215/62215]
#
# --2022-07-19 10:00:55--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGM.06%2F2001%2F3B-MO.MS.MRG.3IMERG.20010301-S000000-E235959.03.V06B.HDF5&FORMAT=bmM0Lw&BBOX=-18.318%2C21.533%2C-7.947%2C33.926&LABEL=3B-MO.MS.MRG.3IMERG.20010301-S000000-E235959.03.V06B.HDF5.SUB.nc4&SHORTNAME=GPM_3IMERGM&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitation
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 61231 (60K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20010301-S000000-E235959.03.V06B.HDF5.SUB.nc4’
#
# 3B-MO.MS.MRG.3IMERG 100%[===================>]  59.80K  --.-KB/s    in 0.005s
#
# 2022-07-19 10:00:58 (10.7 MB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20010301-S000000-E235959.03.V06B.HDF5.SUB.nc4’ saved [61231/61231]
#
# --2022-07-19 10:00:58--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGM.06%2F2001%2F3B-MO.MS.MRG.3IMERG.20010401-S000000-E235959.04.V06B.HDF5&FORMAT=bmM0Lw&BBOX=-18.318%2C21.533%2C-7.947%2C33.926&LABEL=3B-MO.MS.MRG.3IMERG.20010401-S000000-E235959.04.V06B.HDF5.SUB.nc4&SHORTNAME=GPM_3IMERGM&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitation
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 63287 (62K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20010401-S000000-E235959.04.V06B.HDF5.SUB.nc4’
#
# 3B-MO.MS.MRG.3IMERG 100%[===================>]  61.80K  --.-KB/s    in 0.003s
#
# 2022-07-19 10:01:00 (18.0 MB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20010401-S000000-E235959.04.V06B.HDF5.SUB.nc4’ saved [63287/63287]
#
# --2022-07-19 10:01:00--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGM.06%2F2001%2F3B-MO.MS.MRG.3IMERG.20010501-S000000-E235959.05.V06B.HDF5&FORMAT=bmM0Lw&BBOX=-18.318%2C21.533%2C-7.947%2C33.926&LABEL=3B-MO.MS.MRG.3IMERG.20010501-S000000-E235959.05.V06B.HDF5.SUB.nc4&SHORTNAME=GPM_3IMERGM&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitation
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 64019 (63K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20010501-S000000-E235959.05.V06B.HDF5.SUB.nc4’
#
# 3B-MO.MS.MRG.3IMERG 100%[===================>]  62.52K  --.-KB/s    in 0.005s
#
# 2022-07-19 10:01:03 (12.7 MB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20010501-S000000-E235959.05.V06B.HDF5.SUB.nc4’ saved [64019/64019]
#
# --2022-07-19 10:01:03--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGM.06%2F2001%2F3B-MO.MS.MRG.3IMERG.20010601-S000000-E235959.06.V06B.HDF5&FORMAT=bmM0Lw&BBOX=-18.318%2C21.533%2C-7.947%2C33.926&LABEL=3B-MO.MS.MRG.3IMERG.20010601-S000000-E235959.06.V06B.HDF5.SUB.nc4&SHORTNAME=GPM_3IMERGM&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitation
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 64158 (63K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20010601-S000000-E235959.06.V06B.HDF5.SUB.nc4’
#
# 3B-MO.MS.MRG.3IMERG 100%[===================>]  62.65K  --.-KB/s    in 0.003s
#
# 2022-07-19 10:01:05 (21.9 MB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20010601-S000000-E235959.06.V06B.HDF5.SUB.nc4’ saved [64158/64158]
#
# --2022-07-19 10:01:05--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGM.06%2F2001%2F3B-MO.MS.MRG.3IMERG.20010701-S000000-E235959.07.V06B.HDF5&FORMAT=bmM0Lw&BBOX=-18.318%2C21.533%2C-7.947%2C33.926&LABEL=3B-MO.MS.MRG.3IMERG.20010701-S000000-E235959.07.V06B.HDF5.SUB.nc4&SHORTNAME=GPM_3IMERGM&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitation
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 64559 (63K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20010701-S000000-E235959.07.V06B.HDF5.SUB.nc4’
#
# 3B-MO.MS.MRG.3IMERG 100%[===================>]  63.05K  --.-KB/s    in 0.02s
#
# 2022-07-19 10:01:07 (2.56 MB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20010701-S000000-E235959.07.V06B.HDF5.SUB.nc4’ saved [64559/64559]
#
# --2022-07-19 10:01:07--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGM.06%2F2001%2F3B-MO.MS.MRG.3IMERG.20010801-S000000-E235959.08.V06B.HDF5&FORMAT=bmM0Lw&BBOX=-18.318%2C21.533%2C-7.947%2C33.926&LABEL=3B-MO.MS.MRG.3IMERG.20010801-S000000-E235959.08.V06B.HDF5.SUB.nc4&SHORTNAME=GPM_3IMERGM&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitation
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 63844 (62K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20010801-S000000-E235959.08.V06B.HDF5.SUB.nc4’
#
# 3B-MO.MS.MRG.3IMERG 100%[===================>]  62.35K  --.-KB/s    in 0.007s
#
# 2022-07-19 10:01:10 (8.53 MB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20010801-S000000-E235959.08.V06B.HDF5.SUB.nc4’ saved [63844/63844]
#
# --2022-07-19 10:01:10--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGM.06%2F2001%2F3B-MO.MS.MRG.3IMERG.20010901-S000000-E235959.09.V06B.HDF5&FORMAT=bmM0Lw&BBOX=-18.318%2C21.533%2C-7.947%2C33.926&LABEL=3B-MO.MS.MRG.3IMERG.20010901-S000000-E235959.09.V06B.HDF5.SUB.nc4&SHORTNAME=GPM_3IMERGM&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitation
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 63816 (62K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20010901-S000000-E235959.09.V06B.HDF5.SUB.nc4’
#
# 3B-MO.MS.MRG.3IMERG 100%[===================>]  62.32K  --.-KB/s    in 0.004s
#
# 2022-07-19 10:01:12 (15.0 MB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20010901-S000000-E235959.09.V06B.HDF5.SUB.nc4’ saved [63816/63816]
#
# --2022-07-19 10:01:12--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGM.06%2F2001%2F3B-MO.MS.MRG.3IMERG.20011001-S000000-E235959.10.V06B.HDF5&FORMAT=bmM0Lw&BBOX=-18.318%2C21.533%2C-7.947%2C33.926&LABEL=3B-MO.MS.MRG.3IMERG.20011001-S000000-E235959.10.V06B.HDF5.SUB.nc4&SHORTNAME=GPM_3IMERGM&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitation
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 63386 (62K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20011001-S000000-E235959.10.V06B.HDF5.SUB.nc4’
#
# 3B-MO.MS.MRG.3IMERG 100%[===================>]  61.90K  --.-KB/s    in 0.006s
#
# 2022-07-19 10:01:14 (10.9 MB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20011001-S000000-E235959.10.V06B.HDF5.SUB.nc4’ saved [63386/63386]
#
# --2022-07-19 10:01:14--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGM.06%2F2001%2F3B-MO.MS.MRG.3IMERG.20011101-S000000-E235959.11.V06B.HDF5&FORMAT=bmM0Lw&BBOX=-18.318%2C21.533%2C-7.947%2C33.926&LABEL=3B-MO.MS.MRG.3IMERG.20011101-S000000-E235959.11.V06B.HDF5.SUB.nc4&SHORTNAME=GPM_3IMERGM&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitation
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 62024 (61K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20011101-S000000-E235959.11.V06B.HDF5.SUB.nc4’
#
# 3B-MO.MS.MRG.3IMERG 100%[===================>]  60.57K  --.-KB/s    in 0.004s
#
# 2022-07-19 10:01:17 (14.4 MB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20011101-S000000-E235959.11.V06B.HDF5.SUB.nc4’ saved [62024/62024]
#
# --2022-07-19 10:01:17--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGM.06%2F2001%2F3B-MO.MS.MRG.3IMERG.20011201-S000000-E235959.12.V06B.HDF5&FORMAT=bmM0Lw&BBOX=-18.318%2C21.533%2C-7.947%2C33.926&LABEL=3B-MO.MS.MRG.3IMERG.20011201-S000000-E235959.12.V06B.HDF5.SUB.nc4&SHORTNAME=GPM_3IMERGM&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitation
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 61248 (60K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20011201-S000000-E235959.12.V06B.HDF5.SUB.nc4’
#
# 3B-MO.MS.MRG.3IMERG 100%[===================>]  59.81K  --.-KB/s    in 0.004s
#
# 2022-07-19 10:01:19 (15.3 MB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20011201-S000000-E235959.12.V06B.HDF5.SUB.nc4’ saved [61248/61248]
#
# --2022-07-19 10:01:19--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGM.06%2F2002%2F3B-MO.MS.MRG.3IMERG.20020101-S000000-E235959.01.V06B.HDF5&FORMAT=bmM0Lw&BBOX=-18.318%2C21.533%2C-7.947%2C33.926&LABEL=3B-MO.MS.MRG.3IMERG.20020101-S000000-E235959.01.V06B.HDF5.SUB.nc4&SHORTNAME=GPM_3IMERGM&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitation
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 61999 (61K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20020101-S000000-E235959.01.V06B.HDF5.SUB.nc4’
#
# 3B-MO.MS.MRG.3IMERG 100%[===================>]  60.55K  --.-KB/s    in 0.004s
#
# 2022-07-19 10:01:21 (13.7 MB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20020101-S000000-E235959.01.V06B.HDF5.SUB.nc4’ saved [61999/61999]
#
# --2022-07-19 10:01:21--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGM.06%2F2002%2F3B-MO.MS.MRG.3IMERG.20020201-S000000-E235959.02.V06B.HDF5&FORMAT=bmM0Lw&BBOX=-18.318%2C21.533%2C-7.947%2C33.926&LABEL=3B-MO.MS.MRG.3IMERG.20020201-S000000-E235959.02.V06B.HDF5.SUB.nc4&SHORTNAME=GPM_3IMERGM&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitation
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 62295 (61K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20020201-S000000-E235959.02.V06B.HDF5.SUB.nc4’
#
# 3B-MO.MS.MRG.3IMERG 100%[===================>]  60.83K  --.-KB/s    in 0.003s
#
# 2022-07-19 10:01:24 (18.8 MB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20020201-S000000-E235959.02.V06B.HDF5.SUB.nc4’ saved [62295/62295]
#
# --2022-07-19 10:01:24--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGM.06%2F2002%2F3B-MO.MS.MRG.3IMERG.20020301-S000000-E235959.03.V06B.HDF5&FORMAT=bmM0Lw&BBOX=-18.318%2C21.533%2C-7.947%2C33.926&LABEL=3B-MO.MS.MRG.3IMERG.20020301-S000000-E235959.03.V06B.HDF5.SUB.nc4&SHORTNAME=GPM_3IMERGM&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitation
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 62604 (61K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20020301-S000000-E235959.03.V06B.HDF5.SUB.nc4’
#
# 3B-MO.MS.MRG.3IMERG 100%[===================>]  61.14K  --.-KB/s    in 0.003s
#
# 2022-07-19 10:01:26 (17.1 MB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20020301-S000000-E235959.03.V06B.HDF5.SUB.nc4’ saved [62604/62604]
#
# --2022-07-19 10:01:26--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGM.06%2F2002%2F3B-MO.MS.MRG.3IMERG.20020401-S000000-E235959.04.V06B.HDF5&FORMAT=bmM0Lw&BBOX=-18.318%2C21.533%2C-7.947%2C33.926&LABEL=3B-MO.MS.MRG.3IMERG.20020401-S000000-E235959.04.V06B.HDF5.SUB.nc4&SHORTNAME=GPM_3IMERGM&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitation
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 63085 (62K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20020401-S000000-E235959.04.V06B.HDF5.SUB.nc4’
#
# 3B-MO.MS.MRG.3IMERG 100%[===================>]  61.61K  --.-KB/s    in 0.005s
#
# 2022-07-19 10:01:28 (11.4 MB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20020401-S000000-E235959.04.V06B.HDF5.SUB.nc4’ saved [63085/63085]
#
# --2022-07-19 10:01:28--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGM.06%2F2002%2F3B-MO.MS.MRG.3IMERG.20020501-S000000-E235959.05.V06B.HDF5&FORMAT=bmM0Lw&BBOX=-18.318%2C21.533%2C-7.947%2C33.926&LABEL=3B-MO.MS.MRG.3IMERG.20020501-S000000-E235959.05.V06B.HDF5.SUB.nc4&SHORTNAME=GPM_3IMERGM&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitation
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 64292 (63K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20020501-S000000-E235959.05.V06B.HDF5.SUB.nc4’
#
# 3B-MO.MS.MRG.3IMERG 100%[===================>]  62.79K  --.-KB/s    in 0.004s
#
# 2022-07-19 10:01:31 (14.9 MB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20020501-S000000-E235959.05.V06B.HDF5.SUB.nc4’ saved [64292/64292]
#
# --2022-07-19 10:01:31--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGM.06%2F2002%2F3B-MO.MS.MRG.3IMERG.20020601-S000000-E235959.06.V06B.HDF5&FORMAT=bmM0Lw&BBOX=-18.318%2C21.533%2C-7.947%2C33.926&LABEL=3B-MO.MS.MRG.3IMERG.20020601-S000000-E235959.06.V06B.HDF5.SUB.nc4&SHORTNAME=GPM_3IMERGM&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitation
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 64814 (63K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20020601-S000000-E235959.06.V06B.HDF5.SUB.nc4’
#
# 3B-MO.MS.MRG.3IMERG 100%[===================>]  63.29K  --.-KB/s    in 0.006s
#
# 2022-07-19 10:01:33 (10.2 MB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20020601-S000000-E235959.06.V06B.HDF5.SUB.nc4’ saved [64814/64814]
#
# --2022-07-19 10:01:33--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGM.06%2F2002%2F3B-MO.MS.MRG.3IMERG.20020701-S000000-E235959.07.V06B.HDF5&FORMAT=bmM0Lw&BBOX=-18.318%2C21.533%2C-7.947%2C33.926&LABEL=3B-MO.MS.MRG.3IMERG.20020701-S000000-E235959.07.V06B.HDF5.SUB.nc4&SHORTNAME=GPM_3IMERGM&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitation
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 64798 (63K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20020701-S000000-E235959.07.V06B.HDF5.SUB.nc4’
#
# 3B-MO.MS.MRG.3IMERG 100%[===================>]  63.28K  --.-KB/s    in 0.004s
#
# 2022-07-19 10:01:35 (16.2 MB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20020701-S000000-E235959.07.V06B.HDF5.SUB.nc4’ saved [64798/64798]
#
# --2022-07-19 10:01:35--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGM.06%2F2002%2F3B-MO.MS.MRG.3IMERG.20020801-S000000-E235959.08.V06B.HDF5&FORMAT=bmM0Lw&BBOX=-18.318%2C21.533%2C-7.947%2C33.926&LABEL=3B-MO.MS.MRG.3IMERG.20020801-S000000-E235959.08.V06B.HDF5.SUB.nc4&SHORTNAME=GPM_3IMERGM&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitation
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 64292 (63K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20020801-S000000-E235959.08.V06B.HDF5.SUB.nc4’
#
# 3B-MO.MS.MRG.3IMERG 100%[===================>]  62.79K  --.-KB/s    in 0.002s
#
# 2022-07-19 10:01:38 (29.5 MB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20020801-S000000-E235959.08.V06B.HDF5.SUB.nc4’ saved [64292/64292]
#
# --2022-07-19 10:01:38--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGM.06%2F2002%2F3B-MO.MS.MRG.3IMERG.20020901-S000000-E235959.09.V06B.HDF5&FORMAT=bmM0Lw&BBOX=-18.318%2C21.533%2C-7.947%2C33.926&LABEL=3B-MO.MS.MRG.3IMERG.20020901-S000000-E235959.09.V06B.HDF5.SUB.nc4&SHORTNAME=GPM_3IMERGM&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitation
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 63661 (62K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20020901-S000000-E235959.09.V06B.HDF5.SUB.nc4’
#
# 3B-MO.MS.MRG.3IMERG 100%[===================>]  62.17K  --.-KB/s    in 0.004s
#
# 2022-07-19 10:01:40 (15.0 MB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20020901-S000000-E235959.09.V06B.HDF5.SUB.nc4’ saved [63661/63661]
#
# --2022-07-19 10:01:40--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGM.06%2F2002%2F3B-MO.MS.MRG.3IMERG.20021001-S000000-E235959.10.V06B.HDF5&FORMAT=bmM0Lw&BBOX=-18.318%2C21.533%2C-7.947%2C33.926&LABEL=3B-MO.MS.MRG.3IMERG.20021001-S000000-E235959.10.V06B.HDF5.SUB.nc4&SHORTNAME=GPM_3IMERGM&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitation
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 63218 (62K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20021001-S000000-E235959.10.V06B.HDF5.SUB.nc4’
#
# 3B-MO.MS.MRG.3IMERG 100%[===================>]  61.74K  --.-KB/s    in 0.005s
#
# 2022-07-19 10:01:42 (11.1 MB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20021001-S000000-E235959.10.V06B.HDF5.SUB.nc4’ saved [63218/63218]
#
# --2022-07-19 10:01:42--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGM.06%2F2002%2F3B-MO.MS.MRG.3IMERG.20021101-S000000-E235959.11.V06B.HDF5&FORMAT=bmM0Lw&BBOX=-18.318%2C21.533%2C-7.947%2C33.926&LABEL=3B-MO.MS.MRG.3IMERG.20021101-S000000-E235959.11.V06B.HDF5.SUB.nc4&SHORTNAME=GPM_3IMERGM&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitation
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 62551 (61K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20021101-S000000-E235959.11.V06B.HDF5.SUB.nc4’
#
# 3B-MO.MS.MRG.3IMERG 100%[===================>]  61.08K  --.-KB/s    in 0.003s
#
# 2022-07-19 10:01:45 (19.3 MB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20021101-S000000-E235959.11.V06B.HDF5.SUB.nc4’ saved [62551/62551]
#
# --2022-07-19 10:01:45--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGM.06%2F2002%2F3B-MO.MS.MRG.3IMERG.20021201-S000000-E235959.12.V06B.HDF5&FORMAT=bmM0Lw&BBOX=-18.318%2C21.533%2C-7.947%2C33.926&LABEL=3B-MO.MS.MRG.3IMERG.20021201-S000000-E235959.12.V06B.HDF5.SUB.nc4&SHORTNAME=GPM_3IMERGM&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitation
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 61933 (60K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20021201-S000000-E235959.12.V06B.HDF5.SUB.nc4’
#
# 3B-MO.MS.MRG.3IMERG 100%[===================>]  60.48K  --.-KB/s    in 0.005s
#
# 2022-07-19 10:01:47 (11.5 MB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20021201-S000000-E235959.12.V06B.HDF5.SUB.nc4’ saved [61933/61933]
#
# --2022-07-19 10:01:47--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGM.06%2F2003%2F3B-MO.MS.MRG.3IMERG.20030101-S000000-E235959.01.V06B.HDF5&FORMAT=bmM0Lw&BBOX=-18.318%2C21.533%2C-7.947%2C33.926&LABEL=3B-MO.MS.MRG.3IMERG.20030101-S000000-E235959.01.V06B.HDF5.SUB.nc4&SHORTNAME=GPM_3IMERGM&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitation
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 62134 (61K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20030101-S000000-E235959.01.V06B.HDF5.SUB.nc4’
#
# 3B-MO.MS.MRG.3IMERG 100%[===================>]  60.68K  --.-KB/s    in 0.004s
#
# 2022-07-19 10:01:49 (15.0 MB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20030101-S000000-E235959.01.V06B.HDF5.SUB.nc4’ saved [62134/62134]
#
# --2022-07-19 10:01:49--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGM.06%2F2003%2F3B-MO.MS.MRG.3IMERG.20030201-S000000-E235959.02.V06B.HDF5&FORMAT=bmM0Lw&BBOX=-18.318%2C21.533%2C-7.947%2C33.926&LABEL=3B-MO.MS.MRG.3IMERG.20030201-S000000-E235959.02.V06B.HDF5.SUB.nc4&SHORTNAME=GPM_3IMERGM&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitation
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 61809 (60K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20030201-S000000-E235959.02.V06B.HDF5.SUB.nc4’
#
# 3B-MO.MS.MRG.3IMERG 100%[===================>]  60.36K  --.-KB/s    in 0.005s
#
# 2022-07-19 10:01:52 (12.7 MB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20030201-S000000-E235959.02.V06B.HDF5.SUB.nc4’ saved [61809/61809]
#
# --2022-07-19 10:01:52--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGM.06%2F2003%2F3B-MO.MS.MRG.3IMERG.20030301-S000000-E235959.03.V06B.HDF5&FORMAT=bmM0Lw&BBOX=-18.318%2C21.533%2C-7.947%2C33.926&LABEL=3B-MO.MS.MRG.3IMERG.20030301-S000000-E235959.03.V06B.HDF5.SUB.nc4&SHORTNAME=GPM_3IMERGM&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitation
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 61449 (60K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20030301-S000000-E235959.03.V06B.HDF5.SUB.nc4’
#
# 3B-MO.MS.MRG.3IMERG 100%[===================>]  60.01K  --.-KB/s    in 0.004s
#
# 2022-07-19 10:01:54 (14.4 MB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20030301-S000000-E235959.03.V06B.HDF5.SUB.nc4’ saved [61449/61449]
#
# --2022-07-19 10:01:54--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGM.06%2F2003%2F3B-MO.MS.MRG.3IMERG.20030401-S000000-E235959.04.V06B.HDF5&FORMAT=bmM0Lw&BBOX=-18.318%2C21.533%2C-7.947%2C33.926&LABEL=3B-MO.MS.MRG.3IMERG.20030401-S000000-E235959.04.V06B.HDF5.SUB.nc4&SHORTNAME=GPM_3IMERGM&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitation
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 63261 (62K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20030401-S000000-E235959.04.V06B.HDF5.SUB.nc4’
#
# 3B-MO.MS.MRG.3IMERG 100%[===================>]  61.78K  --.-KB/s    in 0.006s
#
# 2022-07-19 10:01:56 (9.52 MB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20030401-S000000-E235959.04.V06B.HDF5.SUB.nc4’ saved [63261/63261]
#
# --2022-07-19 10:01:56--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGM.06%2F2003%2F3B-MO.MS.MRG.3IMERG.20030501-S000000-E235959.05.V06B.HDF5&FORMAT=bmM0Lw&BBOX=-18.318%2C21.533%2C-7.947%2C33.926&LABEL=3B-MO.MS.MRG.3IMERG.20030501-S000000-E235959.05.V06B.HDF5.SUB.nc4&SHORTNAME=GPM_3IMERGM&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitation
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 64405 (63K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20030501-S000000-E235959.05.V06B.HDF5.SUB.nc4’
#
# 3B-MO.MS.MRG.3IMERG 100%[===================>]  62.90K  --.-KB/s    in 0.004s
#
# 2022-07-19 10:01:59 (17.0 MB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20030501-S000000-E235959.05.V06B.HDF5.SUB.nc4’ saved [64405/64405]
#
# --2022-07-19 10:01:59--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGM.06%2F2003%2F3B-MO.MS.MRG.3IMERG.20030601-S000000-E235959.06.V06B.HDF5&FORMAT=bmM0Lw&BBOX=-18.318%2C21.533%2C-7.947%2C33.926&LABEL=3B-MO.MS.MRG.3IMERG.20030601-S000000-E235959.06.V06B.HDF5.SUB.nc4&SHORTNAME=GPM_3IMERGM&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitation
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 64558 (63K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20030601-S000000-E235959.06.V06B.HDF5.SUB.nc4’
#
# 3B-MO.MS.MRG.3IMERG 100%[===================>]  63.04K  --.-KB/s    in 0.004s
#
# 2022-07-19 10:02:01 (14.8 MB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20030601-S000000-E235959.06.V06B.HDF5.SUB.nc4’ saved [64558/64558]
#
# --2022-07-19 10:02:01--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGM.06%2F2003%2F3B-MO.MS.MRG.3IMERG.20030701-S000000-E235959.07.V06B.HDF5&FORMAT=bmM0Lw&BBOX=-18.318%2C21.533%2C-7.947%2C33.926&LABEL=3B-MO.MS.MRG.3IMERG.20030701-S000000-E235959.07.V06B.HDF5.SUB.nc4&SHORTNAME=GPM_3IMERGM&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitation
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 64814 (63K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20030701-S000000-E235959.07.V06B.HDF5.SUB.nc4’
#
# 3B-MO.MS.MRG.3IMERG 100%[===================>]  63.29K  --.-KB/s    in 0.004s
#
# 2022-07-19 10:02:03 (14.3 MB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20030701-S000000-E235959.07.V06B.HDF5.SUB.nc4’ saved [64814/64814]
#
# --2022-07-19 10:02:03--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGM.06%2F2003%2F3B-MO.MS.MRG.3IMERG.20030801-S000000-E235959.08.V06B.HDF5&FORMAT=bmM0Lw&BBOX=-18.318%2C21.533%2C-7.947%2C33.926&LABEL=3B-MO.MS.MRG.3IMERG.20030801-S000000-E235959.08.V06B.HDF5.SUB.nc4&SHORTNAME=GPM_3IMERGM&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitation
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 64217 (63K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20030801-S000000-E235959.08.V06B.HDF5.SUB.nc4’
#
# 3B-MO.MS.MRG.3IMERG 100%[===================>]  62.71K  --.-KB/s    in 0.004s
#
# 2022-07-19 10:02:06 (15.8 MB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20030801-S000000-E235959.08.V06B.HDF5.SUB.nc4’ saved [64217/64217]
#
# --2022-07-19 10:02:06--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGM.06%2F2003%2F3B-MO.MS.MRG.3IMERG.20030901-S000000-E235959.09.V06B.HDF5&FORMAT=bmM0Lw&BBOX=-18.318%2C21.533%2C-7.947%2C33.926&LABEL=3B-MO.MS.MRG.3IMERG.20030901-S000000-E235959.09.V06B.HDF5.SUB.nc4&SHORTNAME=GPM_3IMERGM&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitation
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 64300 (63K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20030901-S000000-E235959.09.V06B.HDF5.SUB.nc4’
#
# 3B-MO.MS.MRG.3IMERG 100%[===================>]  62.79K  --.-KB/s    in 0.005s
#
# 2022-07-19 10:02:08 (12.4 MB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20030901-S000000-E235959.09.V06B.HDF5.SUB.nc4’ saved [64300/64300]
#
# --2022-07-19 10:02:08--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGM.06%2F2003%2F3B-MO.MS.MRG.3IMERG.20031001-S000000-E235959.10.V06B.HDF5&FORMAT=bmM0Lw&BBOX=-18.318%2C21.533%2C-7.947%2C33.926&LABEL=3B-MO.MS.MRG.3IMERG.20031001-S000000-E235959.10.V06B.HDF5.SUB.nc4&SHORTNAME=GPM_3IMERGM&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitation
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 63260 (62K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20031001-S000000-E235959.10.V06B.HDF5.SUB.nc4’
#
# 3B-MO.MS.MRG.3IMERG 100%[===================>]  61.78K  --.-KB/s    in 0.005s
#
# 2022-07-19 10:02:10 (12.7 MB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20031001-S000000-E235959.10.V06B.HDF5.SUB.nc4’ saved [63260/63260]
#
# --2022-07-19 10:02:10--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGM.06%2F2003%2F3B-MO.MS.MRG.3IMERG.20031101-S000000-E235959.11.V06B.HDF5&FORMAT=bmM0Lw&BBOX=-18.318%2C21.533%2C-7.947%2C33.926&LABEL=3B-MO.MS.MRG.3IMERG.20031101-S000000-E235959.11.V06B.HDF5.SUB.nc4&SHORTNAME=GPM_3IMERGM&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitation
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 62577 (61K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20031101-S000000-E235959.11.V06B.HDF5.SUB.nc4’
#
# 3B-MO.MS.MRG.3IMERG 100%[===================>]  61.11K  --.-KB/s    in 0.004s
#
# 2022-07-19 10:02:13 (14.6 MB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20031101-S000000-E235959.11.V06B.HDF5.SUB.nc4’ saved [62577/62577]
#
# --2022-07-19 10:02:13--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGM.06%2F2003%2F3B-MO.MS.MRG.3IMERG.20031201-S000000-E235959.12.V06B.HDF5&FORMAT=bmM0Lw&BBOX=-18.318%2C21.533%2C-7.947%2C33.926&LABEL=3B-MO.MS.MRG.3IMERG.20031201-S000000-E235959.12.V06B.HDF5.SUB.nc4&SHORTNAME=GPM_3IMERGM&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitation
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 61717 (60K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20031201-S000000-E235959.12.V06B.HDF5.SUB.nc4’
#
# 3B-MO.MS.MRG.3IMERG 100%[===================>]  60.27K  --.-KB/s    in 0.003s
#
# 2022-07-19 10:02:15 (23.3 MB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20031201-S000000-E235959.12.V06B.HDF5.SUB.nc4’ saved [61717/61717]
#
# --2022-07-19 10:02:15--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGM.06%2F2004%2F3B-MO.MS.MRG.3IMERG.20040101-S000000-E235959.01.V06B.HDF5&FORMAT=bmM0Lw&BBOX=-18.318%2C21.533%2C-7.947%2C33.926&LABEL=3B-MO.MS.MRG.3IMERG.20040101-S000000-E235959.01.V06B.HDF5.SUB.nc4&SHORTNAME=GPM_3IMERGM&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitation
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# ...
#
# --2022-07-19 10:09:55--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGM.06%2F2020%2F3B-MO.MS.MRG.3IMERG.20200601-S000000-E235959.06.V06B.HDF5&FORMAT=bmM0Lw&BBOX=-18.318%2C21.533%2C-7.947%2C33.926&LABEL=3B-MO.MS.MRG.3IMERG.20200601-S000000-E235959.06.V06B.HDF5.SUB.nc4&SHORTNAME=GPM_3IMERGM&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitation
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 62647 (61K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20200601-S000000-E235959.06.V06B.HDF5.SUB.nc4’
#
# 3B-MO.MS.MRG.3IMERG 100%[===================>]  61.18K  --.-KB/s    in 0.004s
#
# 2022-07-19 10:09:57 (16.3 MB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20200601-S000000-E235959.06.V06B.HDF5.SUB.nc4’ saved [62647/62647]
#
# --2022-07-19 10:09:57--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGM.06%2F2020%2F3B-MO.MS.MRG.3IMERG.20200701-S000000-E235959.07.V06B.HDF5&FORMAT=bmM0Lw&BBOX=-18.318%2C21.533%2C-7.947%2C33.926&LABEL=3B-MO.MS.MRG.3IMERG.20200701-S000000-E235959.07.V06B.HDF5.SUB.nc4&SHORTNAME=GPM_3IMERGM&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitation
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 63278 (62K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20200701-S000000-E235959.07.V06B.HDF5.SUB.nc4’
#
# 3B-MO.MS.MRG.3IMERG 100%[===================>]  61.79K  --.-KB/s    in 0.004s
#
# 2022-07-19 10:09:59 (14.7 MB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20200701-S000000-E235959.07.V06B.HDF5.SUB.nc4’ saved [63278/63278]
#
# --2022-07-19 10:09:59--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGM.06%2F2020%2F3B-MO.MS.MRG.3IMERG.20200801-S000000-E235959.08.V06B.HDF5&FORMAT=bmM0Lw&BBOX=-18.318%2C21.533%2C-7.947%2C33.926&LABEL=3B-MO.MS.MRG.3IMERG.20200801-S000000-E235959.08.V06B.HDF5.SUB.nc4&SHORTNAME=GPM_3IMERGM&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitation
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 63883 (62K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20200801-S000000-E235959.08.V06B.HDF5.SUB.nc4’
#
# 3B-MO.MS.MRG.3IMERG 100%[===================>]  62.39K  --.-KB/s    in 0.007s
#
# 2022-07-19 10:10:02 (8.36 MB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20200801-S000000-E235959.08.V06B.HDF5.SUB.nc4’ saved [63883/63883]
#
# --2022-07-19 10:10:02--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGM.06%2F2020%2F3B-MO.MS.MRG.3IMERG.20200901-S000000-E235959.09.V06B.HDF5&FORMAT=bmM0Lw&BBOX=-18.318%2C21.533%2C-7.947%2C33.926&LABEL=3B-MO.MS.MRG.3IMERG.20200901-S000000-E235959.09.V06B.HDF5.SUB.nc4&SHORTNAME=GPM_3IMERGM&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitation
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 63801 (62K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20200901-S000000-E235959.09.V06B.HDF5.SUB.nc4’
#
# 3B-MO.MS.MRG.3IMERG 100%[===================>]  62.31K  --.-KB/s    in 0.004s
#
# 2022-07-19 10:10:04 (14.6 MB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20200901-S000000-E235959.09.V06B.HDF5.SUB.nc4’ saved [63801/63801]
#
# --2022-07-19 10:10:04--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGM.06%2F2020%2F3B-MO.MS.MRG.3IMERG.20201001-S000000-E235959.10.V06B.HDF5&FORMAT=bmM0Lw&BBOX=-18.318%2C21.533%2C-7.947%2C33.926&LABEL=3B-MO.MS.MRG.3IMERG.20201001-S000000-E235959.10.V06B.HDF5.SUB.nc4&SHORTNAME=GPM_3IMERGM&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitation
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 63554 (62K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20201001-S000000-E235959.10.V06B.HDF5.SUB.nc4’
#
# 3B-MO.MS.MRG.3IMERG 100%[===================>]  62.06K  --.-KB/s    in 0.002s
#
# 2022-07-19 10:10:06 (26.8 MB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20201001-S000000-E235959.10.V06B.HDF5.SUB.nc4’ saved [63554/63554]
#
# --2022-07-19 10:10:06--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGM.06%2F2020%2F3B-MO.MS.MRG.3IMERG.20201101-S000000-E235959.11.V06B.HDF5&FORMAT=bmM0Lw&BBOX=-18.318%2C21.533%2C-7.947%2C33.926&LABEL=3B-MO.MS.MRG.3IMERG.20201101-S000000-E235959.11.V06B.HDF5.SUB.nc4&SHORTNAME=GPM_3IMERGM&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitation
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 63073 (62K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20201101-S000000-E235959.11.V06B.HDF5.SUB.nc4’
#
# 3B-MO.MS.MRG.3IMERG 100%[===================>]  61.59K  --.-KB/s    in 0.002s
#
# 2022-07-19 10:10:09 (26.8 MB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20201101-S000000-E235959.11.V06B.HDF5.SUB.nc4’ saved [63073/63073]
#
# --2022-07-19 10:10:09--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGM.06%2F2020%2F3B-MO.MS.MRG.3IMERG.20201201-S000000-E235959.12.V06B.HDF5&FORMAT=bmM0Lw&BBOX=-18.318%2C21.533%2C-7.947%2C33.926&LABEL=3B-MO.MS.MRG.3IMERG.20201201-S000000-E235959.12.V06B.HDF5.SUB.nc4&SHORTNAME=GPM_3IMERGM&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitation
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 62703 (61K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20201201-S000000-E235959.12.V06B.HDF5.SUB.nc4’
#
# 3B-MO.MS.MRG.3IMERG 100%[===================>]  61.23K  --.-KB/s    in 0.005s
#
# 2022-07-19 10:10:11 (11.8 MB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20201201-S000000-E235959.12.V06B.HDF5.SUB.nc4’ saved [62703/62703]
#
# --2022-07-19 10:10:11--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGM.06%2F2021%2F3B-MO.MS.MRG.3IMERG.20210101-S000000-E235959.01.V06B.HDF5&FORMAT=bmM0Lw&BBOX=-18.318%2C21.533%2C-7.947%2C33.926&LABEL=3B-MO.MS.MRG.3IMERG.20210101-S000000-E235959.01.V06B.HDF5.SUB.nc4&SHORTNAME=GPM_3IMERGM&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitation
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 62775 (61K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20210101-S000000-E235959.01.V06B.HDF5.SUB.nc4’
#
# 3B-MO.MS.MRG.3IMERG 100%[===================>]  61.30K  --.-KB/s    in 0.003s
#
# 2022-07-19 10:10:13 (21.7 MB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20210101-S000000-E235959.01.V06B.HDF5.SUB.nc4’ saved [62775/62775]
#
# --2022-07-19 10:10:13--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGM.06%2F2021%2F3B-MO.MS.MRG.3IMERG.20210201-S000000-E235959.02.V06B.HDF5&FORMAT=bmM0Lw&BBOX=-18.318%2C21.533%2C-7.947%2C33.926&LABEL=3B-MO.MS.MRG.3IMERG.20210201-S000000-E235959.02.V06B.HDF5.SUB.nc4&SHORTNAME=GPM_3IMERGM&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitation
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 62342 (61K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20210201-S000000-E235959.02.V06B.HDF5.SUB.nc4’
#
# 3B-MO.MS.MRG.3IMERG 100%[===================>]  60.88K  --.-KB/s    in 0.003s
#
# 2022-07-19 10:10:16 (23.2 MB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20210201-S000000-E235959.02.V06B.HDF5.SUB.nc4’ saved [62342/62342]
#
# --2022-07-19 10:10:16--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGM.06%2F2021%2F3B-MO.MS.MRG.3IMERG.20210301-S000000-E235959.03.V06B.HDF5&FORMAT=bmM0Lw&BBOX=-18.318%2C21.533%2C-7.947%2C33.926&LABEL=3B-MO.MS.MRG.3IMERG.20210301-S000000-E235959.03.V06B.HDF5.SUB.nc4&SHORTNAME=GPM_3IMERGM&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitation
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 62907 (61K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20210301-S000000-E235959.03.V06B.HDF5.SUB.nc4’
#
# 3B-MO.MS.MRG.3IMERG 100%[===================>]  61.43K  --.-KB/s    in 0.005s
#
# 2022-07-19 10:10:18 (11.5 MB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20210301-S000000-E235959.03.V06B.HDF5.SUB.nc4’ saved [62907/62907]
#
# --2022-07-19 10:10:18--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGM.06%2F2021%2F3B-MO.MS.MRG.3IMERG.20210401-S000000-E235959.04.V06B.HDF5&FORMAT=bmM0Lw&BBOX=-18.318%2C21.533%2C-7.947%2C33.926&LABEL=3B-MO.MS.MRG.3IMERG.20210401-S000000-E235959.04.V06B.HDF5.SUB.nc4&SHORTNAME=GPM_3IMERGM&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitation
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 63922 (62K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20210401-S000000-E235959.04.V06B.HDF5.SUB.nc4’
#
# 3B-MO.MS.MRG.3IMERG 100%[===================>]  62.42K  --.-KB/s    in 0.007s
#
# 2022-07-19 10:10:20 (8.86 MB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20210401-S000000-E235959.04.V06B.HDF5.SUB.nc4’ saved [63922/63922]
#
# --2022-07-19 10:10:20--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGM.06%2F2021%2F3B-MO.MS.MRG.3IMERG.20210501-S000000-E235959.05.V06B.HDF5&FORMAT=bmM0Lw&BBOX=-18.318%2C21.533%2C-7.947%2C33.926&LABEL=3B-MO.MS.MRG.3IMERG.20210501-S000000-E235959.05.V06B.HDF5.SUB.nc4&SHORTNAME=GPM_3IMERGM&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitation
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 64114 (63K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20210501-S000000-E235959.05.V06B.HDF5.SUB.nc4’
#
# 3B-MO.MS.MRG.3IMERG 100%[===================>]  62.61K  --.-KB/s    in 0.008s
#
# 2022-07-19 10:10:23 (7.20 MB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20210501-S000000-E235959.05.V06B.HDF5.SUB.nc4’ saved [64114/64114]
#
# --2022-07-19 10:10:23--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGM.06%2F2021%2F3B-MO.MS.MRG.3IMERG.20210601-S000000-E235959.06.V06B.HDF5&FORMAT=bmM0Lw&BBOX=-18.318%2C21.533%2C-7.947%2C33.926&LABEL=3B-MO.MS.MRG.3IMERG.20210601-S000000-E235959.06.V06B.HDF5.SUB.nc4&SHORTNAME=GPM_3IMERGM&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitation
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 61232 (60K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20210601-S000000-E235959.06.V06B.HDF5.SUB.nc4’
#
# 3B-MO.MS.MRG.3IMERG 100%[===================>]  59.80K  --.-KB/s    in 0.003s
#
# 2022-07-19 10:10:25 (22.5 MB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20210601-S000000-E235959.06.V06B.HDF5.SUB.nc4’ saved [61232/61232]
#
# --2022-07-19 10:10:25--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGM.06%2F2021%2F3B-MO.MS.MRG.3IMERG.20210701-S000000-E235959.07.V06B.HDF5&FORMAT=bmM0Lw&BBOX=-18.318%2C21.533%2C-7.947%2C33.926&LABEL=3B-MO.MS.MRG.3IMERG.20210701-S000000-E235959.07.V06B.HDF5.SUB.nc4&SHORTNAME=GPM_3IMERGM&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitation
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 61991 (61K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20210701-S000000-E235959.07.V06B.HDF5.SUB.nc4’
#
# 3B-MO.MS.MRG.3IMERG 100%[===================>]  60.54K  --.-KB/s    in 0.003s
#
# 2022-07-19 10:10:27 (18.7 MB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20210701-S000000-E235959.07.V06B.HDF5.SUB.nc4’ saved [61991/61991]
#
# --2022-07-19 10:10:27--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGM.06%2F2021%2F3B-MO.MS.MRG.3IMERG.20210801-S000000-E235959.08.V06B.HDF5&FORMAT=bmM0Lw&BBOX=-18.318%2C21.533%2C-7.947%2C33.926&LABEL=3B-MO.MS.MRG.3IMERG.20210801-S000000-E235959.08.V06B.HDF5.SUB.nc4&SHORTNAME=GPM_3IMERGM&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitation
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 64125 (63K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20210801-S000000-E235959.08.V06B.HDF5.SUB.nc4’
#
# 3B-MO.MS.MRG.3IMERG 100%[===================>]  62.62K  --.-KB/s    in 0.004s
#
# 2022-07-19 10:10:30 (16.3 MB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20210801-S000000-E235959.08.V06B.HDF5.SUB.nc4’ saved [64125/64125]
#
# --2022-07-19 10:10:30--  https://gpm1.gesdisc.eosdis.nasa.gov/daac-bin/OTF/HTTP_services.cgi?FILENAME=%2Fdata%2FGPM_L3%2FGPM_3IMERGM.06%2F2021%2F3B-MO.MS.MRG.3IMERG.20210901-S000000-E235959.09.V06B.HDF5&FORMAT=bmM0Lw&BBOX=-18.318%2C21.533%2C-7.947%2C33.926&LABEL=3B-MO.MS.MRG.3IMERG.20210901-S000000-E235959.09.V06B.HDF5.SUB.nc4&SHORTNAME=GPM_3IMERGM&SERVICE=L34RS_GPM&VERSION=1.02&DATASET_VERSION=06&VARIABLES=precipitation
# Connecting to gpm1.gesdisc.eosdis.nasa.gov (gpm1.gesdisc.eosdis.nasa.gov)|198.118.197.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 64520 (63K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20210901-S000000-E235959.09.V06B.HDF5.SUB.nc4’
#
# 3B-MO.MS.MRG.3IMERG 100%[===================>]  63.01K  --.-KB/s    in 0.004s
#
# 2022-07-19 10:10:32 (15.3 MB/s) - ‘/content/drive/MyDrive/IWMI/IMERG_mm_hr/3B-MO.MS.MRG.3IMERG.20210901-S000000-E235959.09.V06B.HDF5.SUB.nc4’ saved [64520/64520]
#
# FINISHED --2022-07-19 10:10:32--
# Total wall clock time: 10m 1s
# Downloaded: 258 files, 18M in 1.2s (14.6 MB/s)

# %% [markdown]
# ### 3.3. Configure the Python environment
# This code for calculating SPI is written in Python 3. It is recommended to use either the [Miniconda3](https://docs.conda.io/en/latest/miniconda.html) (minimal Anaconda) or Anaconda3 distribution. The below instructions will be Anaconda specific (although relevant to any Python [virtual environment](https://virtualenv.pypa.io/en/stable/)).
#
# A new Anaconda [environment](https://conda.io/docs/using/envs.html) can be created using the [conda](https://conda.io/docs/) environment management system that comes packaged with Anaconda. Note: you may need to restart the kernel to use some updated packages. The ```conda``` bash should be run in colab terminal which is provided for colab pro user.

# %% [markdown]
# ##### Conda
# ```conda``` is not preinstalled in the default configuration in Colab. Check the following blog to know more details about how to fix it.
#
# https://rjai.me/posts/google-colab-conda/

# %%
# new code
# !wget https://repo.anaconda.com/archive/Anaconda3-2020.02-Linux-x86_64.sh && bash Anaconda3-2020.02-Linux-x86_64.sh -bfp /usr/local
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# pytest-astropy==0.8.0=py_0 -> pytest[version='>=3.1'] -> setuptools[version='>=40.0']
# anaconda-navigator==1.9.12=py37_0 -> setuptools
# clyent==1.2.2=py37_1 -> setuptools
# anaconda-project==0.8.4=py_0 -> anaconda-client -> setuptools
# flake8==3.7.9=py37_0 -> setuptools[version='>=30.0.0']
# conda-build==3.18.11=py37_0 -> conda[version='>=4.5'] -> setuptools[version='>=31.0.1']
# numba==0.48.0=py37h0573a6f_0 -> setuptools
# scikit-image==0.16.2=py37h0573a6f_0 -> networkx[version='>=2.0'] -> setuptools
# spyder==4.0.1=py37_0 -> pygments[version='>=2.0'] -> setuptools
# bleach==3.1.0=py37_0 -> setuptools
# isort==4.3.21=py37_0 -> setuptools
# pygments==2.5.2=py_0 -> setuptools
# numpydoc==0.9.2=py_0 -> sphinx -> setuptools
# nbconvert==5.6.1=py37_0 -> bleach -> setuptools
# nose==1.3.7=py37_2 -> setuptools
# pylint==2.4.4=py37_0 -> astroid[version='>=2.3.0,<2.4'] -> setuptools
# python=3.7 -> pip -> setuptools
# anaconda-client==1.7.2=py37_0 -> setuptools
# pytest-remotedata==0.3.2=py37_0 -> pytest[version='>=3.1'] -> setuptools[version='>=40.0']
# conda-build==3.18.11=py37_0 -> setuptools
# ipykernel==5.1.4=py37h39e3cac_0 -> ipython[version='>=5.0'] -> setuptools[version='>=18.5']
# pytest-astropy-header==0.1.2=py_0 -> pytest[version='>=3.0'] -> setuptools[version='>=40.0']
# jinja2==2.11.1=py_0 -> setuptools
# networkx==2.4=py_0 -> setuptools
# pip==20.0.2=py37_1 -> setuptools
# matplotlib==3.1.3=py37_0 -> matplotlib-base==3.1.3=py37hef1b27d_0 -> setuptools
# scikit-learn==0.22.1=py37hd81dba3_0 -> joblib[version='>=0.11'] -> setuptools
# notebook==6.0.3=py37_0 -> jinja2 -> setuptools
#
# Package expat conflicts for:
# secretstorage==3.1.2=py37_0 -> dbus -> expat[version='>=2.2.6,<3.0a0']
# pyqt==5.9.2=py37h05f1152_2 -> dbus[version='>=1.13.2,<2.0a0'] -> expat[version='>=2.2.6,<3.0a0']
# expat==2.2.6=he6710b0_0
# anaconda==2020.02=py37_0 -> dbus==1.13.12=h746ee38_0 -> expat[version='>=2.2.6,<3.0a0']
# qt==5.9.7=h5867ecd_1 -> expat[version='>=2.2.6,<3.0a0']
# dbus==1.13.12=h746ee38_0 -> expat[version='>=2.2.6,<3.0a0']
# anaconda==2020.02=py37_0 -> expat==2.2.6=he6710b0_0
#
# Package xz conflicts for:
# qtconsole==4.6.0=py_1 -> python -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# wheel==0.34.2=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# widgetsnbextension==3.5.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# sphinxcontrib-applehelp==1.0.1=py_0 -> python[version='>=3.5'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# mccabe==0.6.1=py37_1 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# html5lib==1.0.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# qt==5.9.7=h5867ecd_1 -> gst-plugins-base[version='>=1.14.0,<1.15.0a0'] -> xz[version='>=5.2.3,<6.0a0|>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# et_xmlfile==1.0.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# anaconda==2020.02=py37_0 -> xz==5.2.4=h14c3975_4
# psutil==5.6.7=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# xlrd==1.2.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# scikit-image==0.16.2=py37h0573a6f_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# backcall==0.1.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# cytoolz==0.10.1=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# pandas==1.0.1=py37h0573a6f_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# mkl_fft==1.0.15=py37ha843d7b_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# boto==2.49.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# ptyprocess==0.6.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# parso==0.5.2=py_0 -> python -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# more-itertools==8.2.0=py_0 -> python[version='>=3.4'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# diff-match-patch==20181111=py_0 -> python -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# watchdog==0.10.2=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# jupyter_client==5.3.4=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# pydocstyle==4.0.1=py_0 -> python[version='>=3.4'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# pango==1.42.4=h049681c_0 -> xz[version='>=5.2.4,<6.0a0']
# jupyter==1.0.0=py37_7 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# tornado==6.0.3=py37h7b6447c_3 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# bokeh==1.4.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# toolz==0.10.0=py_0 -> python -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# matplotlib-base==3.1.3=py37hef1b27d_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# itsdangerous==1.1.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# pathtools==0.1.2=py_1 -> python -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# astropy==4.0=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# clyent==1.2.2=py37_1 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# pluggy==0.13.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# astroid==2.3.3=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# fastcache==1.1.0=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# statsmodels==0.11.0=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# chardet==3.0.4=py37_1003 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# pillow==7.0.0=py37hb39fc2d_0 -> libtiff[version='>=4.1.0,<5.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# anaconda-project==0.8.4=py_0 -> python -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# navigator-updater==0.2.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# conda-build==3.18.11=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# werkzeug==1.0.0=py_0 -> python -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# h5py==2.10.0=py37h7918eee_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# _ipyw_jlab_nb_ext_conf==0.1.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# mkl-service==2.3.0=py37he904b0f_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# pyopenssl==19.1.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# numpy-base==1.18.1=py37hde5b4d6_1 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# jeepney==0.4.2=py_0 -> python[version='>=3.5'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# cffi==1.14.0=py37h2e261b9_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# pathlib2==2.3.5=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# webencodings==0.5.1=py37_1 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# xlwt==1.3.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# kiwisolver==1.1.0=py37he6710b0_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# beautifulsoup4==4.8.2=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# future==0.18.2=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# rtree==0.9.3=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# scipy==1.4.1=py37h0b6359f_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# pytest==5.3.5=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# glob2==0.7=py_0 -> python -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# jinja2==2.11.1=py_0 -> python -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# jedi==0.14.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# unicodecsv==0.14.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# nbconvert==5.6.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# python-language-server==0.31.7=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# python==3.7.6=h0371630_2 -> xz[version='>=5.2.4,<6.0a0']
# contextlib2==0.6.0.post1=py_0 -> python -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# pyflakes==2.1.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# msgpack-python==0.6.1=py37hfd86e86_1 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# pytables==3.6.1=py37h71ec239_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# python-dateutil==2.8.1=py_0 -> python -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# llvmlite==0.31.0=py37hd408876_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# bkcharts==0.2=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# sphinxcontrib==1.0=py37_1 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# jupyterlab_server==1.0.6=py_0 -> python[version='>=3.5'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# pytest-openfiles==0.4.0=py_0 -> python -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# xmltodict==0.12.0=py_0 -> python -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# cryptography==2.8=py37h1ba5d50_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# sphinxcontrib-serializinghtml==1.1.3=py_0 -> python[version='>=3.5'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# numpydoc==0.9.2=py_0 -> python -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# qtpy==1.9.0=py_0 -> python -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# harfbuzz==1.8.8=hffaf4a1_0 -> cairo[version='>=1.14.12,<2.0a0'] -> xz[version='>=5.2.4,<6.0a0']
# pyxdg==0.26=py_0 -> python -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# pycosat==0.6.3=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# qdarkstyle==2.8=py_0 -> python -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# pycrypto==2.6.1=py37h14c3975_9 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# attrs==19.3.0=py_0 -> python -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# pycurl==7.43.0.5=py37h1ba5d50_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# tqdm==4.42.1=py_0 -> python -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# urllib3==1.25.8=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# sphinxcontrib-devhelp==1.0.1=py_0 -> python[version='>=3.5'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# setuptools==45.2.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# pickleshare==0.7.5=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# docutils==0.16=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# libtiff==4.1.0=h2733197_0 -> xz[version='>=5.2.4,<6.0a0']
# seaborn==0.10.0=py_0 -> python[version='>=3.6'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# rope==0.16.0=py_0 -> python -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# flask==1.1.1=py_0 -> python -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# gstreamer==1.14.0=hb453b48_1 -> xz[version='>=5.2.3,<6.0a0']
# prometheus_client==0.7.1=py_0 -> python -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# pexpect==4.8.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# pytest-astropy==0.8.0=py_0 -> python -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# jupyter_core==4.6.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# conda==4.8.2=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# nose==1.3.7=py37_2 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# certifi==2019.11.28=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# libarchive==3.3.3=h5d8350f_5 -> libxml2[version='>=2.9.8,<2.10.0a0'] -> xz[version='>=5.2.5,<5.3.0a0']
# singledispatch==3.4.0.3=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# qtawesome==0.6.1=py_0 -> python -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# spyder-kernels==1.8.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# wcwidth==0.1.8=py_0 -> python -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# hypothesis==5.5.4=py_0 -> python[version='>=3.5'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# tblib==1.6.0=py_0 -> python -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# lxml==4.5.0=py37hefd8a0e_0 -> libxml2[version='>=2.9.9,<2.10.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# jupyter_console==6.1.0=py_0 -> python[version='>=3.5'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# pysocks==1.7.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# spyder==4.0.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# pytest-astropy-header==0.1.2=py_0 -> python -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# sphinxcontrib-jsmath==1.0.1=py_0 -> python[version='>=3.5'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# keyring==21.1.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# greenlet==0.4.15=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# soupsieve==1.9.5=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# python=3.7 -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# terminado==0.8.3=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# babel==2.8.0=py_0 -> python -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# snowballstemmer==2.0.0=py_0 -> python -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# notebook==6.0.3=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# pytest-doctestplus==0.5.0=py_0 -> python -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# mamba -> libarchive[version='>=3.5.1,<3.6.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# pytest-arraydiff==0.3=py37h39e3cac_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# sqlalchemy==1.3.13=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# nltk==3.4.5=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# backports.weakref==1.0.post1=py_1 -> python -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# pyrsistent==0.15.7=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# conda-verify==3.4.2=py_1 -> python -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# sphinxcontrib-qthelp==1.0.2=py_0 -> python[version='>=3.5'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# zipp==2.2.0=py_0 -> python[version='>=3.6'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# pygments==2.5.2=py_0 -> python -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# intervaltree==3.0.2=py_0 -> python -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# testpath==0.4.4=py_0 -> python -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# argh==0.26.2=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# gmpy2==2.0.8=py37h10f8cd9_2 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# dask-core==2.11.0=py_0 -> python[version='>=3.6'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# wrapt==1.11.2=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# colorama==0.4.3=py_0 -> python -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# cython==0.29.15=py37he6710b0_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# alabaster==0.7.12=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# imageio==2.6.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# flake8==3.7.9=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# six==1.14.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# sip==4.19.8=py37hf484d3e_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# pyodbc==4.0.30=py37he6710b0_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# importlib_metadata==1.5.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# anaconda-client==1.7.2=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# ruamel_yaml==0.15.87=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# nbformat==5.0.4=py_0 -> python[version='>=3.5'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# simplegeneric==0.8.1=py37_2 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# ipywidgets==7.5.1=py_0 -> python -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# pandocfilters==1.4.2=py37_1 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# backports.functools_lru_cache==1.6.1=py_0 -> python -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# numexpr==2.7.1=py37h423224d_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# ujson==1.35=py37h14c3975_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# backports.shutil_get_terminal_size==1.0.0=py37_2 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# autopep8==1.4.4=py_0 -> python -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# distributed==2.11.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# ipython==7.12.0=py37h5ca1d4c_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# isort==4.3.21=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# backports==1.0=py_2 -> python -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# pylint==2.4.4=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# path==13.1.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# ipython_genutils==0.2.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# xz==5.2.4=h14c3975_4
# numba==0.48.0=py37h0573a6f_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# cycler==0.10.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# numpy==1.18.1=py37h4f9e942_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# entrypoints==0.3=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# requests==2.22.0=py37_1 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# bleach==3.1.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# python-libarchive-c==2.8=py37_13 -> libarchive -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# path.py==12.4.0=0 -> python[version='>=3.5'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# scikit-learn==0.22.1=py37hd81dba3_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# idna==2.8=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# libxslt==1.1.33=h7d1a2b0_0 -> libxml2[version='>=2.9.8,<2.10.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# markupsafe==1.1.1=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# mkl_random==1.1.0=py37hd6b4f25_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# pycodestyle==2.5.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# py-lief==0.9.0=py37h7725739_2 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# pyzmq==18.1.1=py37he6710b0_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# sphinxcontrib-websupport==1.2.0=py_0 -> python -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# blosc==1.16.3=hd408876_0 -> zstd[version='>=1.3.7,<1.3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0']
# sympy==1.5.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# zict==1.0.0=py_0 -> python -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# py==1.8.1=py_0 -> python -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# pycparser==2.19=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# packaging==20.1=py_0 -> python -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# filelock==3.0.12=py_0 -> python -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# sphinxcontrib-htmlhelp==1.0.2=py_0 -> python[version='>=3.5'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# jdcal==1.4.1=py_0 -> python -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# bitarray==1.2.1=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# dask==2.11.0=py_0 -> python[version='>=3.6'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# olefile==0.46=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# pep8==1.7.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# prompt_toolkit==3.0.3=py_0 -> python[version='>=3.6'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# bottleneck==1.3.2=py37heb32a55_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# mpmath==1.1.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# sphinx==2.4.0=py_0 -> python[version='>=3.5'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# click==7.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# python_abi -> python=3.7 -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# traitlets==4.3.3=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# fsspec==0.6.2=py_0 -> python[version='>=3.5'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# backports.tempfile==1.0=py_1 -> python -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# pytz==2019.3=py_0 -> python -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# pytest-remotedata==0.3.2=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# cairo==1.14.12=h8948797_3 -> xz[version='>=5.2.4,<6.0a0']
# sortedcollections==1.1.2=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# patsy==0.5.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# mock==4.0.1=py_0 -> python[version='>=3.6'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# pyyaml==5.3=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# gst-plugins-base==1.14.0=hbbd80ab_1 -> xz[version='>=5.2.3,<6.0a0']
# jupyterlab==1.2.6=pyhf63ae98_0 -> python[version='>=3.5'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# heapdict==1.0.1=py_0 -> python -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# decorator==4.4.1=py_0 -> python -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# python-jsonrpc-server==0.3.4=py_0 -> python -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# wurlitzer==2.0.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# locket==0.2.0=py37_1 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# conda-package-handling==1.6.0=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# atomicwrites==1.3.0=py37_1 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# pkginfo==1.5.0.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# brotlipy -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# asn1crypto==1.3.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# send2trash==1.5.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# libxml2==2.9.9=hea5a465_1 -> xz[version='>=5.2.4,<6.0a0']
# fontconfig==2.13.0=h9420a91_0 -> libxml2[version='>=2.9.8,<2.10.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# pango==1.42.4=h049681c_0 -> libxml2[version='>=2.9.8,<2.10.0a0'] -> xz[version='>=5.2.5,<5.3.0a0']
# jsonschema==3.2.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# pyqt==5.9.2=py37h05f1152_2 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# gevent==1.4.0=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# openpyxl==3.0.3=py_0 -> python[version='>=3.6'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# secretstorage==3.1.2=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# imagesize==1.2.0=py_0 -> python -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# anaconda==2020.02=py37_0 -> cairo==1.14.12=h8948797_3 -> xz[version='>=5.2.3,<6.0a0|>=5.2.4,<6.0a0']
# libarchive==3.3.3=h5d8350f_5 -> xz[version='>=5.2.4,<6.0a0']
# networkx==2.4=py_0 -> python[version='>=3.5'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# zstd==1.3.7=h0b5b093_0 -> xz[version='>=5.2.4,<6.0a0']
# lazy-object-proxy==1.4.3=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# anaconda-navigator==1.9.12=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# defusedxml==0.6.0=py_0 -> python -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# cloudpickle==1.3.0=py_0 -> python[version='>=3'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# pywavelets==1.1.1=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# ipykernel==5.1.4=py37h39e3cac_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# joblib==0.14.1=py_0 -> python -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# multipledispatch==0.6.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# yapf==0.28.0=py_0 -> python -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# pyparsing==2.4.6=py_0 -> python -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# partd==1.1.0=py_0 -> python[version='>=3.5'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# xlsxwriter==1.2.7=py_0 -> python -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# json5==0.9.1=py_0 -> python -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# sortedcontainers==2.1.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# matplotlib==3.1.3=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# mistune==0.8.4=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
# pip==20.0.2=py37_1 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<5.3.0a0']
#
# Package ncurses conflicts for:
# sip==4.19.8=py37hf484d3e_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# wrapt==1.11.2=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# backports==1.0=py_2 -> python -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# nbconvert==5.6.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# pyyaml==5.3=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# py==1.8.1=py_0 -> python -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# conda-build==3.18.11=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# terminado==0.8.3=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# astropy==4.0=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# et_xmlfile==1.0.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# jupyter_core==4.6.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# wurlitzer==2.0.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# anaconda==2020.02=py37_0 -> ncurses==6.2=he6710b0_0
# certifi==2019.11.28=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# nose==1.3.7=py37_2 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# anaconda-client==1.7.2=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# rope==0.16.0=py_0 -> python -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# python-libarchive-c==2.8=py37_13 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# python-dateutil==2.8.1=py_0 -> python -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# libedit==3.1.20181209=hc058e9b_0 -> ncurses[version='>=6.1,<7.0a0']
# pytest-astropy-header==0.1.2=py_0 -> python -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# watchdog==0.10.2=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# multipledispatch==0.6.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# qtpy==1.9.0=py_0 -> python -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# future==0.18.2=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# pytest-doctestplus==0.5.0=py_0 -> python -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# markupsafe==1.1.1=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# autopep8==1.4.4=py_0 -> python -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# jedi==0.14.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# psutil==5.6.7=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# click==7.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# qdarkstyle==2.8=py_0 -> python -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# pep8==1.7.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# ptyprocess==0.6.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# itsdangerous==1.1.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# python_abi -> python=3.7 -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# pyzmq==18.1.1=py37he6710b0_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# sphinxcontrib-jsmath==1.0.1=py_0 -> python[version='>=3.5'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# mpmath==1.1.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# cryptography==2.8=py37h1ba5d50_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# atomicwrites==1.3.0=py37_1 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# jdcal==1.4.1=py_0 -> python -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# anaconda-navigator==1.9.12=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# pytest-arraydiff==0.3=py37h39e3cac_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# conda-package-handling==1.6.0=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# partd==1.1.0=py_0 -> python[version='>=3.5'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# pytest-openfiles==0.4.0=py_0 -> python -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# locket==0.2.0=py37_1 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# prometheus_client==0.7.1=py_0 -> python -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# ipython==7.12.0=py37h5ca1d4c_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# numexpr==2.7.1=py37h423224d_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# sphinxcontrib-qthelp==1.0.2=py_0 -> python[version='>=3.5'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# diff-match-patch==20181111=py_0 -> python -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# pyparsing==2.4.6=py_0 -> python -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# tornado==6.0.3=py37h7b6447c_3 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# kiwisolver==1.1.0=py37he6710b0_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# pillow==7.0.0=py37hb39fc2d_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# astroid==2.3.3=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# contextlib2==0.6.0.post1=py_0 -> python -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# xlwt==1.3.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# singledispatch==3.4.0.3=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# zipp==2.2.0=py_0 -> python[version='>=3.6'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# pyqt==5.9.2=py37h05f1152_2 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# conda==4.8.2=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# beautifulsoup4==4.8.2=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# nltk==3.4.5=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# brotlipy -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# sortedcontainers==2.1.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# greenlet==0.4.15=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# pycurl==7.43.0.5=py37h1ba5d50_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# bottleneck==1.3.2=py37heb32a55_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# glob2==0.7=py_0 -> python -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# jupyterlab==1.2.6=pyhf63ae98_0 -> python[version='>=3.5'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# testpath==0.4.4=py_0 -> python -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# numpy==1.18.1=py37h4f9e942_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# sphinxcontrib-devhelp==1.0.1=py_0 -> python[version='>=3.5'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# olefile==0.46=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# pandocfilters==1.4.2=py37_1 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# ruamel_yaml==0.15.87=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# openpyxl==3.0.3=py_0 -> python[version='>=3.6'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# cython==0.29.15=py37he6710b0_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# widgetsnbextension==3.5.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# hypothesis==5.5.4=py_0 -> python[version='>=3.5'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# qtconsole==4.6.0=py_1 -> python -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# asn1crypto==1.3.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# mccabe==0.6.1=py37_1 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# pycparser==2.19=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# cloudpickle==1.3.0=py_0 -> python[version='>=3'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# conda-verify==3.4.2=py_1 -> python -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# attrs==19.3.0=py_0 -> python -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# matplotlib-base==3.1.3=py37hef1b27d_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# mamba -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# sphinx==2.4.0=py_0 -> python[version='>=3.5'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# h5py==2.10.0=py37h7918eee_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# webencodings==0.5.1=py37_1 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# pathlib2==2.3.5=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# sphinxcontrib-websupport==1.2.0=py_0 -> python -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# tblib==1.6.0=py_0 -> python -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# jsonschema==3.2.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# wcwidth==0.1.8=py_0 -> python -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# entrypoints==0.3=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# python-language-server==0.31.7=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# sqlite==3.31.1=h7b6447c_0 -> libedit[version='>=3.1.20181209,<3.2.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# imagesize==1.2.0=py_0 -> python -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# mkl_random==1.1.0=py37hd6b4f25_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# xmltodict==0.12.0=py_0 -> python -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# joblib==0.14.1=py_0 -> python -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# sphinxcontrib-applehelp==1.0.1=py_0 -> python[version='>=3.5'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# tqdm==4.42.1=py_0 -> python -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# nbformat==5.0.4=py_0 -> python[version='>=3.5'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# clyent==1.2.2=py37_1 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# chardet==3.0.4=py37_1003 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# pyflakes==2.1.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# qt==5.9.7=h5867ecd_1 -> sqlite[version='>=3.25.3,<4.0a0'] -> ncurses[version='>=6.2,<6.3.0a0']
# pandas==1.0.1=py37h0573a6f_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# bkcharts==0.2=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# imageio==2.6.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# python=3.7 -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# pathtools==0.1.2=py_1 -> python -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# babel==2.8.0=py_0 -> python -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# sphinxcontrib-htmlhelp==1.0.2=py_0 -> python[version='>=3.5'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# jupyter_client==5.3.4=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# qtawesome==0.6.1=py_0 -> python -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# decorator==4.4.1=py_0 -> python -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# sqlalchemy==1.3.13=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# setuptools==45.2.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# traitlets==4.3.3=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# werkzeug==1.0.0=py_0 -> python -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# ipywidgets==7.5.1=py_0 -> python -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# json5==0.9.1=py_0 -> python -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# mock==4.0.1=py_0 -> python[version='>=3.6'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# dask-core==2.11.0=py_0 -> python[version='>=3.6'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# anaconda-project==0.8.4=py_0 -> python -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# dask==2.11.0=py_0 -> python[version='>=3.6'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# pycosat==0.6.3=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# statsmodels==0.11.0=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# keyring==21.1.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# pickleshare==0.7.5=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# wheel==0.34.2=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# pydocstyle==4.0.1=py_0 -> python[version='>=3.4'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# bleach==3.1.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# lazy-object-proxy==1.4.3=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# unicodecsv==0.14.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# gmpy2==2.0.8=py37h10f8cd9_2 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# sphinxcontrib-serializinghtml==1.1.3=py_0 -> python[version='>=3.5'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# pyodbc==4.0.30=py37he6710b0_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# pyxdg==0.26=py_0 -> python -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# colorama==0.4.3=py_0 -> python -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# ncurses==6.2=he6710b0_0
# bitarray==1.2.1=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# mistune==0.8.4=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# notebook==6.0.3=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# more-itertools==8.2.0=py_0 -> python[version='>=3.4'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# pytables==3.6.1=py37h71ec239_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# pysocks==1.7.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# intervaltree==3.0.2=py_0 -> python -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# numba==0.48.0=py37h0573a6f_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# sortedcollections==1.1.2=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# pywavelets==1.1.1=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# isort==4.3.21=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# mkl_fft==1.0.15=py37ha843d7b_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# pylint==2.4.4=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# ipython_genutils==0.2.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# numpy-base==1.18.1=py37hde5b4d6_1 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# backports.weakref==1.0.post1=py_1 -> python -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# seaborn==0.10.0=py_0 -> python[version='>=3.6'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# sphinxcontrib==1.0=py37_1 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# packaging==20.1=py_0 -> python -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# urllib3==1.25.8=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# pytest-astropy==0.8.0=py_0 -> python -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# pyrsistent==0.15.7=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# docutils==0.16=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# ipykernel==5.1.4=py37h39e3cac_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# scikit-learn==0.22.1=py37hd81dba3_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# pluggy==0.13.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# krb5==1.17.1=h173b8e3_0 -> libedit[version='>=3.1.20181209,<3.2.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# bokeh==1.4.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# pkginfo==1.5.0.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# requests==2.22.0=py37_1 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# flake8==3.7.9=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# py-lief==0.9.0=py37h7725739_2 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# path==13.1.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# readline==7.0=h7b6447c_5 -> ncurses[version='>=6.1,<7.0a0']
# spyder-kernels==1.8.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# llvmlite==0.31.0=py37hd408876_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# rtree==0.9.3=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.1,<7.0a0|>=6.2,<6.3.0a0']
# ...
# sphinx==2.4.0=py_0 -> sphinxcontrib-serializinghtml
# anaconda==2020.02=py37_0 -> sphinx==2.4.0=py_0 -> sphinxcontrib-serializinghtml
# numpydoc==0.9.2=py_0 -> sphinx -> sphinxcontrib-serializinghtml
# spyder==4.0.1=py37_0 -> sphinx -> sphinxcontrib-serializinghtml
#
# Package libgomp conflicts for:
# _openmp_mutex -> libgomp[version='>=7.5.0']
# libgomp
#
# Package diff-match-patch conflicts for:
# anaconda==2020.02=py37_0 -> diff-match-patch==20181111=py_0
# anaconda==2020.02=py37_0 -> spyder==4.0.1=py37_0 -> diff-match-patch
# diff-match-patch==20181111=py_0
# spyder==4.0.1=py37_0 -> diff-match-patch
#
# Package backports.tempfile conflicts for:
# backports.tempfile==1.0=py_1
# conda-verify==3.4.2=py_1 -> backports.tempfile
#
# Package backports.functools_lru_cache conflicts for:
# conda-verify==3.4.2=py_1 -> backports.functools_lru_cache
# backports.functools_lru_cache==1.6.1=py_0
#
# Package tblib conflicts for:
# distributed==2.11.0=py37_0 -> tblib[version='>=1.6.0']
# anaconda==2020.02=py37_0 -> distributed==2.11.0=py37_0 -> tblib[version='>=1.6.0']
# tblib==1.6.0=py_0
# anaconda==2020.02=py37_0 -> tblib==1.6.0=py_0
# dask==2.11.0=py_0 -> distributed[version='>=2.11.0'] -> tblib[version='>=1.6.0']
#
# Package qdarkstyle conflicts for:
# anaconda==2020.02=py37_0 -> qdarkstyle==2.8=py_0
# anaconda==2020.02=py37_0 -> spyder==4.0.1=py37_0 -> qdarkstyle[version='>=2.7']
# spyder==4.0.1=py37_0 -> qdarkstyle[version='>=2.7']
# qdarkstyle==2.8=py_0
#
# Package mock conflicts for:
# anaconda==2020.02=py37_0 -> mock==4.0.1=py_0
# anaconda==2020.02=py37_0 -> pytables==3.6.1=py37h71ec239_0 -> mock
# pytables==3.6.1=py37h71ec239_0 -> mock
# mock==4.0.1=py_0
#
# Package ipywidgets conflicts for:
# anaconda==2020.02=py37_0 -> ipywidgets==7.5.1=py_0
# anaconda==2020.02=py37_0 -> jupyter==1.0.0=py37_7 -> ipywidgets
# jupyter==1.0.0=py37_7 -> ipywidgets
# ipywidgets==7.5.1=py_0
# _ipyw_jlab_nb_ext_conf==0.1.0=py37_0 -> ipywidgets
#
# Package wrapt conflicts for:
# wrapt==1.11.2=py37h7b6447c_0
# anaconda==2020.02=py37_0 -> wrapt==1.11.2=py37h7b6447c_0
# pylint==2.4.4=py37_0 -> astroid[version='>=2.3.0,<2.4'] -> wrapt
# astroid==2.3.3=py37_0 -> wrapt
# anaconda==2020.02=py37_0 -> astroid==2.3.3=py37_0 -> wrapt
#
# Package bkcharts conflicts for:
# anaconda==2020.02=py37_0 -> bkcharts==0.2=py37_0
# bkcharts==0.2=py37_0
#
# Package gmpy2 conflicts for:
# sympy==1.5.1=py37_0 -> gmpy2[version='>=2.0.8']
# anaconda==2020.02=py37_0 -> gmpy2==2.0.8=py37h10f8cd9_2
# anaconda==2020.02=py37_0 -> sympy==1.5.1=py37_0 -> gmpy2[version='>=2.0.8']
# gmpy2==2.0.8=py37h10f8cd9_2
#
# Package kiwisolver conflicts for:
# anaconda==2020.02=py37_0 -> kiwisolver==1.1.0=py37he6710b0_0
# anaconda==2020.02=py37_0 -> matplotlib-base==3.1.3=py37hef1b27d_0 -> kiwisolver
# matplotlib==3.1.3=py37_0 -> matplotlib-base==3.1.3=py37hef1b27d_0 -> kiwisolver
# kiwisolver==1.1.0=py37he6710b0_0
# matplotlib-base==3.1.3=py37hef1b27d_0 -> kiwisolver
#
# Package libsodium conflicts for:
# anaconda==2020.02=py37_0 -> zeromq==4.3.1=he6710b0_3 -> libsodium[version='>=1.0.16,<1.0.17.0a0']
# pyzmq==18.1.1=py37he6710b0_0 -> zeromq[version='>=4.3.1,<4.4.0a0'] -> libsodium[version='>=1.0.16,<1.0.17.0a0']
# libsodium==1.0.16=h1bed415_0
# anaconda==2020.02=py37_0 -> libsodium==1.0.16=h1bed415_0
# zeromq==4.3.1=he6710b0_3 -> libsodium[version='>=1.0.16,<1.0.17.0a0']
#
# Package fontconfig conflicts for:
# anaconda==2020.02=py37_0 -> cairo==1.14.12=h8948797_3 -> fontconfig[version='>=2.13.0,<3.0a0']
# anaconda==2020.02=py37_0 -> fontconfig==2.13.0=h9420a91_0
# pango==1.42.4=h049681c_0 -> fontconfig[version='>=2.13.0,<3.0a0']
# pyqt==5.9.2=py37h05f1152_2 -> qt=5.9 -> fontconfig[version='>=2.13.0,<3.0a0']
# qt==5.9.7=h5867ecd_1 -> fontconfig[version='>=2.13.0,<3.0a0']
# fontconfig==2.13.0=h9420a91_0
# harfbuzz==1.8.8=hffaf4a1_0 -> cairo[version='>=1.14.12,<2.0a0'] -> fontconfig[version='>=2.13.0,<3.0a0']
# cairo==1.14.12=h8948797_3 -> fontconfig[version='>=2.13.0,<3.0a0']
#
# Package cython conflicts for:
# cython==0.29.15=py37he6710b0_0
# anaconda==2020.02=py37_0 -> cython==0.29.15=py37he6710b0_0
#
# Package libnghttp2 conflicts for:
# mamba -> libcurl[version='>=7.75.0,<8.0a0'] -> libnghttp2[version='>=1.43.0,<2.0a0']
# pycurl==7.43.0.5=py37h1ba5d50_0 -> libcurl[version='>=7.67.0,<8.0a0'] -> libnghttp2[version='>=1.43.0,<2.0a0']
# libnghttp2
#
# Package anaconda-project conflicts for:
# anaconda-project==0.8.4=py_0
# anaconda==2020.02=py37_0 -> anaconda-project==0.8.4=py_0
#
# Package sphinxcontrib-qthelp conflicts for:
# sphinxcontrib-qthelp==1.0.2=py_0
# sphinx==2.4.0=py_0 -> sphinxcontrib-qthelp
# anaconda==2020.02=py37_0 -> sphinxcontrib-qthelp==1.0.2=py_0
# anaconda==2020.02=py37_0 -> sphinx==2.4.0=py_0 -> sphinxcontrib-qthelp
# spyder==4.0.1=py37_0 -> sphinx -> sphinxcontrib-qthelp
# numpydoc==0.9.2=py_0 -> sphinx -> sphinxcontrib-qthelp
#
# Package clyent conflicts for:
# anaconda==2020.02=py37_0 -> clyent==1.2.2=py37_1
# clyent==1.2.2=py37_1
# anaconda-project==0.8.4=py_0 -> anaconda-client -> clyent[version='>=1.2.2']
# anaconda-client==1.7.2=py37_0 -> clyent[version='>=1.2.2']
# anaconda==2020.02=py37_0 -> anaconda-client==1.7.2=py37_0 -> clyent[version='>=1.2.2']
# anaconda-navigator==1.9.12=py37_0 -> anaconda-client[version='>=1.6.14'] -> clyent[version='>=1.2.2']
#
# Package itsdangerous conflicts for:
# anaconda==2020.02=py37_0 -> flask==1.1.1=py_0 -> itsdangerous[version='>=0.24']
# flask==1.1.1=py_0 -> itsdangerous[version='>=0.24']
# anaconda==2020.02=py37_0 -> itsdangerous==1.1.0=py37_0
# itsdangerous==1.1.0=py37_0
#
# Package libuuid conflicts for:
# qt==5.9.7=h5867ecd_1 -> fontconfig[version='>=2.13.0,<3.0a0'] -> libuuid[version='>=1.0.3,<2.0a0']
# fontconfig==2.13.0=h9420a91_0 -> libuuid[version='>=1.0.3,<2.0a0']
# libuuid==1.0.3=h1bed415_2
# pango==1.42.4=h049681c_0 -> libuuid[version='>=1.0.3,<2.0a0']
# cairo==1.14.12=h8948797_3 -> fontconfig[version='>=2.13.0,<3.0a0'] -> libuuid[version='>=1.0.3,<2.0a0']
# anaconda==2020.02=py37_0 -> libuuid==1.0.3=h1bed415_2
# anaconda==2020.02=py37_0 -> fontconfig==2.13.0=h9420a91_0 -> libuuid[version='>=1.0.3,<2.0a0']
#
# Package sphinxcontrib-applehelp conflicts for:
# spyder==4.0.1=py37_0 -> sphinx -> sphinxcontrib-applehelp
# numpydoc==0.9.2=py_0 -> sphinx -> sphinxcontrib-applehelp
# sphinx==2.4.0=py_0 -> sphinxcontrib-applehelp
# sphinxcontrib-applehelp==1.0.1=py_0
# anaconda==2020.02=py37_0 -> sphinxcontrib-applehelp==1.0.1=py_0
# anaconda==2020.02=py37_0 -> sphinx==2.4.0=py_0 -> sphinxcontrib-applehelp
#
# Package pkginfo conflicts for:
# conda-build==3.18.11=py37_0 -> pkginfo
# pkginfo==1.5.0.1=py37_0
# anaconda==2020.02=py37_0 -> pkginfo==1.5.0.1=py37_0
#
# Package fastcache conflicts for:
# anaconda==2020.02=py37_0 -> fastcache==1.1.0=py37h7b6447c_0
# sympy==1.5.1=py37_0 -> fastcache
# fastcache==1.1.0=py37h7b6447c_0
# anaconda==2020.02=py37_0 -> sympy==1.5.1=py37_0 -> fastcache
#
# Package unixodbc conflicts for:
# anaconda==2020.02=py37_0 -> unixodbc==2.3.7=h14c3975_0
# pyodbc==4.0.30=py37he6710b0_0 -> unixodbc[version='>=2.3.7,<2.4.0a0']
# unixodbc==2.3.7=h14c3975_0
# anaconda==2020.02=py37_0 -> pyodbc==4.0.30=py37he6710b0_0 -> unixodbc[version='>=2.3.7,<2.4.0a0']
#
# Package jbig conflicts for:
# anaconda==2020.02=py37_0 -> jbig==2.1=hdba287a_0
# jbig==2.1=hdba287a_0
#
# Package ruamel_yaml conflicts for:
# mamba -> conda[version='>=4.8'] -> ruamel_yaml[version='>=0.11.14,<0.16']
# ruamel_yaml==0.15.87=py37h7b6447c_0
# conda-build==3.18.11=py37_0 -> conda[version='>=4.5'] -> ruamel_yaml[version='>=0.11.14,<0.16']
# anaconda==2020.02=py37_0 -> anaconda-project==0.8.4=py_0 -> ruamel_yaml
# conda==4.8.2=py37_0 -> ruamel_yaml[version='>=0.11.14,<0.16']
# anaconda==2020.02=py37_0 -> ruamel_yaml==0.15.87=py37h7b6447c_0
# anaconda-project==0.8.4=py_0 -> ruamel_yaml
#
# Package pathlib2 conflicts for:
# anaconda==2020.02=py37_0 -> pathlib2==2.3.5=py37_0
# pathlib2==2.3.5=py37_0
#
# Package alabaster conflicts for:
# sphinx==2.4.0=py_0 -> alabaster[version='>=0.7,<0.8']
# numpydoc==0.9.2=py_0 -> sphinx -> alabaster[version='>=0.7,<0.8']
# alabaster==0.7.12=py37_0
# anaconda==2020.02=py37_0 -> sphinx==2.4.0=py_0 -> alabaster[version='>=0.7,<0.8']
# spyder==4.0.1=py37_0 -> sphinx -> alabaster[version='>=0.7,<0.8']
# anaconda==2020.02=py37_0 -> alabaster==0.7.12=py37_0
#
# Package watchdog conflicts for:
# watchdog==0.10.2=py37_0
# spyder==4.0.1=py37_0 -> watchdog
# anaconda==2020.02=py37_0 -> watchdog==0.10.2=py37_0
# anaconda==2020.02=py37_0 -> spyder==4.0.1=py37_0 -> watchdog
#
# Package babel conflicts for:
# numpydoc==0.9.2=py_0 -> sphinx -> babel[version='>=1.3,!=2.0']
# spyder==4.0.1=py37_0 -> sphinx -> babel[version='>=1.3,!=2.0']
# anaconda==2020.02=py37_0 -> babel==2.8.0=py_0
# babel==2.8.0=py_0
# sphinx==2.4.0=py_0 -> babel[version='>=1.3,!=2.0']
# anaconda==2020.02=py37_0 -> sphinx==2.4.0=py_0 -> babel[version='>=1.3,!=2.0']
#
# Package greenlet conflicts for:
# gevent==1.4.0=py37h7b6447c_0 -> greenlet[version='>=0.4.14']
# anaconda==2020.02=py37_0 -> greenlet==0.4.15=py37h7b6447c_0
# anaconda==2020.02=py37_0 -> gevent==1.4.0=py37h7b6447c_0 -> greenlet[version='>=0.4.14']
# greenlet==0.4.15=py37h7b6447c_0
#
# Package pytest-openfiles conflicts for:
# anaconda==2020.02=py37_0 -> pytest-openfiles==0.4.0=py_0
# anaconda==2020.02=py37_0 -> pytest-astropy==0.8.0=py_0 -> pytest-openfiles[version='>=0.3.1']
# pytest-openfiles==0.4.0=py_0
# astropy==4.0=py37h7b6447c_0 -> pytest-astropy -> pytest-openfiles[version='>=0.3.1']
# pytest-astropy==0.8.0=py_0 -> pytest-openfiles[version='>=0.3.1']
#
# Package pyopenssl conflicts for:
# pyopenssl==19.1.0=py37_0
# requests==2.22.0=py37_1 -> urllib3[version='>=1.21.1,<1.26,!=1.25.0,!=1.25.1'] -> pyopenssl[version='>=0.14']
# conda==4.8.2=py37_0 -> pyopenssl[version='>=16.2.0']
# mamba -> conda[version='>=4.8'] -> pyopenssl[version='>=16.2.0']
# anaconda==2020.02=py37_0 -> urllib3==1.25.8=py37_0 -> pyopenssl[version='>=0.14']
# anaconda==2020.02=py37_0 -> pyopenssl==19.1.0=py37_0
# urllib3==1.25.8=py37_0 -> pyopenssl[version='>=0.14']
# conda-build==3.18.11=py37_0 -> conda[version='>=4.5'] -> pyopenssl[version='>=16.2.0']
#
# Package xlrd conflicts for:
# xlrd==1.2.0=py37_0
# anaconda==2020.02=py37_0 -> xlrd==1.2.0=py37_0
#
# Package soupsieve conflicts for:
# anaconda==2020.02=py37_0 -> soupsieve==1.9.5=py37_0
# beautifulsoup4==4.8.2=py37_0 -> soupsieve[version='>=1.2']
# soupsieve==1.9.5=py37_0
# anaconda==2020.02=py37_0 -> beautifulsoup4==4.8.2=py37_0 -> soupsieve[version='>=1.2']
# conda-build==3.18.11=py37_0 -> beautifulsoup4 -> soupsieve[version='>=1.2']
#
# Package colorama conflicts for:
# colorama==0.4.3=py_0
# anaconda==2020.02=py37_0 -> colorama==0.4.3=py_0
#
# Package h5py conflicts for:
# h5py==2.10.0=py37h7918eee_0
# anaconda==2020.02=py37_0 -> h5py==2.10.0=py37h7918eee_0
#
# Package isort conflicts for:
# anaconda==2020.02=py37_0 -> isort==4.3.21=py37_0
# pylint==2.4.4=py37_0 -> isort[version='>=4.2.5,<5']
# python-language-server==0.31.7=py37_0 -> pylint -> isort[version='>=4.2.5,<5']
# anaconda==2020.02=py37_0 -> pylint==2.4.4=py37_0 -> isort[version='>=4.2.5,<5']
# isort==4.3.21=py37_0
# spyder==4.0.1=py37_0 -> pylint -> isort[version='>=4.2.5,<5']
#
# Package xmltodict conflicts for:
# anaconda-navigator==1.9.12=py37_0 -> xmltodict
# xmltodict==0.12.0=py_0
#
# Package sphinxcontrib conflicts for:
# anaconda==2020.02=py37_0 -> sphinxcontrib-websupport==1.2.0=py_0 -> sphinxcontrib
# anaconda==2020.02=py37_0 -> sphinxcontrib==1.0=py37_1
# sphinxcontrib==1.0=py37_1
# sphinxcontrib-websupport==1.2.0=py_0 -> sphinxcontrib
#
# Package libspatialindex conflicts for:
# rtree==0.9.3=py37_0 -> libspatialindex[version='>=1.9.3,<1.9.4.0a0']
# anaconda==2020.02=py37_0 -> rtree==0.9.3=py37_0 -> libspatialindex[version='>=1.9.3,<1.9.4.0a0']
# libspatialindex==1.9.3=he6710b0_0
# spyder==4.0.1=py37_0 -> rtree -> libspatialindex[version='>=1.9.3,<1.9.4.0a0']
# anaconda==2020.02=py37_0 -> libspatialindex==1.9.3=he6710b0_0
#
# Package ripgrep conflicts for:
# anaconda==2020.02=py37_0 -> ripgrep==11.0.2=he32d670_0
# conda-build==3.18.11=py37_0 -> ripgrep
# ripgrep==11.0.2=he32d670_0
#
# Package bottleneck conflicts for:
# bottleneck==1.3.2=py37heb32a55_0
# anaconda==2020.02=py37_0 -> bottleneck==1.3.2=py37heb32a55_0
#
# Package gstreamer conflicts for:
# gst-plugins-base==1.14.0=hbbd80ab_1 -> gstreamer[version='>=1.14.0,<2.0a0']
# gstreamer==1.14.0=hb453b48_1
# qt==5.9.7=h5867ecd_1 -> gst-plugins-base[version='>=1.14.0,<1.15.0a0'] -> gstreamer[version='>=1.14.0,<2.0a0']
# anaconda==2020.02=py37_0 -> gstreamer==1.14.0=hb453b48_1
# qt==5.9.7=h5867ecd_1 -> gstreamer[version='>=1.14.0,<1.15.0a0']
# pyqt==5.9.2=py37h05f1152_2 -> qt=5.9 -> gstreamer[version='>=1.14.0,<1.15.0a0']
# anaconda==2020.02=py37_0 -> gst-plugins-base==1.14.0=hbbd80ab_1 -> gstreamer[version='>=1.14.0,<1.15.0a0|>=1.14.0,<2.0a0']
#
# Package html5lib conflicts for:
# anaconda==2020.02=py37_0 -> html5lib==1.0.1=py37_0
# html5lib==1.0.1=py37_0
#
# Package reproc-cpp conflicts for:
# mamba -> reproc-cpp[version='>=14.2,<15.0a0']
# reproc-cpp
#
# Package conda conflicts for:
# conda==4.8.2=py37_0
# conda-build==3.18.11=py37_0 -> conda[version='>=4.5']
# mamba -> conda[version='>=4.8']
#
# Package xlwt conflicts for:
# xlwt==1.3.0=py37_0
# anaconda==2020.02=py37_0 -> xlwt==1.3.0=py37_0
#
# Package numba conflicts for:
# numba==0.48.0=py37h0573a6f_0
# anaconda==2020.02=py37_0 -> numba==0.48.0=py37h0573a6f_0
#
# Package c-ares conflicts for:
# c-ares
# libnghttp2 -> c-ares[version='>=1.17.1,<2.0a0|>=1.7.5']
#
# Package atomicwrites conflicts for:
# anaconda==2020.02=py37_0 -> atomicwrites==1.3.0=py37_1
# atomicwrites==1.3.0=py37_1
# anaconda==2020.02=py37_0 -> spyder==4.0.1=py37_0 -> atomicwrites
# spyder==4.0.1=py37_0 -> atomicwrites
#
# Package lxml conflicts for:
# lxml==4.5.0=py37hefd8a0e_0
# anaconda==2020.02=py37_0 -> lxml==4.5.0=py37hefd8a0e_0
#
# Package snappy conflicts for:
# snappy==1.1.7=hbae5bb6_3
# blosc==1.16.3=hd408876_0 -> snappy[version='>=1.1.7,<2.0a0']
# anaconda==2020.02=py37_0 -> blosc==1.16.3=hd408876_0 -> snappy[version='>=1.1.7,<2.0a0']
# anaconda==2020.02=py37_0 -> snappy==1.1.7=hbae5bb6_3
# pytables==3.6.1=py37h71ec239_0 -> blosc[version='>=1.16.3,<2.0a0'] -> snappy[version='>=1.1.7,<2.0a0']
#
# Package locket conflicts for:
# dask==2.11.0=py_0 -> partd[version='>=0.3.10'] -> locket
# locket==0.2.0=py37_1
# anaconda==2020.02=py37_0 -> partd==1.1.0=py_0 -> locket
# anaconda==2020.02=py37_0 -> locket==0.2.0=py37_1
# partd==1.1.0=py_0 -> locket
#
# Package scikit-learn conflicts for:
# scikit-learn==0.22.1=py37hd81dba3_0
# anaconda==2020.02=py37_0 -> scikit-learn==0.22.1=py37hd81dba3_0
#
# Package sympy conflicts for:
# anaconda==2020.02=py37_0 -> sympy==1.5.1=py37_0
# sympy==1.5.1=py37_0
#
# Package libtool conflicts for:
# libtool==2.4.6=h7b6447c_5
# anaconda==2020.02=py37_0 -> libtool==2.4.6=h7b6447c_5
#
# Package contextlib2 conflicts for:
# contextlib2==0.6.0.post1=py_0
# anaconda==2020.02=py37_0 -> contextlib2==0.6.0.post1=py_0
#
# Package et_xmlfile conflicts for:
# openpyxl==3.0.3=py_0 -> et_xmlfile
# anaconda==2020.02=py37_0 -> et_xmlfile==1.0.1=py37_0
# et_xmlfile==1.0.1=py37_0
# anaconda==2020.02=py37_0 -> openpyxl==3.0.3=py_0 -> et_xmlfile
#
# Package gevent conflicts for:
# anaconda==2020.02=py37_0 -> gevent==1.4.0=py37h7b6447c_0
# gevent==1.4.0=py37h7b6447c_0
#
# Package libev conflicts for:
# libev
# libnghttp2 -> libev[version='>=4.11|>=4.33,<4.34.0a0']
#
# Package scikit-image conflicts for:
# anaconda==2020.02=py37_0 -> scikit-image==0.16.2=py37h0573a6f_0
# scikit-image==0.16.2=py37h0573a6f_0
#
# Package patchelf conflicts for:
# conda-build==3.18.11=py37_0 -> patchelf
# anaconda==2020.02=py37_0 -> patchelf==0.10=he6710b0_0
# patchelf==0.10=he6710b0_0
#
# Package sqlalchemy conflicts for:
# anaconda==2020.02=py37_0 -> sqlalchemy==1.3.13=py37h7b6447c_0
# sqlalchemy==1.3.13=py37h7b6447c_0
#
# Package singledispatch conflicts for:
# singledispatch==3.4.0.3=py37_0
# anaconda==2020.02=py37_0 -> singledispatch==3.4.0.3=py37_0
#
# Package pango conflicts for:
# anaconda==2020.02=py37_0 -> pango==1.42.4=h049681c_0
# pango==1.42.4=h049681c_0
#
# Package statsmodels conflicts for:
# statsmodels==0.11.0=py37h7b6447c_0
# anaconda==2020.02=py37_0 -> statsmodels==0.11.0=py37h7b6447c_0
#
# Package astropy conflicts for:
# anaconda==2020.02=py37_0 -> astropy==4.0=py37h7b6447c_0
# astropy==4.0=py37h7b6447c_0
#
# Package curl conflicts for:
# curl==7.68.0=hbc83047_0
# anaconda==2020.02=py37_0 -> curl==7.68.0=hbc83047_0
#
# Package get_terminal_size conflicts for:
# anaconda==2020.02=py37_0 -> get_terminal_size==1.0.0=haa9412d_0
# get_terminal_size==1.0.0=haa9412d_0

# %% [markdown]
# Any package that you install with Conda will be installed into the directory /usr/local/lib/python3.7/site-packages so you will need to add this directory to sys.path in order for these packages to be available for import.

# %%
# new code
import sys
sys.path.insert(0, "/usr/local/lib/python3.7/site-packages/")

# %% [markdown]
# Now that you have installed Conda you need to update Conda and all its dependencies to their most recent versions and update Python to 3.7. The conda update command then updates all of Conda’s dependencies to their most recent versions

# %%
# new code
# !conda install -yq python=3.7
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - python=3.7
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2022.6.15  |       ha878542_0         149 KB  conda-forge
#     certifi-2022.6.15          |   py37h89c1867_0         155 KB  conda-forge
#     cffi-1.15.1                |   py37h43b0acd_0         227 KB  conda-forge
#     conda-4.13.0               |   py37h89c1867_1         989 KB  conda-forge
#     libffi-3.4.2               |       h7f98852_5          57 KB  conda-forge
#     libgcc-ng-12.1.0           |      h8d9b700_16         940 KB  conda-forge
#     libgomp-12.1.0             |      h8d9b700_16         459 KB  conda-forge
#     libnsl-2.0.0               |       h7f98852_0          31 KB  conda-forge
#     libstdcxx-ng-12.1.0        |      ha89aaad_16         4.3 MB  conda-forge
#     libzlib-1.2.12             |       h166bdaf_2          63 KB  conda-forge
#     ncurses-6.3                |       h27087fc_1        1002 KB  conda-forge
#     openssl-1.1.1q             |       h166bdaf_0         2.1 MB  conda-forge
#     python-3.7.12              |hb7a2778_100_cpython        57.3 MB  conda-forge
#     python_abi-3.7             |          2_cp37m           4 KB  conda-forge
#     readline-8.1.2             |       h0f457ee_0         291 KB  conda-forge
#     sqlite-3.39.1              |       h4ff8645_0         1.5 MB  conda-forge
#     tk-8.6.12                  |       h27826a3_0         3.3 MB  conda-forge
#     zlib-1.2.12                |       h166bdaf_2          91 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        72.9 MB
#
# The following NEW packages will be INSTALLED:
#
#   libnsl             conda-forge/linux-64::libnsl-2.0.0-h7f98852_0
#   libzlib            conda-forge/linux-64::libzlib-1.2.12-h166bdaf_2
#
# The following packages will be UPDATED:
#
#   ca-certificates                      2020.12.5-ha878542_0 --> 2022.6.15-ha878542_0
#   certifi                          2020.12.5-py37h89c1867_1 --> 2022.6.15-py37h89c1867_0
#   cffi                                1.14.5-py37hc58025e_0 --> 1.15.1-py37h43b0acd_0
#   conda                                4.9.2-py37h89c1867_0 --> 4.13.0-py37h89c1867_1
#   libffi                                     3.3-h58526e2_2 --> 3.4.2-h7f98852_5
#   libgcc-ng                               9.3.0-h2828fa1_18 --> 12.1.0-h8d9b700_16
#   libgomp                                 9.3.0-h2828fa1_18 --> 12.1.0-h8d9b700_16
#   libstdcxx-ng                            9.3.0-h6de172a_18 --> 12.1.0-ha89aaad_16
#   ncurses                                    6.2-h58526e2_4 --> 6.3-h27087fc_1
#   openssl                                 1.1.1j-h7f98852_0 --> 1.1.1q-h166bdaf_0
#   python                        3.7.10-hffdb5ce_100_cpython --> 3.7.12-hb7a2778_100_cpython
#   python_abi                                    3.7-1_cp37m --> 3.7-2_cp37m
#   readline                                   8.0-he28a2e2_2 --> 8.1.2-h0f457ee_0
#   sqlite                                  3.34.0-h74cdb3f_0 --> 3.39.1-h4ff8645_0
#   tk                                      8.6.10-h21135ba_1 --> 8.6.12-h27826a3_0
#   zlib                                 1.2.11-h516909a_1010 --> 1.2.12-h166bdaf_2
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done

# %% [markdown]
# #### NCO
#
# NetCDF Operators (NCO) is a requirement and must be installed for utilization of this package. Instructions for installation on various platforms is available [here](http://nco.sourceforge.net/#Executables//) and other information related to NCO command can be found at the link: http://nco.sourceforge.net/nco.html. If using an Anaconda environment as advised above then it’s as simple as running the following command within the activated conda environment:

# %%
# !conda install -c conda-forge nco
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - nco
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     c-ares-1.18.1              |       h7f98852_0         113 KB  conda-forge
#     cudatoolkit-11.1.1         |      ha002fc5_10        1.20 GB  conda-forge
#     curl-7.83.1                |       h7bff187_0          89 KB  conda-forge
#     esmf-8.2.0                 | nompi_h61edca3_0        27.4 MB  conda-forge
#     expat-2.4.8                |       h27087fc_0         187 KB  conda-forge
#     gsl-2.7                    |       he838d99_0         3.2 MB  conda-forge
#     hdf4-4.2.15                |       h10796ff_3         950 KB  conda-forge
#     hdf5-1.12.1                |nompi_h2386368_104         3.5 MB  conda-forge
#     jpeg-9e                    |       h166bdaf_2         269 KB  conda-forge
#     keyutils-1.6.1             |       h166bdaf_0         115 KB  conda-forge
#     krb5-1.19.3                |       h3790be6_0         1.4 MB  conda-forge
#     libblas-3.9.0              |15_linux64_openblas          12 KB  conda-forge
#     libcblas-3.9.0             |15_linux64_openblas          12 KB  conda-forge
#     libcurl-7.83.1             |       h7bff187_0         342 KB  conda-forge
#     libgfortran-ng-12.1.0      |      h69a702a_16          23 KB  conda-forge
#     libgfortran5-12.1.0        |      hdcd56e2_16         1.8 MB  conda-forge
#     liblapack-3.9.0            |15_linux64_openblas          12 KB  conda-forge
#     libnetcdf-4.8.1            |nompi_h329d8a1_102         1.5 MB  conda-forge
#     libnghttp2-1.47.0          |       h727a467_0         808 KB  conda-forge
#     libopenblas-0.3.20         |pthreads_h78a6416_0        10.1 MB  conda-forge
#     libssh2-1.10.0             |       ha56f1ee_2         233 KB  conda-forge
#     libzip-1.9.2               |       hc869a4a_0          97 KB  conda-forge
#     nco-5.1.0                  |       hdef2bbc_0         2.2 MB  conda-forge
#     netcdf-fortran-4.5.4       |nompi_h2b6e579_100         1.3 MB  conda-forge
#     tempest-remap-2.1.1        |       hfda0864_0         1.3 MB  conda-forge
#     udunits2-2.2.28            |       hc3e0081_0         161 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        1.26 GB
#
# The following NEW packages will be INSTALLED:
#
#   cudatoolkit        conda-forge/linux-64::cudatoolkit-11.1.1-ha002fc5_10
#   curl               conda-forge/linux-64::curl-7.83.1-h7bff187_0
#   esmf               conda-forge/linux-64::esmf-8.2.0-nompi_h61edca3_0
#   expat              conda-forge/linux-64::expat-2.4.8-h27087fc_0
#   gsl                conda-forge/linux-64::gsl-2.7-he838d99_0
#   hdf4               conda-forge/linux-64::hdf4-4.2.15-h10796ff_3
#   hdf5               conda-forge/linux-64::hdf5-1.12.1-nompi_h2386368_104
#   jpeg               conda-forge/linux-64::jpeg-9e-h166bdaf_2
#   keyutils           conda-forge/linux-64::keyutils-1.6.1-h166bdaf_0
#   libblas            conda-forge/linux-64::libblas-3.9.0-15_linux64_openblas
#   libcblas           conda-forge/linux-64::libcblas-3.9.0-15_linux64_openblas
#   libgfortran-ng     conda-forge/linux-64::libgfortran-ng-12.1.0-h69a702a_16
#   libgfortran5       conda-forge/linux-64::libgfortran5-12.1.0-hdcd56e2_16
#   liblapack          conda-forge/linux-64::liblapack-3.9.0-15_linux64_openblas
#   libnetcdf          conda-forge/linux-64::libnetcdf-4.8.1-nompi_h329d8a1_102
#   libopenblas        conda-forge/linux-64::libopenblas-0.3.20-pthreads_h78a6416_0
#   libzip             conda-forge/linux-64::libzip-1.9.2-hc869a4a_0
#   nco                conda-forge/linux-64::nco-5.1.0-hdef2bbc_0
#   netcdf-fortran     conda-forge/linux-64::netcdf-fortran-4.5.4-nompi_h2b6e579_100
#   tempest-remap      conda-forge/linux-64::tempest-remap-2.1.1-hfda0864_0
#   udunits2           conda-forge/linux-64::udunits2-2.2.28-hc3e0081_0
#
# The following packages will be UPDATED:
#
#   c-ares                                  1.17.1-h7f98852_1 --> 1.18.1-h7f98852_0
#   krb5                                    1.17.2-h926e7f8_0 --> 1.19.3-h3790be6_0
#   libcurl                                 7.75.0-hc4aaa36_0 --> 7.83.1-h7bff187_0
#   libnghttp2                              1.43.0-h812cca2_0 --> 1.47.0-h727a467_0
#   libssh2                                  1.9.0-ha56f1ee_6 --> 1.10.0-ha56f1ee_2
#
#
#
# Downloading and Extracting Packages
# liblapack-3.9.0      | 12 KB     | : 100% 1.0/1 [00:00<00:00, 11.80it/s]
# libzip-1.9.2         | 97 KB     | : 100% 1.0/1 [00:00<00:00, 13.01it/s]
# curl-7.83.1          | 89 KB     | : 100% 1.0/1 [00:00<00:00, 16.25it/s]
# expat-2.4.8          | 187 KB    | : 100% 1.0/1 [00:00<00:00, 11.20it/s]
# hdf5-1.12.1          | 3.5 MB    | : 100% 1.0/1 [00:00<00:00,  1.27it/s]
# libnetcdf-4.8.1      | 1.5 MB    | : 100% 1.0/1 [00:00<00:00,  3.10it/s]
# libblas-3.9.0        | 12 KB     | : 100% 1.0/1 [00:00<00:00, 24.29it/s]
# nco-5.1.0            | 2.2 MB    | : 100% 1.0/1 [00:00<00:00,  1.72it/s]
# libgfortran-ng-12.1. | 23 KB     | : 100% 1.0/1 [00:00<00:00, 20.15it/s]
# jpeg-9e              | 269 KB    | : 100% 1.0/1 [00:00<00:00,  8.47it/s]
# cudatoolkit-11.1.1   | 1.20 GB   | :  99% 0.9920286482017683/1 [00:14<00:00, 14.30s/it]

# %% [markdown]
# #### Climate-indices package
# Install ```climate-indices``` package. Once the environment has been activated then subsequent Python commands will run in this environment where the package dependencies for this project are present. Now the package can be added to the environment along with all required modules (dependencies) via [pip](https://pip.pypa.io/en/stable/):

# %%
# !pip install climate-indices

# %% [markdown]
# ### 3.4. Preprocess data using NCO

# %% [markdown]
# 1. The original downloaded files from GPM IMERG is in mm/hr, while to calculate monthly SPI the data must be in mm/month, we need to do a conversion process using ```ncap2``` (arithmetic operator for NetCDF files) command by multiplying number of day in month for each data with 24hour.
#
# 2. Arrange IMERG data files based on number of days within a month, dont forget to create a folder to store the files:
#     - ```/Day28```
#     - ```/Day29```
#     - ```/Day30```
#     - ```/Day31```, and new folder
#     - ```/IMERG_mm_month``` to save the converted files.

# %% [markdown]
# >    - Arrange data in their corresponding folders:

# %%
# new code
months_31Days = ['01', '03', '05', '07', '08', '10', '12'] 
months_30Days = ['04', '06', '09', '11'] 
leapY_29Days = ['200002', '200402', '200802', '201202', '201602', '202002']

# %%
# new code
import shutil
import glob

path_list = glob.glob('/content/drive/MyDrive/IWMI/IMERG_mm_hr/*')[3:]
for path in path_list:
  month = path.split('/')[-1].split('.')[4].split('-')[0][4:6]
  if month in months_31Days:
    shutil.move(path, '/content/drive/MyDrive/IWMI/Day31')

  elif month in months_30Days:
    shutil.move(path, '/content/drive/MyDrive/IWMI/Day30')

# %%
# new code
path_list = glob.glob('/content/drive/MyDrive/IWMI/IMERG_mm_hr/*')[3:]
for path in path_list:
  YYYYMM = path.split('/')[-1].split('.')[4].split('-')[0][:6]
  if YYYYMM in leapY_29Days:
    shutil.move(path, '/content/drive/MyDrive/IWMI/Day29')
  else:
    shutil.move(path, '/content/drive/MyDrive/IWMI/Day28')

# %% [markdown]
# >    - Navigate to ```Day28``` folder in terminal, type this code:

# %%
# %cd /content/drive/MyDrive/IWMI/Day28
# Out:
# /content/drive/MyDrive/IWMI/Day28

# %%
# !ls
# Out:
# 3B-MO.MS.MRG.3IMERG.20010201-S000000-E235959.02.V06B.HDF5.SUB.nc4
# 3B-MO.MS.MRG.3IMERG.20020201-S000000-E235959.02.V06B.HDF5.SUB.nc4
# 3B-MO.MS.MRG.3IMERG.20030201-S000000-E235959.02.V06B.HDF5.SUB.nc4
# 3B-MO.MS.MRG.3IMERG.20050201-S000000-E235959.02.V06B.HDF5.SUB.nc4
# 3B-MO.MS.MRG.3IMERG.20060201-S000000-E235959.02.V06B.HDF5.SUB.nc4
# 3B-MO.MS.MRG.3IMERG.20070201-S000000-E235959.02.V06B.HDF5.SUB.nc4
# 3B-MO.MS.MRG.3IMERG.20090201-S000000-E235959.02.V06B.HDF5.SUB.nc4
# 3B-MO.MS.MRG.3IMERG.20100201-S000000-E235959.02.V06B.HDF5.SUB.nc4
# 3B-MO.MS.MRG.3IMERG.20110201-S000000-E235959.02.V06B.HDF5.SUB.nc4
# 3B-MO.MS.MRG.3IMERG.20130201-S000000-E235959.02.V06B.HDF5.SUB.nc4
# 3B-MO.MS.MRG.3IMERG.20140201-S000000-E235959.02.V06B.HDF5.SUB.nc4
# 3B-MO.MS.MRG.3IMERG.20150201-S000000-E235959.02.V06B.HDF5.SUB.nc4
# 3B-MO.MS.MRG.3IMERG.20170201-S000000-E235959.02.V06B.HDF5.SUB.nc4
# 3B-MO.MS.MRG.3IMERG.20180201-S000000-E235959.02.V06B.HDF5.SUB.nc4
# 3B-MO.MS.MRG.3IMERG.20190201-S000000-E235959.02.V06B.HDF5.SUB.nc4
# 3B-MO.MS.MRG.3IMERG.20210201-S000000-E235959.02.V06B.HDF5.SUB.nc4

# %%
# !for fl in *.nc4; do ncap2 -s 'precipitation=672*precipitation' $fl /content/drive/MyDrive/IWMI/IMERG_mm_month/$fl; done

# %% [markdown]
# >    - Navigate to ```Day29``` folder in terminal, type this code:

# %%
# %cd /content/drive/MyDrive/IWMI/Day29
# Out:
# /content/drive/MyDrive/IWMI/Day29

# %%
# !for fl in *.nc4; do ncap2 -s 'precipitation=696*precipitation' $fl /content/drive/MyDrive/IWMI/IMERG_mm_month/$fl; done

# %% [markdown]
# >    - Navigate to ```Day30``` folder in terminal, type this code:

# %%
# %cd /content/drive/MyDrive/IWMI/Day30
# Out:
# /content/drive/MyDrive/IWMI/Day30

# %%
# !for fl in *.nc4; do ncap2 -s 'precipitation=720*precipitation' $fl /content/drive/MyDrive/IWMI/IMERG_mm_month/$fl; done

# %% [markdown]
# >    - Navigate to ```Day31``` folder in terminal, type this code:

# %%
# %cd /content/drive/MyDrive/IWMI/Day31
# Out:
# /content/drive/MyDrive/IWMI/Day31

# %%
# !for fl in *.nc4; do ncap2 -s 'precipitation=744*precipitation' $fl /content/drive/MyDrive/IWMI/IMERG_mm_month/$fl; done

# %% [markdown]
# 3. Navigate to ```IMERG_mm_month``` folder in terminal. Loops all files in the folder ```IMERG_mm_month``` to make ```time``` the record dimension/variable used for concatenating using ```Ncks``` command

# %%
# %cd /content/drive/MyDrive/IWMI/IMERG_mm_month
# Out:
# /content/drive/MyDrive/IWMI/IMERG_mm_month

# %%
# !for fl in *.nc4; do ncks --mk_rec_dmn time $fl -o $fl.TMP; mv $fl.TMP $fl; done

# %% [markdown]
# 4. Concatenates all ```.nc4``` files in ```IMERG_mm_month``` folder into one ```.nc4``` file named ```IMERG_concat.nc4``` using ```ncrcat``` command

# %%
# !ncrcat -h *.nc4 IMERG_concat.nc4

# %% [markdown]
# 5. Check the header

# %%
# !ncdump -h IMERG_concat.nc4
# Out:
# netcdf IMERG_concat {
# dimensions:
# 	lat = 104 ;
# 	lon = 124 ;
# 	time = UNLIMITED ; // (256 currently)
# variables:
# 	float lat(lat) ;
# 		lat:standard_name = "latitude" ;
# 		lat:long_name = "latitude" ;
# 		lat:units = "degrees_north" ;
# 		lat:axis = "Y" ;
# 	float lon(lon) ;
# 		lon:standard_name = "longitude" ;
# 		lon:long_name = "longitude" ;
# 		lon:units = "degrees_east" ;
# 		lon:axis = "X" ;
# 	float precipitation(time, lon, lat) ;
# 		precipitation:_FillValue = -9999.9f ;
# 		precipitation:CodeMissingValue = "-9999.9" ;
# 		precipitation:DimensionNames = "time,lon,lat" ;
# 		precipitation:Units = "mm/hr" ;
# 		precipitation:missing_value = -9999.9f ;
# 		precipitation:units = "mm/hr" ;
# 		precipitation:cell_methods = "time: mean" ;
# 	int time(time) ;
# 		time:standard_name = "time" ;
# 		time:units = "seconds since 1970-01-01 00:00:00 UTC" ;
# 		time:calendar = "standard" ;
# 		time:axis = "T" ;
# 		time:cell_methods = "time: mean" ;
#
# // global attributes:
# 		:CDI = "Climate Data Interface version 1.9.8 (https://mpimet.mpg.de/cdi)" ;
# 		:Conventions = "CF-1.6" ;
# 		:Original_Producer_Metadata_FileHeader = "DOI=10.5067/GPM/IMERG/3B-MONTH/06;\nDOIauthority=http://dx.doi.org/;\nDOIshortName=3IMERGM;\nAlgorithmID=3IMERGM;\nAlgorithmVersion=3IMERGM_6.3;\nFileName=3B-MO.MS.MRG.3IMERG.20000601-S000000-E235959.06.V06B.HDF5;\nSatelliteName=MULTI;\nInstrumentName=MERGED;\nGenerationDateTime=2019-06-18T06:30:13.000Z;\nStartGranuleDateTime=2000-06-01T00:00:00.000Z;\nStopGranuleDateTime=2000-06-30T23:59:59.999Z;\nGranuleNumber=;\nNumberOfSwaths=0;\nNumberOfGrids=1;\nGranuleStart=;\nTimeInterval=MONTH;\nProcessingSystem=PPS;\nProductVersion=V06B;\nEmptyGranule=NOT_EMPTY;\nMissingData=;\n" ;
# 		:Original_Producer_Metadata_FileInfo = "DataFormatVersion=6a;\nTKCodeBuildVersion=0;\nMetadataVersion=6a;\nFormatPackage=HDF5-1.8.9;\nBlueprintFilename=GPM.V6.3IMERGM.blueprint.xml;\nBlueprintVersion=BV_62;\nTKIOVersion=3.93;\nMetadataStyle=PVL;\nEndianType=LITTLE_ENDIAN;\n" ;
# 		:Original_Producer_Metadata_GridHeader = "BinMethod=ARITHMETIC_MEAN;\nRegistration=CENTER;\nLatitudeResolution=0.1;\nLongitudeResolution=0.1;\nNorthBoundingCoordinate=90;\nSouthBoundingCoordinate=-90;\nEastBoundingCoordinate=180;\nWestBoundingCoordinate=-180;\nOrigin=SOUTHWEST;\n" ;
# 		:InputPointer = "3B-MO.MS.MRG.3IMERG.20000601-S000000-E235959.06.V06B.HDF5" ;
# 		:history_L34RS = "\'Created by L34RS v1.4.3 @ NASA GES DISC on June 28 2022 09:04:49. Spatial: 21.533 33.926 -18.318 -7.947. Variables: precipitation\'" ;
# 		:CDO = "Climate Data Operators version 1.9.8 (https://mpimet.mpg.de/cdo)" ;
# 		:history = "Wed Jun 29 08:24:50 2022: ncks --mk_rec_dmn time 3B-MO.MS.MRG.3IMERG.20000601-S000000-E235959.06.V06B.HDF5.SUB.nc4 -o 3B-MO.MS.MRG.3IMERG.20000601-S000000-E235959.06.V06B.HDF5.SUB.nc4.TMP\nWed Jun 29 08:23:42 2022: ncap2 -s precipitation=720*precipitation 3B-MO.MS.MRG.3IMERG.20000601-S000000-E235959.06.V06B.HDF5.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_mm_month/3B-MO.MS.MRG.3IMERG.20000601-S000000-E235959.06.V06B.HDF5.SUB.nc4" ;
# 		:NCO = "netCDF Operators version 5.0.7 (Homepage = http://nco.sf.net, Code = http://github.com/nco/nco)" ;
# }

# %% [markdown]
# 6. And the variables for ```precipitation``` is ```time,lon,lat``` but SPI calculation required:
#     - ```lat,lon,time``` or
#     - ```time,lat,lon```

# %% [markdown]
# 7. Let's re-order the variables into ```time,lat,lon``` using ```ncpdq``` command, to be able running the SPI code in Python

# %%
# !ncpdq -a time,lat,lon IMERG_concat.nc4 IMERG_concat_ncpdq0.nc4

# %% [markdown]
# 8. Check again the header for ```IMERG_concat_ncpdq0.nc4```

# %%
# !ncdump -h IMERG_concat_ncpdq0.nc4
# Out:
# netcdf IMERG_concat_ncpdq0 {
# dimensions:
# 	lat = 104 ;
# 	lon = 124 ;
# 	time = UNLIMITED ; // (256 currently)
# variables:
# 	float lat(lat) ;
# 		lat:standard_name = "latitude" ;
# 		lat:long_name = "latitude" ;
# 		lat:units = "degrees_north" ;
# 		lat:axis = "Y" ;
# 	float lon(lon) ;
# 		lon:standard_name = "longitude" ;
# 		lon:long_name = "longitude" ;
# 		lon:units = "degrees_east" ;
# 		lon:axis = "X" ;
# 	float precipitation(time, lat, lon) ;
# 		precipitation:_FillValue = -9999.9f ;
# 		precipitation:CodeMissingValue = "-9999.9" ;
# 		precipitation:DimensionNames = "time,lon,lat" ;
# 		precipitation:Units = "mm/hr" ;
# 		precipitation:missing_value = -9999.9f ;
# 		precipitation:units = "mm/hr" ;
# 		precipitation:cell_methods = "time: mean" ;
# 	int time(time) ;
# 		time:standard_name = "time" ;
# 		time:units = "seconds since 1970-01-01 00:00:00 UTC" ;
# 		time:calendar = "standard" ;
# 		time:axis = "T" ;
# 		time:cell_methods = "time: mean" ;
#
# // global attributes:
# 		:CDI = "Climate Data Interface version 1.9.8 (https://mpimet.mpg.de/cdi)" ;
# 		:Conventions = "CF-1.6" ;
# 		:Original_Producer_Metadata_FileHeader = "DOI=10.5067/GPM/IMERG/3B-MONTH/06;\nDOIauthority=http://dx.doi.org/;\nDOIshortName=3IMERGM;\nAlgorithmID=3IMERGM;\nAlgorithmVersion=3IMERGM_6.3;\nFileName=3B-MO.MS.MRG.3IMERG.20000601-S000000-E235959.06.V06B.HDF5;\nSatelliteName=MULTI;\nInstrumentName=MERGED;\nGenerationDateTime=2019-06-18T06:30:13.000Z;\nStartGranuleDateTime=2000-06-01T00:00:00.000Z;\nStopGranuleDateTime=2000-06-30T23:59:59.999Z;\nGranuleNumber=;\nNumberOfSwaths=0;\nNumberOfGrids=1;\nGranuleStart=;\nTimeInterval=MONTH;\nProcessingSystem=PPS;\nProductVersion=V06B;\nEmptyGranule=NOT_EMPTY;\nMissingData=;\n" ;
# 		:Original_Producer_Metadata_FileInfo = "DataFormatVersion=6a;\nTKCodeBuildVersion=0;\nMetadataVersion=6a;\nFormatPackage=HDF5-1.8.9;\nBlueprintFilename=GPM.V6.3IMERGM.blueprint.xml;\nBlueprintVersion=BV_62;\nTKIOVersion=3.93;\nMetadataStyle=PVL;\nEndianType=LITTLE_ENDIAN;\n" ;
# 		:Original_Producer_Metadata_GridHeader = "BinMethod=ARITHMETIC_MEAN;\nRegistration=CENTER;\nLatitudeResolution=0.1;\nLongitudeResolution=0.1;\nNorthBoundingCoordinate=90;\nSouthBoundingCoordinate=-90;\nEastBoundingCoordinate=180;\nWestBoundingCoordinate=-180;\nOrigin=SOUTHWEST;\n" ;
# 		:InputPointer = "3B-MO.MS.MRG.3IMERG.20000601-S000000-E235959.06.V06B.HDF5" ;
# 		:history_L34RS = "\'Created by L34RS v1.4.3 @ NASA GES DISC on June 28 2022 09:04:49. Spatial: 21.533 33.926 -18.318 -7.947. Variables: precipitation\'" ;
# 		:CDO = "Climate Data Operators version 1.9.8 (https://mpimet.mpg.de/cdo)" ;
# 		:history = "Wed Jun 29 08:26:34 2022: ncpdq -a time,lat,lon IMERG_concat.nc4 IMERG_concat_ncpdq0.nc4\nWed Jun 29 08:24:50 2022: ncks --mk_rec_dmn time 3B-MO.MS.MRG.3IMERG.20000601-S000000-E235959.06.V06B.HDF5.SUB.nc4 -o 3B-MO.MS.MRG.3IMERG.20000601-S000000-E235959.06.V06B.HDF5.SUB.nc4.TMP\nWed Jun 29 08:23:42 2022: ncap2 -s precipitation=720*precipitation 3B-MO.MS.MRG.3IMERG.20000601-S000000-E235959.06.V06B.HDF5.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_mm_month/3B-MO.MS.MRG.3IMERG.20000601-S000000-E235959.06.V06B.HDF5.SUB.nc4" ;
# 		:NCO = "netCDF Operators version 5.0.7 (Homepage = http://nco.sf.net, Code = http://github.com/nco/nco)" ;
# }

# %% [markdown]
# 9. And the variables for ```precipitation``` is ```time,lat,lon```, it means the result is correct. But the unit still in ```mm/hr```, we need to edit to ```mm```

# %% [markdown]
# 10. SPI code does not recognized unit ```mm/hr``` or ```mm/month```, we need to edit into ```mm```. To edit the unit attribute names, we will use ```ncatted``` command, follow below code:

# %%
# !ncatted -a units,precipitation,modify,c,'mm' IMERG_concat_ncpdq0.nc4 IMERG_concat_ncpdq1.nc4

# %% [markdown]
# 11. Check again the header for IMERG_concat_ncpdq1.nc4, to make sure everything is correct.

# %%
# !ncdump -h IMERG_concat_ncpdq1.nc4
# Out:
# netcdf IMERG_concat_ncpdq1 {
# dimensions:
# 	lat = 104 ;
# 	lon = 124 ;
# 	time = UNLIMITED ; // (256 currently)
# variables:
# 	float lat(lat) ;
# 		lat:standard_name = "latitude" ;
# 		lat:long_name = "latitude" ;
# 		lat:units = "degrees_north" ;
# 		lat:axis = "Y" ;
# 	float lon(lon) ;
# 		lon:standard_name = "longitude" ;
# 		lon:long_name = "longitude" ;
# 		lon:units = "degrees_east" ;
# 		lon:axis = "X" ;
# 	float precipitation(time, lat, lon) ;
# 		precipitation:_FillValue = -9999.9f ;
# 		precipitation:CodeMissingValue = "-9999.9" ;
# 		precipitation:DimensionNames = "time,lon,lat" ;
# 		precipitation:Units = "mm/hr" ;
# 		precipitation:missing_value = -9999.9f ;
# 		precipitation:cell_methods = "time: mean" ;
# 		precipitation:units = "mm" ;
# 	int time(time) ;
# 		time:standard_name = "time" ;
# 		time:units = "seconds since 1970-01-01 00:00:00 UTC" ;
# 		time:calendar = "standard" ;
# 		time:axis = "T" ;
# 		time:cell_methods = "time: mean" ;
#
# // global attributes:
# 		:CDI = "Climate Data Interface version 1.9.8 (https://mpimet.mpg.de/cdi)" ;
# 		:Conventions = "CF-1.6" ;
# 		:Original_Producer_Metadata_FileHeader = "DOI=10.5067/GPM/IMERG/3B-MONTH/06;\nDOIauthority=http://dx.doi.org/;\nDOIshortName=3IMERGM;\nAlgorithmID=3IMERGM;\nAlgorithmVersion=3IMERGM_6.3;\nFileName=3B-MO.MS.MRG.3IMERG.20000601-S000000-E235959.06.V06B.HDF5;\nSatelliteName=MULTI;\nInstrumentName=MERGED;\nGenerationDateTime=2019-06-18T06:30:13.000Z;\nStartGranuleDateTime=2000-06-01T00:00:00.000Z;\nStopGranuleDateTime=2000-06-30T23:59:59.999Z;\nGranuleNumber=;\nNumberOfSwaths=0;\nNumberOfGrids=1;\nGranuleStart=;\nTimeInterval=MONTH;\nProcessingSystem=PPS;\nProductVersion=V06B;\nEmptyGranule=NOT_EMPTY;\nMissingData=;\n" ;
# 		:Original_Producer_Metadata_FileInfo = "DataFormatVersion=6a;\nTKCodeBuildVersion=0;\nMetadataVersion=6a;\nFormatPackage=HDF5-1.8.9;\nBlueprintFilename=GPM.V6.3IMERGM.blueprint.xml;\nBlueprintVersion=BV_62;\nTKIOVersion=3.93;\nMetadataStyle=PVL;\nEndianType=LITTLE_ENDIAN;\n" ;
# 		:Original_Producer_Metadata_GridHeader = "BinMethod=ARITHMETIC_MEAN;\nRegistration=CENTER;\nLatitudeResolution=0.1;\nLongitudeResolution=0.1;\nNorthBoundingCoordinate=90;\nSouthBoundingCoordinate=-90;\nEastBoundingCoordinate=180;\nWestBoundingCoordinate=-180;\nOrigin=SOUTHWEST;\n" ;
# 		:InputPointer = "3B-MO.MS.MRG.3IMERG.20000601-S000000-E235959.06.V06B.HDF5" ;
# 		:history_L34RS = "\'Created by L34RS v1.4.3 @ NASA GES DISC on June 28 2022 09:04:49. Spatial: 21.533 33.926 -18.318 -7.947. Variables: precipitation\'" ;
# 		:CDO = "Climate Data Operators version 1.9.8 (https://mpimet.mpg.de/cdo)" ;
# 		:NCO = "netCDF Operators version 5.0.7 (Homepage = http://nco.sf.net, Code = http://github.com/nco/nco)" ;
# 		:history = "Wed Jun 29 08:27:46 2022: ncatted -a units,precipitation,modify,c,mm IMERG_concat_ncpdq0.nc4 IMERG_concat_ncpdq1.nc4\nWed Jun 29 08:26:34 2022: ncpdq -a time,lat,lon IMERG_concat.nc4 IMERG_concat_ncpdq0.nc4\nWed Jun 29 08:24:50 2022: ncks --mk_rec_dmn time 3B-MO.MS.MRG.3IMERG.20000601-S000000-E235959.06.V06B.HDF5.SUB.nc4 -o 3B-MO.MS.MRG.3IMERG.20000601-S000000-E235959.06.V06B.HDF5.SUB.nc4.TMP\nWed Jun 29 08:23:42 2022: ncap2 -s precipitation=720*precipitation 3B-MO.MS.MRG.3IMERG.20000601-S000000-E235959.06.V06B.HDF5.SUB.nc4 /content/drive/MyDrive/IWMI/IMERG_mm_month/3B-MO.MS.MRG.3IMERG.20000601-S000000-E235959.06.V06B.HDF5.SUB.nc4" ;
# }

# %% [markdown]
# 12. And the ```units``` already in ```mm```

# %% [markdown]
# 13. Once this has completed the dataset can be used as input to this package for computing SPI. From above picture, some of the precipitation attribute are still wrong: ```DimensionNames``` and ```Units```. We can leave it as is, SPI code will only read ```units``` and ```variables``` ```precipitation(time,lat,lon)```

# %% [markdown]
# ## 4. Running SPI code

# %% [markdown]
# 1. We will use ```IMERG_concat_ncpdq1.nc4``` as ```input```, let's move this data to ```Input``` folder.
#     - Move using ```mv oldlocation newlocation``` command: ```mv /IMERG_mm_month/IMERG_concat_ncpdq1.nc4 /Input/IMERG_concat_ncpdq1.nc4```

# %%
# !mv /content/drive/MyDrive/IWMI/IMERG_mm_month/IMERG_concat_ncpdq1.nc4 /content/drive/MyDrive/IWMI/Input/IMERG_concat_ncpdq1.nc4

# %% [markdown]
# 2. Run the code

# %%
# new code
# !conda install -c anaconda numpy
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - numpy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     blas-1.0                   |         openblas          48 KB  anaconda
#     ca-certificates-2022.4.26  |       h06a4308_0         132 KB  anaconda
#     certifi-2022.6.15          |   py37h06a4308_0         156 KB  anaconda
#     conda-4.13.0               |   py37h06a4308_0         990 KB  anaconda
#     numpy-1.21.5               |   py37hf838250_3          10 KB  anaconda
#     numpy-base-1.21.5          |   py37h1e6e340_3         6.1 MB  anaconda
#     ------------------------------------------------------------
#                                            Total:         7.4 MB
#
# The following NEW packages will be INSTALLED:
#
#   blas               anaconda/linux-64::blas-1.0-openblas
#   numpy              anaconda/linux-64::numpy-1.21.5-py37hf838250_3
#   numpy-base         anaconda/linux-64::numpy-base-1.21.5-py37h1e6e340_3
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates    conda-forge::ca-certificates-2022.6.1~ --> anaconda::ca-certificates-2022.4.26-h06a4308_0
#   certifi            conda-forge::certifi-2022.6.15-py37h8~ --> anaconda::certifi-2022.6.15-py37h06a4308_0
#   conda              conda-forge::conda-4.13.0-py37h89c186~ --> anaconda::conda-4.13.0-py37h06a4308_0
#
#
#
# Downloading and Extracting Packages
# blas-1.0             | 48 KB     | : 100% 1.0/1 [00:00<00:00,  7.21it/s]
# numpy-base-1.21.5    | 6.1 MB    | : 100% 1.0/1 [00:03<00:00,  3.27s/it]
# ca-certificates-2022 | 132 KB    | : 100% 1.0/1 [00:00<00:00, 11.70it/s]
# certifi-2022.6.15    | 156 KB    | : 100% 1.0/1 [00:00<00:00, 10.05it/s]
# numpy-1.21.5         | 10 KB     | : 100% 1.0/1 [00:00<00:00, 12.94it/s]
# conda-4.13.0         | 990 KB    | : 100% 1.0/1 [00:00<00:00,  2.30it/s]
# done
# done
# done

# %%
# new code
# !conda upgrade numpy
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - numpy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _openmp_mutex-4.5          |            2_gnu          23 KB  conda-forge
#     brotlipy-0.7.0             |py37h540881e_1004         342 KB  conda-forge
#     charset-normalizer-2.1.0   |     pyhd8ed1ab_0          35 KB  conda-forge
#     colorama-0.4.5             |     pyhd8ed1ab_0          18 KB  conda-forge
#     conda-package-handling-1.8.1|   py37h540881e_1         1.0 MB  conda-forge
#     cryptography-37.0.2        |   py37h38fbfac_0         1.5 MB  conda-forge
#     idna-3.3                   |     pyhd8ed1ab_0          55 KB  conda-forge
#     ld_impl_linux-64-2.36.1    |       hea4e1c9_2         667 KB  conda-forge
#     numpy-1.21.6               |   py37h976b520_0         6.1 MB  conda-forge
#     pip-22.1.2                 |     pyhd8ed1ab_0         1.5 MB  conda-forge
#     pycosat-0.6.3              |py37h540881e_1010         107 KB  conda-forge
#     pycparser-2.21             |     pyhd8ed1ab_0         100 KB  conda-forge
#     pyopenssl-22.0.0           |     pyhd8ed1ab_0          49 KB  conda-forge
#     pysocks-1.7.1              |   py37h89c1867_5          28 KB  conda-forge
#     requests-2.28.1            |     pyhd8ed1ab_0          53 KB  conda-forge
#     ruamel_yaml-0.15.80        |py37h540881e_1007         259 KB  conda-forge
#     setuptools-62.6.0          |   py37h89c1867_0         1.3 MB  conda-forge
#     six-1.16.0                 |     pyh6c4a22f_0          14 KB  conda-forge
#     tqdm-4.64.0                |     pyhd8ed1ab_0          81 KB  conda-forge
#     urllib3-1.26.9             |     pyhd8ed1ab_0         100 KB  conda-forge
#     wheel-0.37.1               |     pyhd8ed1ab_0          31 KB  conda-forge
#     yaml-0.2.5                 |       h7f98852_2          87 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        13.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   charset-normalizer conda-forge/noarch::charset-normalizer-2.1.0-pyhd8ed1ab_0
#   colorama           conda-forge/noarch::colorama-0.4.5-pyhd8ed1ab_0
#
# The following packages will be REMOVED:
#
#   blas-1.0-openblas
#   chardet-4.0.0-py37h89c1867_1
#   cudatoolkit-11.1.1-ha002fc5_10
#   icu-68.1-h58526e2_0
#   libarchive-3.5.1-h3f442fb_1
#   libiconv-1.16-h516909a_0
#   libsolv-0.7.17-h780b84a_0
#   libxml2-2.9.10-h72842e0_3
#   lz4-c-1.9.3-h9c3ff4c_0
#   lzo-2.10-h516909a_1000
#   mamba-0.8.0-py37h7f483ca_0
#   numpy-base-1.21.5-py37h1e6e340_3
#   reproc-14.2.1-h36c2ea0_0
#   reproc-cpp-14.2.1-h58526e2_0
#   zstd-1.4.9-ha95c52a_0
#
# The following packages will be UPDATED:
#
#   _openmp_mutex                                   4.5-1_gnu --> 4.5-2_gnu
#   brotlipy                          0.7.0-py37h5e8e339_1001 --> 0.7.0-py37h540881e_1004
#   ca-certificates    anaconda::ca-certificates-2022.4.26-h~ --> conda-forge::ca-certificates-2022.6.15-ha878542_0
#   conda               anaconda::conda-4.13.0-py37h06a4308_0 --> conda-forge::conda-4.13.0-py37h89c1867_1
#   conda-package-han~                   1.7.2-py37hb5d75c8_0 --> 1.8.1-py37h540881e_1
#   cryptography                         3.4.5-py37h5d9358c_1 --> 37.0.2-py37h38fbfac_0
#   idna                                    2.10-pyh9f0ad1d_0 --> 3.3-pyhd8ed1ab_0
#   ld_impl_linux-64                        2.35.1-hea4e1c9_2 --> 2.36.1-hea4e1c9_2
#   numpy               anaconda::numpy-1.21.5-py37hf838250_3 --> conda-forge::numpy-1.21.6-py37h976b520_0
#   pip                                   21.0.1-pyhd8ed1ab_0 --> 22.1.2-pyhd8ed1ab_0
#   pycosat                           0.6.3-py37h5e8e339_1006 --> 0.6.3-py37h540881e_1010
#   pycparser                               2.20-pyh9f0ad1d_2 --> 2.21-pyhd8ed1ab_0
#   pyopenssl                             20.0.1-pyhd8ed1ab_0 --> 22.0.0-pyhd8ed1ab_0
#   pysocks                              1.7.1-py37h89c1867_3 --> 1.7.1-py37h89c1867_5
#   requests                              2.25.1-pyhd3deb0d_0 --> 2.28.1-pyhd8ed1ab_0
#   ruamel_yaml                     0.15.80-py37h5e8e339_1004 --> 0.15.80-py37h540881e_1007
#   setuptools                          49.6.0-py37h89c1867_3 --> 62.6.0-py37h89c1867_0
#   six                                   1.15.0-pyh9f0ad1d_0 --> 1.16.0-pyh6c4a22f_0
#   tqdm                                  4.59.0-pyhd8ed1ab_0 --> 4.64.0-pyhd8ed1ab_0
#   urllib3                               1.26.3-pyhd8ed1ab_0 --> 1.26.9-pyhd8ed1ab_0
#   wheel                                 0.36.2-pyhd3deb0d_0 --> 0.37.1-pyhd8ed1ab_0
#   yaml                                     0.2.5-h516909a_0 --> 0.2.5-h7f98852_2
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   certifi            anaconda::certifi-2022.6.15-py37h06a4~ --> conda-forge::certifi-2022.6.15-py37h89c1867_0
#
#
#
# Downloading and Extracting Packages
# setuptools-62.6.0    | 1.3 MB    | : 100% 1.0/1 [00:00<00:00,  1.67it/s]
# ruamel_yaml-0.15.80  | 259 KB    | : 100% 1.0/1 [00:00<00:00,  9.08it/s]
# colorama-0.4.5       | 18 KB     | : 100% 1.0/1 [00:00<00:00, 21.61it/s]
# numpy-1.21.6         | 6.1 MB    | : 100% 1.0/1 [00:01<00:00,  1.86s/it]
# tqdm-4.64.0          | 81 KB     | : 100% 1.0/1 [00:00<00:00, 15.51it/s]
# six-1.16.0           | 14 KB     | : 100% 1.0/1 [00:00<00:00, 22.00it/s]
# urllib3-1.26.9       | 100 KB    | : 100% 1.0/1 [00:00<00:00, 13.87it/s]
# charset-normalizer-2 | 35 KB     | : 100% 1.0/1 [00:00<00:00, 20.42it/s]
# yaml-0.2.5           | 87 KB     | : 100% 1.0/1 [00:00<00:00, 15.88it/s]
# pycosat-0.6.3        | 107 KB    | : 100% 1.0/1 [00:00<00:00, 15.73it/s]
# ld_impl_linux-64-2.3 | 667 KB    | : 100% 1.0/1 [00:00<00:00,  4.66it/s]
# pyopenssl-22.0.0     | 49 KB     | : 100% 1.0/1 [00:00<00:00, 20.62it/s]
# pysocks-1.7.1        | 28 KB     | : 100% 1.0/1 [00:00<00:00, 16.70it/s]
# pycparser-2.21       | 100 KB    | : 100% 1.0/1 [00:00<00:00, 13.08it/s]
# pip-22.1.2           | 1.5 MB    | : 100% 1.0/1 [00:00<00:00,  1.72it/s]
# _openmp_mutex-4.5    | 23 KB     | : 100% 1.0/1 [00:00<00:00, 18.24it/s]
# requests-2.28.1      | 53 KB     | : 100% 1.0/1 [00:00<00:00, 17.24it/s]
# cryptography-37.0.2  | 1.5 MB    | : 100% 1.0/1 [00:00<00:00,  2.16it/s]
# idna-3.3             | 55 KB     | : 100% 1.0/1 [00:00<00:00, 18.52it/s]
# conda-package-handli | 1.0 MB    | : 100% 1.0/1 [00:00<00:00,  4.15it/s]
# brotlipy-0.7.0       | 342 KB    | : 100% 1.0/1 [00:00<00:00,  8.28it/s]
# wheel-0.37.1         | 31 KB     | : 100% 1.0/1 [00:00<00:00, 17.53it/s]
# done
# done
# done

# %%
# !process_climate_indices --index spi --periodicity monthly --netcdf_precip /content/drive/MyDrive/IWMI/Input/IMERG_concat_ncpdq1.nc4 --var_name_precip precipitation --output_file_base /content/drive/MyDrive/IWMI/Output/IMERG --scales 1 2 3 6 9 12 24 36 48 60 72 --calibration_start_year 2000 --calibration_end_year 2021 --multiprocessing all
# Out:
# 2022-06-29  09:42:12 INFO Start time:    2022-06-29 09:42:12.224250
# 2022-06-29  09:42:13 INFO Computing 1-month SPI/Pearson
# 2022-06-29  09:42:48 INFO Computing 1-month SPI/Gamma
# 2022-06-29  09:43:08 INFO Computing 2-month SPI/Pearson
# 2022-06-29  09:43:44 INFO Computing 2-month SPI/Gamma
# 2022-06-29  09:44:05 INFO Computing 3-month SPI/Pearson
# 2022-06-29  09:44:41 INFO Computing 3-month SPI/Gamma
# 2022-06-29  09:45:01 INFO Computing 6-month SPI/Pearson
# 2022-06-29  09:45:39 INFO Computing 6-month SPI/Gamma
# 2022-06-29  09:46:00 INFO Computing 9-month SPI/Pearson
# 2022-06-29  09:46:36 INFO Computing 9-month SPI/Gamma
# 2022-06-29  09:46:56 INFO Computing 12-month SPI/Pearson
# 2022-06-29  09:47:32 INFO Computing 12-month SPI/Gamma
# 2022-06-29  09:47:53 INFO Computing 24-month SPI/Pearson
# 2022-06-29  09:48:28 INFO Computing 24-month SPI/Gamma
# 2022-06-29  09:48:49 INFO Computing 36-month SPI/Pearson
# 2022-06-29  09:49:24 INFO Computing 36-month SPI/Gamma
# 2022-06-29  09:49:44 INFO Computing 48-month SPI/Pearson
# 2022-06-29  09:50:21 INFO Computing 48-month SPI/Gamma
# 2022-06-29  09:50:42 INFO Computing 60-month SPI/Pearson
# 2022-06-29  09:51:16 INFO Computing 60-month SPI/Gamma
# 2022-06-29  09:51:37 INFO Computing 72-month SPI/Pearson
# 2022-06-29  09:52:11 INFO Computing 72-month SPI/Gamma
# 2022-06-29  09:52:31 INFO End time:      2022-06-29 09:52:31.879647
# 2022-06-29  09:52:31 INFO Elapsed time:  0:10:19.655397

# %%
# new code
# change the order of the to be readable by QGIS (SPI3, SPI6, SPI9, SPI12)
# !ncpdq -a time,lat,lon /content/drive/MyDrive/IWMI/Output_spi_gamma_12.nc /content/drive/MyDrive/IWMI/QGIS_spi_gamma_12.nc

# %% [markdown]
# ## 5. Interpret the result using Panoply
#
# The visualization can be employed with Panoply, which is independent with the google colab.

# %% [markdown]
# 1. Launch the Panoply desktop application
# 2. Open the SPI file ```/Output/IMERG_spi_gamma_01.nc``` in Panoply
# 3. From the Datasets tab select spi_gamma_01 and click Create Plot
# 4. In the Create Plot window select ‘Create a georeferenced <<Longitude Latitude>> plot’ and click Create
# 5. When the Plot window opens:
#     - Array tab: Change the time into 238 to view the latest/last data ~ Mar 2020
#     - Scale tab: Change value on Min -3, Max 3, Major 6, Color Table CB_RdBu_09.cpt
#     - Map tab: Change value on Center on Lon 115.0, Lat -8.5, then Zoom in the map through menu-editor Plot > Zoom Plot In few times until Bali island bigger.
#     - Overlays tab: Change Overlay 1 to MWDB_Coasts_Countries_1.cnob
#     - To explore the values in the array, click on the Array 1 tab at the top of the window

# %% [markdown]
# ## End
